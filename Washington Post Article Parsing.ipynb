# %%
import urllib
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %%
articleURL = "https://www.washingtonpost.com/world/europe/companies-struggle-to-recover-after-massive-cyberattack-with-ransom-demands/2017/06/28/4e9e8fbe-5bd5-11e7-8e2f-ef443171f6bd_story.html?utm_term=.e648a0e5be2c"

# %%
page = urlopen(articleURL).read().decode('utf8','ignore')
soup = BeautifulSoup(page,'lxml')
soup
# Out:
# <!DOCTYPE html>
# <html class="article layout_article rendering-context-www" itemscope="" itemtype="http://schema.org/NewsArticle" lang="en"> <head> <script id="_$cookiemonster">(function(b,m){function d(b,d){this.wl={map:f.map.concat(b||[]),reg:f.reg.concat(d||[])}}var f={reg:[],map:[]};d.prototype.ommNom=function(){return this.nom(!0,void 0)};d.prototype.allows=function(b){return!(-1<this.nom(!1,[b]).indexOf(b))};d.prototype.nom=function(d,f){for(var c=[],l=b.location.hostname.split("").reverse().join("").slice(0,18),g=f||b.cookie.split(";"),a,h,e=0;e<g.length,a=g[e];e++)a=a.trim().split("\x3d")[0].toLowerCase(),-1<this.wl.map.indexOf(a)||c.push(a);for(var k=0;k<this.wl.reg.length,
# h=this.wl.reg[k];k++)for(e=h.lastIndex=0;e<g.length,a=g[e];e++)a=a.trim().split("\x3d")[0].toLowerCase(),h.test(a)?-1<c.indexOf(a)&&c.splice(c.indexOf(a),1):0>c.indexOf(a)&&0>this.wl.map.indexOf(a)&&c.push(a);d&&("moc.tsopnotgnihsaw"==l&&(this.wl.reg.length||this.wl.map.length)?setTimeout(function(a){return function(){for(var a=0;a<c.length;a++)b.cookie=c[a]+"\x3d; expires\x3dThu, 01 Jan 1970 00:00:01 GMT; path\x3d/; domain\x3dwww.washingtonpost.com",b.cookie=c[a]+"\x3d; expires\x3dThu, 01 Jan 1970 00:00:01 GMT; path\x3d/; domain\x3d.washingtonpost.com",
# b.cookie=c[a]+"\x3d; expires\x3dThu, 01 Jan 1970 00:00:01 GMT; path\x3d/; domain\x3d"}}(this),0):console.error("[cookie-monster] Cowardly refusing to delete cookies on "+b.location.hostname,c));return c};return b.__CookieMonster__=d})(document);</script> <script>console.time("header-start");</script> <script>var TWP_Debug=window.TWP_Debug||{};TWP_Debug.initialTime=new Date;window.pageBuilder=window.pageBuilder||{};window.pageBuilder.loadAsyncFeatures=function(){__e=window.__e||[];__e.push(["lazy-scroll",function(){var b=window.document.getElementsByClassName("pb-async");[].slice.call(b).map(function(a){return a.id}).forEach(function(a){window.pageBuilder.loadAsyncFeature(a)})}])};window.pageBuilder.featureLoaded=function(){$(window.document).trigger("dom-manipulation-complete")};</script> <meta content="4e9e8fbe-5bd5-11e7-8e2f-ef443171f6bd" name="eomportal-uuid"/> <meta content="1498678244" name="object-hash"/> <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/> <meta charset="utf-8"/> <meta content="width=device-width, initial-scale=1.0, user-scalable=yes, minimum-scale=0.5, maximum-scale=2.0" id="viewport" name="viewport"/> <meta content="unsafe-url" name="referrer"/> <meta content="ukraine, ransomware, cyberattack, ukraine cyber, ukraine ransomware, bitcoin, rosneft, pavlo rozenko, Kaspersky labs, Petya, Maersk, worldwide cybarattack" name="keywords"/> <meta content="ukraine, ransomware, cyberattack, ukraine cyber, ukraine ransomware, bitcoin, rosneft, pavlo rozenko, Kaspersky labs, Petya, Maersk, worldwide cybarattack" name="news_keywords"/> <meta name="twitter:site" value="@WashingtonPost"/> <meta content="summary_large_image" name="twitter:card"/> <meta content="article" property="og:type"/> <meta content="Washington Post" property="og:site_name"/> <meta content="True" itemprop="mainEntityOfPage"/> <meta content="https://www.facebook.com/washingtonpost" property="article:publisher"/> <meta content="1513210492" property="fb:admins"/> <meta content="41245586762" property="fb:app_id"/> <meta content="1244584375" property="fb:admins"/> <meta content="4403963" property="fb:admins"/> <meta content="2724956" property="fb:admins"/> <meta content="500835072" property="fb:admins"/> <link href="/pb/resources/json/desktop-notifications-manifest.json" rel="manifest"/> <title>Companies struggle to recover after massive cyberattack with ransom demands - The Washington Post</title> <link href="https://www.washingtonpost.com/world/europe/companies-struggle-to-recover-after-massive-cyberattack-with-ransom-demands/2017/06/28/4e9e8fbe-5bd5-11e7-8e2f-ef443171f6bd_story.html" itemprop="url" rel="canonical"/> <meta content="https://www.washingtonpost.com/world/europe/companies-struggle-to-recover-after-massive-cyberattack-with-ransom-demands/2017/06/28/4e9e8fbe-5bd5-11e7-8e2f-ef443171f6bd_story.html" property="og:url"/> <meta content="https://img.washingtonpost.com/rf/image_1484w/2010-2019/WashingtonPost/2017/06/28/Foreign/Images/2017-06-28T023423Z_1888700886_RC17E8D8BE10_RTRMADP_3_CYBER-ATTACK-MAERSK.jpg?t=20170517" itemprop="image" property="og:image"/> <meta content="Companies struggle to recover after massive cyberattack with ransom demands" property="og:title"/> <meta content="Systems as far afield as Asia were hit, but the epicenter of the outbreak was in Ukraine." itemprop="description" name="description"/> <meta content="Systems as far afield as Asia were hit, but the epicenter of the outbreak was in Ukraine." property="og:description"/> <meta content="index,follow" name="robots"/> <meta content="normal" name="theme"/> <meta content="" name="audio_url"/> <link href="https://www.washingtonpost.com/amphtml/world/europe/companies-struggle-to-recover-after-massive-cyberattack-with-ransom-demands/2017/06/28/4e9e8fbe-5bd5-11e7-8e2f-ef443171f6bd_story.html" rel="amphtml"/> <link href="android-app://com.washingtonpost.rainbow/wp-android-rainbow/www.washingtonpost.com/world/europe/companies-struggle-to-recover-after-massive-cyberatt ...
# (function(){try{wp_meta_data=window.wp_meta_data||{},wp_meta_data.platform="pagebuilder","isPageInitiallyHydrated"in wp_meta_data||(wp_meta_data.isPageInitiallyHydrated=!0),wp_meta_data.showAds=!0,wp_meta_data.isPWA=!1,wp_meta_data.showPreRollAds=!1,wp_meta_data.isHomepage=!1,wp_meta_data.isErrorPage=!1,wp_meta_data.isMultimedia=!1,wp_meta_data.wt="article_story",delete wp_meta_data.facet,delete wp_meta_data.contentName,delete wp_meta_data.contentLength,wp_meta_data.page_id=["4e9e8fbe-5bd5-11e7-8e2f-ef443171f6bd"],
# wp_meta_data.author=["David Filipov","Andrew Roth","Ellen Nakashima"],wp_meta_data.keywords="ukraine;ransomware;cyberattack;ukraine cyber;ukraine ransomware;bitcoin;rosneft;pavlo rozenko;Kaspersky labs;Petya;Maersk;worldwide cybarattack".split(";"),wp_meta_data.clavis=wp_meta_data.clavis||{},wp_meta_data.clavis.keywords=[],wp_meta_data.clavis.topics=[],wp_meta_data.clavis.ct=[],delete wp_meta_data.destinations,wp_meta_data.hot_topic=[!1],delete wp_meta_data.subjects,delete wp_meta_data.category,delete wp_meta_data.people_names,
# delete wp_meta_data.people_positions,delete wp_meta_data.organization_names,delete wp_meta_data.coverage_industrys,delete wp_meta_data.ideology,delete wp_meta_data.addresses,delete wp_meta_data.neighborhoods,delete wp_meta_data.zip_codes,delete wp_meta_data.counties,delete wp_meta_data.venues,delete wp_meta_data.cities,delete wp_meta_data.states,delete wp_meta_data.countries,delete wp_meta_data.breaking_news,wp_meta_data.contentType=["article"]}catch(a){}})();</script> <script>window.wpAd={inventory:{interstitial:{size:[],keyvalues:{ad:"interstitial"}},leaderboard:{size:[[728,90],[970,66],[970,250]],keyvalues:{pos:"leaderboard"}},inline_bb:{size:[[300,250],"fluid"],sizeOnCondition:{windowWidth:1250,size:[620,250]}},"inline_bb_*":{size:[[300,250],"fluid"],sizeOnCondition:{windowWidth:1250,size:[620,250]}},flex_ss_bb_hp:{size:[[336,850],[336,280],[160,600],[300,250],[300,600],[300,1050]]},"flex_ss_bb_hp_*":{size:[[336,850],[336,280],[160,600],[300,250],[300,600],[300,1050]]},
# flex_bb_hp:{size:[[336,850],[336,280],[300,600],[300,1050],[300,250]]},tiffany_tile:{size:[[200,60],[184,90]],keyvalues:{ad:["tiffany_tile"]}},"tiffany_tile_*":{size:[[200,60],[184,90]]},brandconnect_front:{size:[[1,8],"fluid"]},bc_pb_homepage:{size:[[1,8],"fluid"]},"336x60":{size:[[336,60]],keyvalues:{ad:["336x60"]}},"336x35_top":{size:[[336,35]],keyvalues:{ad:["336x35"]}},marketing_2:{size:[[1,1]]},marketwatch:{size:[[1,1]]},"88x31":{size:[[88,31]]},bigbox_gallery:{size:[[300,250]]},mob_bigbox:{size:[[300,
# 250],[300,600],"fluid"]},"mob_bigbox_*":{size:[[300,250],"fluid"]},fixedBottom:{size:[[320,50],[300,50]]},pushdown:{size:[[1,1],[970,66],[970,90],[728,90],[970,250]]},bc_bigbox:{size:[[300,250]]},polly_article:{size:[[1,1]]}},exclusionsKeyWords:{natural_disaster:"deepwater;oil spill;shell;exxon;citgo;bp;chevron;hess;sunoco;disaster;fire;explosion;oil;coal;death;dead;quake;earthquake;tsunami;tornado;hurricane;flood;bed bug;infestation;gas".split(";"),human_disaster:"oreilly;Ailes;o'reilly;fox news;abuse;death;trafficking;dead;gunshot;murderer;porn;sex tape;sexting;sexual abuse;molestation;assault;child abuse;sex abuse;ISIS;ISIL;Islamic State;Al Qaeda;Syria;Syrian;Assad;shooter;shooting;migrants;aylan kurdi;refugee crisis;drown;shoot;vatican;spanair;aground;rescue;attack;disaster;explosion;war;hostage;terror;terrorist;bomb;blast;mining;miner;violence;riot;crash;9/11;sept. 11;september 11;behead;United 93;pistorius;ebola;rape;rapist;amtrak;derailment;benghazi;misconduct".split(";"),
# financial_crisis:"corrupt;lawsuit;goldman;aig;foreclosure;enron;sec;mortgage;Insurance;health;bank;wall street;protest;labor strike;union strike;labor issue;union issue;teacher strike;teachers strike;election".split(";"),inappropriate:"porn deepwater gambling sex alcohol pornography".split(" ")},posOnCommericalNode:{"washingtonpost.com":{pos:{leaderboard:{start:"06/17/2017 00:00 EDT",end:"06/17/2017 23:59 EDT"},flex_bb_hp:{start:"06/14/2017 00:00 EDT",end:"12/31/2017 23:59 EDT"},tiffany_tile:{start:"05/24/2017 00:00 EDT",
# end:"12/31/2017 23:59 EDT"},tiffany_tile_2:{start:"05/24/2017 00:00 EDT",end:"12/31/2017 23:59 EDT"},marketwatch:!1,pushdown:{start:"06/21/2017 00:00 EDT",end:"06/22/2017 23:59 EDT"}}}}};</script> <script async="" src="https://www.washingtonpost.com/wp-stat/ad/zeus/wp-ad.min.js"></script> <script>window.console&&console.log&&console.log("["+(new Date-TWP_Debug.initialTime)/1E3+"] STARTING load_immediately");</script> <script>console.time("load_immediately");</script> <script src="/pb/gr/c/default/r0pDNIUocOndnq/load_immediately/4697e08d36.js?_=e1bf8"></script> <script>console.timeEnd("load_immediately");</script> <script>wp_import.valor(!0);</script> <script>window.wp_pb=window.wp_pb||{};wp_pb.banditoEnv={TIMEOUT:2500,PERF_API:"https://loxodo-ct.ext.nile.works/api/save-perf",TESTS_API:"https://www.washingtonpost.com/bandito/tests-pb/",EVENTS_API:"https://loxodo-ct.ext.nile.works/api/save-event"};</script> <script>window.head_conf={head:"TWPHead"};</script> <script>console.time("head.min.js");</script> <script src="/pb/resources/js/head.min.js"></script> <script>console.timeEnd("head.min.js");</script> <script>console.time("global");</script> <script src="/pb/gr/c/default/r0pDNIUocOndnq/global/ecae3e7968.js?_=b9e93"></script> <script>console.timeEnd("global");</script> <script>console.time("headjs");</script> <script src="/pb/gr/c/default/r0pDNIUocOndnq/headjs/8bb9d8351d.js?_=69d73"></script> <script>console.timeEnd("headjs");</script> <script>console.time("head.js");</script> <script src="/pb/gr/p/default/r0pDNIUocOndnq/head.js?_=5b7b1"></script> <script>console.timeEnd("head.js");</script> <script>console.time("exec-header-tracking");</script> <script>(function(){TWP="undefined"==typeof TWP?{}:TWP;TWP.Data="undefined"==typeof TWP.Data?{}:TWP.Data;TWP.Data.Tracking={init:function(){this.props={};this.props.platform="pagebuilder";this.props.site="www.washingtonpost.com";this.props.page_type="";this.props.page_name="world:article - ef443171f6bd - 20170628 - companies-struggle-to-recover-after-massive-cyberattack-with-ransom-demands";this.props.section="world";this.props.channel="wp - world";this.props.subsection="world - europe";this.props.hierarchy=
# "world|europe|article";this.props.content_type="article";this.props.story_type="";this.props.headline="Companies struggle to recover after massive cyberattack with ransom demands";this.props.author="David Filipov; Andrew Roth; Ellen Nakashima";this.props.source="The Washington Post";this.props.content_id="4e9e8fbe-5bd5-11e7-8e2f-ef443171f6bd";this.props.page_num="";this.props.columnname="";this.props.blogname="";this.props.published="";this.props.news_or_commercial="News";this.props.commercial_node=
# "/world/europe";this.props.content_category="Foreign";this.props.sectionfront="";this.props.track_scrolling=!0}};TWP.Data.Tracking.init()})();</script> <script>console.timeEnd("exec-header-tracking");</script> <script>console.time("exec-header-review");</script> <script>console.timeEnd("exec-header-review");</script> <script>console.time("exec-header-abtest");</script> <script>console.timeEnd("exec-header-abtest");</script> <script>window.console&&console.log&&console.log("["+(new Date-TWP_Debug.initialTime)/1E3+"] STARTING exec-twp-global");</script> <script>console.time("exec-twp-global");</script> <script>(function(b){var a=[];a.push("//www.washingtonpost.com/pb/gr/c/default/r0pDNIUocOndnq/conf-production/b5411285f6.js?_\x3d81d55");a.push("//www.washingtonpost.com/pb/gr/c/default/r0pDNIUocOndnq/modal-css/938c258067.css?_\x3d874d9");a.push("//www.washingtonpost.com/pb/gr/c/default/r0pDNIUocOndnq/identity-management/da39a3ee5e.js?_\x3d21843");a.push("https://www.washingtonpost.com/wp-stat/pwapi/prod/wpPwapi1-min.js?token\x3d201706011309EST");a.push("//www.washingtonpost.com/pb/gr/c/default/r0pDNIUocOndnq/identity-management/c4d7fa1f35.js?_\x3d21843");
# a.push("//www.washingtonpost.com/pb/gr/c/default/r0pDNIUocOndnq/wapo-production/8f8c39c9d8.js?_\x3dbee5a");a.push("//www.washingtonpost.com/wp-stat/analytics/latest/main.js?token\x3d201706271439EST");a.push("//www.washingtonpost.com/wp-stat/advertising/pseudo-static/identity-retargeting.js");"undefined"===typeof b.jqm&&a.unshift("//www.washingtonpost.com/pb/gr/c/default/r0pDNIUocOndnq/jqmodal/7a5b554023.js?_\x3da9337");"undefined"===typeof b.cookie&&a.unshift("//www.washingtonpost.com/pb/gr/c/default/r0pDNIUocOndnq/jquery-cookie/4cc3c1bef0.js?_\x3db8874");
# "undefined"===typeof jQuery&&a.unshift("//www.washingtonpost.com/pb/gr/c/default/r0pDNIUocOndnq/jquery/c85562b39d.js?_\x3db45ba");window.head_conf={head:"TWPHead"};console.time("ResourceBundle pb-r-identity");if("undefined"==typeof window.TWPHead){b=document.createElement("script");b.onload=b.onreadystatechange=function(){this.readyState&&"complete"!=this.readyState&&"loaded"!=this.readyState||TWPHead.load(a,function(){console.timeEnd("ResourceBundle pb-r-identity")})};b.src="//www.washingtonpost.com/pb/resources/js/head.min.js";
# var c=document.getElementsByTagName("script")[0];c.parentNode.insertBefore(b,c)}else TWPHead&&TWPHead.load(a,function(){console.timeEnd("ResourceBundle pb-r-identity")})})(jQuery);</script> <script>console.timeEnd("exec-twp-global");</script> </head> <body class="pb-theme-normal pb-full-fluid"> <div class="pub_300x250 pub_300x250m pub_728x90 text-ad textAd text_ad text_ads text-ads text-ad-links" id="wp-adb-c" style="width: 1px !important; height: 1px !important; position: absolute !important; left: -10000px !important; top: -1000px !important;"></div> <div id="pb-f-a"></div> <div class="" id="pb-root"><section class="col-xs-12 layout" id="top-furniture"> <div class="pb-container"> <div class="moat-trackable pb-f-theme-normal pb-f-dehydrate-false pb-1 pb-feature pb-layout-item pb-f-page-push-notifications" data-chain-name="no-name" data-feature-id="page/push-notifications" data-feature-name="no-name" data-pb-fingerprint="0fIsR8n9Wp7" id="f6V38Y1ocOndnq" moat-id="page/push-notifications|world"> <div class="notifications-container hidden"> <div class="pull-right notify-ic"> <i aria-hidden="true" class="fa fa-bell-o"></i> <span class="notif-number hide">2</span> </div> <div class="clear"> </div> <div class="notification-items hide"> <div class="notifications-top-arrow"></div> <div class="notifications-list"> </div> <div class="notifications-controll"> <p class="notify-txt">Desktop notifications are on   | <a class="turn-off" href="">Turn off</a> </p> </div> </div> <div class="permission-request hide"> <div class="notifications-top-arrow"></div> <p class="headline">Get breaking news alerts from <span class="wp-txt"> The Washington Post </span></p> <div class="permission-default"> <p class="notify-txt">Turn on desktop notifications?</p> <div class="actions-container"> <span class="notify-action yes">Yes</span> <span class="notify-action not-now">Not now</span> </div> </div> <div class="permission-denied hide"> <p class="notify-txt">It looks like you've previously blocked notifications. Please update your browser permissions to allow them.</p> <img class="permission-denied-img" src="/pb/resources/img/push_notifications/notification_denied_v1.png"/> </div> </div> </div> </div> </div> <div class="moat-trackable pb-f-theme-normal pb-f-dehydrate-false full pb-feature pb-layout-item pb-f-page-header-v2" data-chain-name="no-name" data-feature-id="page/header-v2" data-feature-name="no-name" data-pb-fingerprint="0fE2pbXsipa" id="f0Z6rqHocOndnq" moat-id="page/header-v2|world"> <!--[if IE 9]><style>#main-sections-nav.subNavigation{width:475px !important}#main-sections-nav{left:-250px !important;width:315px !important}#main-sections-nav-inner{position:absolute !important}#main-sections-nav.subNavigation #main-sections-nav-inner{width:550px !important;overflow-x:hidden !important}#main-sections-nav.subNavigation{width:470px !important}</style><![endif]--> <!--[if IE 9]><div id="page" class="ie ie9 "><![endif]--> <!--[if IE 8]><div id="page" class="ie ie8 "><![endif]--> <!--[if !IE]><!--> <div class="nie " id="page"> <!--<![endif]--> <header class="site-header fixed " id="wp-header"> <nav class="top-nav" id="nav-bar" role="navigation"> <div class=" nav-display-show " id="logo-in-nav" itemprop="publisher" itemscope="" itemtype="https://schema.org/Organization"> <a class="wp-logo-link" href="https://www.washingtonpost.com" itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject"> <img alt="The Washington Post" class="main-logo" src="https://www.washingtonpost.com/pb/resources/img/thewashingtonpost-white-2x.png" width="181"/> <meta content="https://www.washingtonpost.com/pb/resources/img/thewashingtonpost-white-2x.png" itemprop="url"/> <meta content="200" itemprop="width"/> <meta content="40" itemprop="height"/> <div class="tagline-wrapper"> <span class="header-tagline">Democracy Dies in Darkness</span> </div> </a> <meta content="washingtonpost" itemprop="name"/> </div> <div class="main-navigation row"> <div class="col-xs-7 col-md-7 c ...
# (function(d){if(function(){var N="undefined"===typeof IXC_175_8953684100313002||"undefined"===typeof IXC_175_8953684100313002.CanRun||"_175_8953684100313002"!==IXC_175_8953684100313002._175_8953684100313002||IXC_175_8953684100313002.CanRun("abd");if(N)try{(d.IXC_175_8953684100313002=d.IXC_175_8953684100313002||{})._175_8953684100313002="_175_8953684100313002",d[atob("SU5TVEFSVA==")+"_TARGET_NAME"]="abd",d[atob("STExQw==")]=d[atob("STExQw==")]||{}}catch(g){console.error(g)}else{var O="abd"!==d[atob("SU5TVEFSVA==")+
# "_TARGET_NAME"],W="double nanovisor injection: abd after "+d[atob("SU5TVEFSVA==")+"_TARGET_NAME"];O&&console.log(W);"function"!==typeof d[atob("SU5TVEFSVA==")].Init&&(d[atob("SU5TVEFSVA==")].Init=function(){O&&console.error("ignored Init call after "+W)})}return N}()){(function(){function N(b,a){return La(b,a,O,{G:function(c,a){return c.concat(a)}})}function O(b,a){return"object"!==typeof a||Array.isArray(a)?a:La(a,b,O)}function W(){var b=d.googletag;if((b=b&&b.pubads&&"function"===typeof b.pubads&&
# b.pubads())&&b.addEventListener&&"function"===typeof b.addEventListener)try{b.addEventListener("slotRenderEnded",function(a){var c=a.slot&&a.slot.getSlotElementId();a.isEmpty||(X[c]=!0);Ma.b(c,a.isEmpty)}),b.addEventListener("slotVisibilityChanged",function(a){a=a.slot&&a.slot.getSlotElementId();X[a]&&Na.b(a)}),b.addEventListener("slotOnload",function(a){a=a.slot&&a.slot.getSlotElementId();X[a]&&Oa.b(a)}),b.addEventListener("impressionViewable",function(a){a=a.slot&&a.slot.getSlotElementId();X[a]&&
# Pa.b(a)}),d.clearInterval(Qa)}catch(a){}}function g(b){return b.split("").filter(function(a,c){return 0===c%2}).reverse().join("")}function E(){return 1===x.c}function Ra(){return 4===x.c}function Y(){return 2===x.c}function Sa(){return 3===x.c}function Ta(){return 5===x.c}function Z(b){G=new ta(b);x=G.U;P=G.R;return G}function ua(b,a){if(!b&&(console.error(a),(b=[],0<b.length)&&console.log(b),Ua))throw a;}function h(b,a){function c(){this.constructor=b}Wb(b,a);b.prototype=null===a?Object.create(a):
# (c.prototype=a.prototype,new c)}function Va(){for(var b=[],a=1;9>=a;a++)b[a]=H["$"+a];return b}function Wa(b){for(var a="",c="",e=1;b&&9>=e;e++)b[e]?(b[e]=b[e].replace(/[-[\]{}()*+?.,\\^$|#\s]/g,"\\$&"),a+="("+b[e]+")",c+=""+b[e]):a+="()";c.match(a)}function I(b){return"string"===typeof b&&0<b.length?b:null}function Xa(b){var a;void 0===a&&(a=Xb);var c=new a.la;b.onload&&(c.onload=function(){return b.onload(new va(c,b))});b.onerror&&(c.onerror=function(){return b.onload(new va(c,b))});if(b.Ja)for(var e=
# 0;e<b.Ja.length;e++)c.setRequestHeader(b.Ja[e].B,this.Ja[e].Nd);c.withCredentials=!!b.credentials;a.Nc.call(c,b.method,b.url,!1!==b.async);e=b.body&&JSON.stringify(b.body);a.ed.call(c,e);!1===b.async&&new va(c,b)}function Ya(b){return function(a){function c(){return null!==a&&a.apply(this,arguments)||this}h(c,a);c.prototype.va=function(){throw Error("Method not implemented.");};return c}(b)}function Za(b){return function(a){function c(){var c=null!==a&&a.apply(this,arguments)||this;c.Kc=new aa;return c}
# h(c,a);return c}(b)}function Yb(b){b.La.Ec();$a=b}function y(b,a){b=b.split(".");for(var c=d||{},e,f=0;f<b.length-1;++f){e=b[f];if(!c)return;var l=c[e]||{};try{c[e]=l}catch(ab){}c=l}e=b[b.length-1];if(c){ua(!!e,"In Export, name not defined");try{c[e]=a}catch(ab){}}}function Zb(b){b=b.split(".");for(var a=d,c,e=0;a&&e<b.length-1;++e)if(c=b[e],a=a[c],!a)return;c=b[b.length-1];ua(!!a&&!!c,"In Deport, obj or name not defined");try{var f=Object.getOwnPropertyDescriptor(a,c);f&&f.writable&&delete a[c]||
# (a[c]=void 0)}catch(l){}}function wa(){return d.document.currentScript||d.document.scripts[document.scripts.length-1]}function $b(){if(z&&J&&z.nextSibling===J)for(var b=J.nextSibling,a=z;a!=b;){var c=a,a=a.nextSibling;c.parentNode.removeChild(c)}Zb(ba);y(ba+".Init",function(){});J=z=null}function p(b,a,c){var e={};e.Type=b;e[w]=a;c&&(e[bb]=c);return e}function Q(b,a,c){try{Object.defineProperty(b,a,c)}catch(e){}}function ca(b){var a=typeof b;if(b&&("object"===a||"function"===a)&&!ac.call(b,"__ext")){if(b instanceof
# NodeList||b instanceof HTMLCollection){for(var a=b.length,c=0;c<a;c++)ca(b[c]);return b}a=void 0;c=b.nodeType,1===c&&(a=xa[b.nodeName]),a||(a=cb[c]),a||(a=b.__pext);a&&(c={Od:{},Uc:a,wa:bc++},db.value=c,Object.defineProperty(b,"__ext",db),a.fb(b))}return b}function da(b,a){var c=b.__ext;c||(ca(b),c=b.__ext);return(b=c)&&b.Uc.rc(a)}function cc(b,a){for(var c=Object.getOwnPropertyNames(b),e=0,f=c.length;e<f;++e){var l=c[e];if(!(l in a)){var d=Object.getOwnPropertyDescriptor(b,l);try{Object.defineProperty(a,
# l,d)}catch(n){}}}(c=b.prototype)&&(a.prototype=c);if(b=b.name)try{Object.defineProperty(a,"name",{value:b})}catch(n){}}function dc(b){b.J.pa(function(){var a=da(this,b.B);return a?a.xd(this):b.J.D.call(this)});b.Set.pa(function(a){var c=da(this,b.B);c?c.Set(this,a,!0,!1):b.Set.D.call(this,a);return a})}function eb(b,a,c){var e=Object.getOwnPropertyDescriptor(b,a),f=e&&e.get,l=e&&e.set,d=e&&e.value;f||l?Object.defineProperty(b,a,{get:f,set:function(a){d=a;c(d);l.apply(this,arguments)},enumerable:e.enumerable,
# configurable:!0}):Object.defineProperty(b,a,{get:function(){return d},set:function(a){d=a;c(d)},enumerable:e&&e.enumerable||!0,configurable:!0})}function ec(){function b(b){Array.isArray(b)&&!a(b)&&b.push(c)}function a(a){for(var b=!1,e=0;e<a.length;e++)if(a[e]===c){b=!0;break}return b}function c(){var c=d.googletag.display,a=[];d.googletag.display=function(b){b?(a.push({id:b}),fc.push(b),fb.b([b])):a.push({id:"unknown"});e++;c.apply(this,arguments)}}var e=0,f=d.googletag||{};d.googletag=f;f.cmd=
# f.cmd||[];f.cmd.push(c);eb(d,"googletag",function(e){Array.isArray(e.cmd)&&!a(e.cmd)&&e.cmd.push(c);eb(e,"cmd",b)})}function gc(){d.pbjs=d.pbjs||{};d.pbjs.que=d.pbjs.que||[];d.pbjs.que.push(function(){d.pbjs.onEvent("bidResponse",function(b){gb.push({SlotId:b.adUnitCode,ExchangeName:b.bidder,CPM:b.cpm,ResponseTime:b.timeToRespond})});d.pbjs.onEvent("auctionInit",function(){hb=!0})})}function ya(b){try{var a=d[b];a.setItem("TEST","TEST");a.removeItem("TEST");return!0}catch(c){return!1}}function za(){var b=
# {};try{if(ya(ib)){var a=sessionStorage._175_8953684100313002;a&&(b=JSON.parse(a))}}catch(c){}return b}function hc(b){function a(c){var a=new ea(c);c=a.m.I||"";a=a.m.ca||"";return c=a.startsWith("/")?c+a:c+"/"+a}ic.qa.Set.Xc(function(c){for(var e=0;e<b.a.G.length;e++)if(b.a.G[e].test(c)){this.addEventListener("error",function(){jb.b(a(c))});this.addEventListener("load",function(){Aa.push(a(c))});break}})}function jc(){return new fa(function(b){function a(a){var e=!1;"load"===a.type?e=!1:"error"===
# a.type&&(e=!0);b(p(kc,e,a.currentTarget.src));c&&(a=a.target)&&a.parentNode&&a.parentNode.removeChild(a)}var c=4===x.c&&3===P.c,e=document.createElement("img");e.onload=a;e.onerror=a;var f=Math.floor(Math.random()*R.length);e.src=R[f]+"?"+kb[Math.floor(Math.random()*kb.length)];c&&document.body.appendChild(e);1<R.length&&R.splice(f,1)})}function Ba(b){return new fa(function(a){var c=lc,e=Ra();if(E()||e||Y()){var f;e&&(f=setTimeout(function(){a(p(c,!1,"Timed out on error"))},500));var l=!1,d=function(b){if(!l){l=
# !0;e&&clearTimeout(f);var d=!1;"load"===b.type?d=!1:"error"===b.type&&(d=!0);a(p(c,d,b.currentTarget.href));n&&n.parentNode&&n.parentNode.removeChild(n)}},n=document.createElement("link");n.onload=d;n.onerror=d;n.rel=Y()?"prefetch":"preload";n.as="script";d=Math.floor(Math.random()*b.length);n.href=b[d];A&&A.parentNode&&A.parentNode.insertBefore(n,A);1<b.length&&b.splice(d,1)}else a(p(c,!1,"Neither Chrome nor Safari"))})}function mc(){return new fa(function(b){var a=document.createElement("iframe");
# a.src=d.atob("Ly90cGMuZ29vZ2xlc3luZGljYXRpb24uY29tL3NhZmVmcmFtZS8=")+d.atob("MS0wLTU=")+d.atob("L2h0bWwvY29udGFpbmVyLmh0bWw=");a.style.height="1px";a.style.width="1px";a.style.left="-555px";a.style.top="-555px";a.style.display="block";a.scrolling="no";a.frameBorder="0";var c=d.atob("PHNjcmlwdD53aW5kb3cucGFyZW50ICYmIHdpbmRvdy5wYXJlbnQucG9zdE1lc3NhZ2UoIg==")+d.atob("aTEwY09L")+d.atob("IiwgICIqIik8L3NjcmlwdD4="),e=setTimeout(function(){b(p(B,!0,"Disabled"));clearTimeout(e);a.parentNode&&a.parentNode.removeChild(a)},
# 5E3),f=lb();a.name=d.atob("MS0wLTU=")+";"+c.length+";"+c;d.addEventListener("message",function(c){c=c.data;"string"===typeof c&&0===c.lastIndexOf(d.atob("aTEwY09L"),d.atob("aTEwY09L").length+1)&&(b(p(B,!1,String(lb()-f))),clearTimeout(e),a.parentNode&&a.parentNode.removeChild(a))},!1);A&&A.parentNode&&A.parentNode.insertBefore(a,A)})}function nc(){return new fa(function(b){var a=mb[Math.floor(Math.random()*mb.length)],c=document.createElement(a[0]);c.id=a[1];c.style.width="1px";c.style.height="1px";
# c.style.top="-555px";c.style.left="-555px";c.style.display="block";var e=setInterval(function(){document&&document.body&&(document.body.appendChild(c),clearInterval(e),setTimeout(function(){var a=getComputedStyle(c),e,d=!1;if("none"===a.display||(e=a.getPropertyValue("-moz-binding"))&&-1!==e.indexOf("abp-elemhidehit"))d=!0;b(p(oc,d));c&&c.parentNode&&c.parentNode.removeChild(c)},200))},10)})}function pc(b){return b[w]||"BFRAME"===b.Type}function ga(b,a){try{var c=[],c=a.Results&&(a[w]?a.Results:a.Results.filter(pc));
# ha[w]&&c.push(ha);var e={adbType:[a[w]?"PRESENT":"NOT"],otherData:JSON.stringify(c),clientIpAddr:"",userAgent:navigator.userAgent,pageUrl:d.location.href,detectionTime:a[ia]},f={data_stream_type:"adb",json_data:JSON.stringify(e),generated_timestamp_msec:Date.now()};nb.Da.D?nb.Da.D.call(navigator,b,JSON.stringify(f)):Xa({method:"POST",url:b,body:f,async:!0,onload:void 0,onerror:void 0,onchange:void 0})}catch(l){}}function Ca(b,a){y(ja+"."+b,a);y(Da+"."+b,a)}function ob(b){Ea?b(Ea):pb.push(b)}function qc(b){Ea=
# b;var a=!0;pb.forEach(function(c){a=c(b)&&a});return a}function rc(){"d3d3Lndhc2hpbmd0b25wb3N0LmNvbQ=="===d.btoa(d.location.hostname)&&ob(function(b){if(b[w])try{if(d.localStorage.setItem("__iabcd","true"),"true"===d.localStorage.getItem("__iabcr")||-1<document.cookie.indexOf("__iabcr=true"))return!0}catch(a){}return!1})}function qb(b){var a="";try{a=b.location.protocol}catch(c){a="cross"}return a}function La(b,a,c,e){if(!b)return a;if(a)for(var f=Object.keys(a),d=f.length-1;0<=d;--d){var g=f[d],
# n=a[g],h=b[g],n="undefined"===typeof h?n:(e&&e[g]||c)(h,n);b[g]=n}return b}function ka(b){return document[b]&&""===document[b].name?!0:!1}var Da=g("C41119I0"),ja=g("C70918I6"),ba=g("T3R7A3T1S1N7I1"),la=g("r0e5n4e3t4s3i8L2t3n7e0v4E2d6d0A8d3e0h5c4t3a4P3"),ma=g("r2o8r3r5E8n6O5d3e4h2c0t4a4P9"),rb=g("=3=7A0d8v591m9U03897G8Z7h1h329c6"),K=g("09V624Z0"),sc=g("04V820a8j29621U5i7V127V1"),L=g("E7B4U2O2Y3");g("B6U4O9Y2");g("P7B8D7A5");var S=g("B6D4A4"),sb=g("S3T0A2T4S4B1D0A3");g("G3D6A0");g("P6C0X0E0");var tc=
# g("X7L8O8V0"),r=g("E3N7O8N9"),M=g("E0V1A6R7B7"),uc=g("d5e6r0i3f5_9d8a3o7l6n1o2_7e1l5g2o5o6g0"),vc=g("r4o0t4a7g3i3v7a9N1"),wc=g("k4c8a8r4T5t8o2N3o5d5"),xc=g("e8d0o3c7 9e4v2i9t7a8n5"),yc=g("k6c2a6b8l2l4a0C5d7b2A5r3e2t1s4i7g6e2R6"),lc=g("T1P5I0R3C7S3B3"),kc=g("G1M4I3B9");g("L7M1T9H4B2");var oc=g("T2N9E3M4E3L0E3"),B=g("E7M9A2R1F6B1"),zc=g("D5E4T7S3E3U9Q0E8R6D9A7P8F5D2"),tb=g("D4E9D7A6O9L2P0F2D1"),F=g("I7R4U2D2A4D2E1K2C5O4L4B3"),ub=g("I5R0U6D7A9D4E9D6A0O4L7"),vb=g("E6L7B2A8W3E2I6V1P7F4D6"),wb=g("E6G9N4A4H6C0W5E6I8V3P4F4D0"),
# xb=g("D5E0R3E8D5N8E0R2P5F8D0"),Ac=g("S8T4A2T0S1D0I1B3E6R2P1");g("S3T4S9E6T1G1I8S7N4O8N3T2P2R2");var yb=g("D9F6"),Bc=g("T0L8U2S7E5R5D4E9R7O2T5S3"),Fa=g("T1N0E2S6E4R6P9"),Cc=g("T4O4N7"),zb=g("Y3D1A0E1R3T8O1N1"),Dc=g("e5t9u6o8r7.4h794r305m7"),Ec=g("c30516i4h0p9r7o9m6"),Fc=g("r1e8r6r0e6f1e1r8.2c60815i7"),Gc=g("0706g6/4");g("e3t6a3t3S9h0p2r9o3M3");g("d1e2k4c6o3l0b0");g("d4e1k0c7o9l2b3n0u7");var Hc=g("/8)1]2z1-8a591-008[8]095-704[0g4:8?1(2/1^8"),w=g("d6e9t8c1e8t7e1D3"),bb=g("n0o0s5a5e2R5"),C=g("s7t3l4u6s5e6R5"),
# ia=g("y0c8n3e0t5a2L1n9o8i3t0c4e9t6e3D6"),Ab=g("D8E8D0A1O7L8_1V4"),Bb=g("D9E3D0A3O0L6T2O1N0_7V7"),ib=g("e1g2a2r5o9t0S0n6o9i8s7s6e8s5"),Cb=g("d4f0c30512i8"),ta=function(){function b(a){this.U=this.cb(a,[{w:/MSIE\s([\d]+)(\.([\d]+))?(\.([\d]+))?/,c:3},{w:/Edge\/([\d]+)(\.([\d]+))?(\.([\d]+))?/,c:5},{w:/Trident.*rv:([\d]+)(\.([\d]+))?(\.([\d]+))?/,c:3},{w:/Chrome\/([\d]+)(\.([\d]+))?(\.([\d]+))?/,c:1},{w:/Firefox\/([\d]+)(\.([\d]+))?(\.([\d]+))?/,c:2},{w:/Version\/([\d]+)(\.([\d]+))?(\.([\d]+))?.*Safari/,
# c:4}])||{c:0,na:0,ib:0,hb:0};this.R=this.cb(a,[{w:/Android\s([\d]+)(\.([\d]+))?(\.([\d]+))?/,c:1},{w:/CPU OS ([\d]+)(_([\d]+))?(_([\d]+))?/,c:2},{w:/CPU iPhone OS ([\d]+)(_([\d]+))?(_([\d]+))?/,c:2},{w:/Mac OS X ([\d]+)(_([\d]+))?(_([\d]+))?/,c:3},{w:/Windows NT ([\d]+)(.([\d]+))?(.([\d]+))?/,c:4},{w:/Linux [a-z]*([\d]+)(_([\d]+))?(_([\d]+))?/,c:5},{w:/CrOS [a-z]*([\d]+)(_([\d]+))?(_([\d]+))?/,c:5}])||{c:0,na:0,ib:0,hb:0}}b.prototype.cb=function(a,c){for(var b,f=0;f<c.length;++f){var d=c[f],g=d.w.exec(a);
# if(null!=g){b={c:d.c,na:parseInt(g[1])||0,ib:parseInt(g[3])||0,hb:parseInt(g[5])||0};break}}return b};return b}(),G,x,P;"undefined"!==typeof navigator&&navigator.userAgent?Z(navigator.userAgent):Z("");var T=Object.freeze({W:ta,get xa(){return G},get U(){return x},get R(){return P},zd:E,Fd:Ra,Ad:Y,Ed:Sa,Dd:Ta,Cd:function(){return 3===P.c},Bd:function(){return 2===P.c},yd:Z,ud:function(b){switch(b){case 0:return"Unknown";case 1:return"Chrome";case 2:return"Firefox";case 3:return"Msie";case 4:return"Safari";
# case 5:return"Msedge"}},wd:function(b){switch(b){case 0:return"Unknown";case 1:return"Android";case 2:return"IOS";case 3:return"Mac";case 4:return"Windows";case 5:return"Linux"}}}),Ua=!1,Ic=function(){return function(){this.Cc=[]}}(),Wb=Object.setPrototypeOf||{__proto__:[]}instanceof Array&&function(b,a){b.__proto__=a}||function(b,a){for(var c in a)a.hasOwnProperty(c)&&(b[c]=a[c])},H=RegExp,na=function(){function b(a,c){this.yb=new b.T.la(a,c);c&&(this.$=c)}b.Kd=function(a){b.T=a};b.Ld=function(){var a=
# b.T.V,c=b.T.ra;b.T={la:H,V:function(c){var b=Va(),e=a.apply(this,arguments);Wa(b);return e},ra:function(a){var b=Va(),e=c.apply(this,arguments);Wa(b);return e}}};b.prototype.V=function(a){return b.T.V.apply(this.yb,arguments)};b.prototype.ra=function(a){return b.T.ra.apply(this.yb,arguments)};return b}();na.T={la:H,V:H.prototype.exec,ra:H.prototype.test};var Jc=new na("^(?:([^:/?#]+):)?(?://(?:([^/?#]*)@)?([^/?#:@]*)(?::([0-9]+)?)?)?([^?#]+)?(?:\\?([^#]*))?(?:#(.*))?$"),Kc=/[#\/\?]/g,Lc=new H("(/|^)(?:[^./][^/]*|\\.{2,}(?:[^./][^/]*)|\\.{3,}[^/]*)/\\.\\.(?:/|$)"),
# Mc=/^([/])?(?:\.\.(?:[/]|$))+/,Nc=new na("[^.]+[.](?:([^.]{2}[.][^.]{2})|([^.]+)|com[.]au)$");new na("^([^=]*)(?:=(.*))?$");var ea=function(){function b(a){if(a){if("string"===typeof a)if(a=Jc.V(""+a)){var c=a[7];a={Ab:I(a[1]),Wb:I(a[2]),I:I(a[3]),Port:I(a[4]),ca:I(a[5]),wb:I(a[6]),Ua:"string"===typeof c?c:null}}else a=null}else a={Ab:null,Wb:null,I:null,Port:null,ca:null,wb:null,Ua:null};this.m=a;this.Cache={bb:null,tb:null,ab:null,oa:null,Fa:null,Jd:null}}b.prototype.pc=function(){var a=this.m.Ab;
# return a&&a+":"};b.prototype.Bb=function(a){if(Kc.test(a))return this;this.m.I=a;(a=this.m.ca)&&"/"!==a[0]&&(this.m.ca="/"+a);a=this.Cache;a.bb=null;a.tb=null;a.ab=null;a.oa=null;a.Fa=null;return this};b.prototype.Rb=function(){var a=this.Cache;if(!a.oa){var c=this.m.I;if(c=c&&Nc.V(c))a.oa=c[0],(a.Fa=c[2])||(a.Fa=c[1])}};b.prototype.qc=function(){this.Rb();return this.Cache.oa||this.m.I};b.prototype.kd=function(a){if(a){a=Number(a);if(a!==(a&65535))return;this.m.Port=""+a}else this.m.Port=null;a=
# this.Cache;a.bb=null;a.tb=null;a.ab=null};b.prototype.nc=function(){var a="",c=this.m.ca;c&&(a+=c);(c=this.m.wb)&&(a+="?"+c);(c=this.m.Ua)&&(a+="#"+c);return""!==a?a:null};b.td=function(a){if(null===a)return null;a=a.replace(/(^|\/)\.(?:\/|$)/g,"$1").replace(/\/{2,}/g,"/");for(var c;(c=a.replace(Lc,"$1"))!=a;a=c);return a=a.replace(Mc,"$1")};return b}(),va=function(){function b(a){this.ga=a}b.prototype.A=function(){return 1223===this.ga.status?204:this.ga.status};b.prototype.Jc=function(){return 200<=
# this.ga.status&&300>this.ga.status};b.prototype.Error=function(){return 100>this.A()||599<this.A()?"Network request failed":null};b.prototype.Text=function(){return this.ga.responseText};return b}(),Xb={la:XMLHttpRequest,Nc:XMLHttpRequest.prototype.open,ed:XMLHttpRequest.prototype.send},t=function(){function b(){this.b=this.Ha}b.prototype.Ha=function(){};b.prototype.$a=function(){return this.b!=this.Ha};b.prototype.ka=function(a){return function(){for(var c=0,b=a.length;c<b;++c)a[c].apply(this,arguments)}};
# b.prototype.o=function(a){if(this.b===this.Ha)this.b=a;else if(this.b!==this.pd){var c=this.Fb;c||(c=this.Fb=[this.b,a],this.b=this.pd=this.ka(c))}else this.Fb.push(a);return a};return b}(),Oc=function(b){function a(c){var a=b.call(this)||this;a.sb={async:!0,method:"GET",url:c||"//cenome.nanovisor.io/endpoint/nanovisor",onload:function(c){var b;if(c.Jc()){b=c.Text();var e=(new Function("var module={exports:{}}; var exports=module.exports; "+b+"; return module.exports;"))();a.ja=e.ComputeAll;a.sb.async=
# !1}a.rb.b({ja:a.ja,Response:c,Body:b})}};return a}h(a,b);a.prototype.Ec=function(){this.ja||Xa(this.sb)};return a}(function(){return function(){this.rb=new t}}()),Ga=function(){function b(){this.wa=this.Xa()}b.prototype.Xa=function(){return"id_"+Math.round(1E4*Math.random())};return b}(),aa=function(b){function a(){var c=b.call(this)||this;b.prototype.o.call(c,function(){c.Hc=this;c.jb=arguments});return c}h(a,b);a.prototype.o=function(c){b.prototype.o.call(this,c);this.jb&&c.apply(this.Hc,this.jb);
# return c};return a}(t),Db=function(b){function a(c,e,f){var d=b.call(this)||this;d.rd=c;d.sd=e;d.eb=f;a.Aa.b(d);return d}h(a,b);a.prototype.Xa=function(){return this.Za().toFixed(3)};a.prototype.Za=function(){throw Error("Method not implemented.");};return a}(Ga);Db.Aa=new aa;(function(b){function a(){return null!==b&&b.apply(this,arguments)||this}h(a,b);return a})(Ya(Ga));var Pc="undefined"!==typeof d.performance&&d.performance.now&&function(){return d.performance.now()}||Date&&Date.now&&function(){return Date.now()},
# Qc=function(b){function a(c){var a=b.call(this,c.Ob,c.Pb,c.eb)||this;a.Window=c.Window||d;a.W=new ta(a.Window.navigator.userAgent);return a}h(a,b);a.prototype.Za=function(){return Pc()};a.prototype.va=function(){return this.Window.document.cookie};return a}(Ya(Db));(function(b){function a(){return null!==b&&b.apply(this,arguments)||this}h(a,b);return a})(Za(Ga));var Eb=function(b){function a(c,e){void 0===c&&(c="nanovisor");var f=b.call(this,{Ob:c,Pb:"1",eb:"nanovisor"})||this;e||(e="//cenome.nanovisor.io/endpoint/nanovisor");
# f.La=new Oc(e);f.La.rb.o(function(c){c=c.ja({Gb:{},Ib:{},Kb:{}},{});f.f=c;f.Kc.b(c)});a.Aa.b(f);return f}h(a,b);return a}(Za(Qc));Eb.Aa=new aa;var $a=null,oa=function(){function b(a,c){this.B=a;this.v=c}b.prototype.N=function(a){this.v=a};return b}(),Rc=function(b){function a(){return null!==b&&b.apply(this,arguments)||this}h(a,b);a.prototype.N=function(c){b.prototype.N.call(this,"string"===typeof c?"true"===c:c)};return a}(oa),Sc=function(b){function a(){return null!==b&&b.apply(this,arguments)||
# this}h(a,b);a.prototype.N=function(c){b.prototype.N.call(this,"string"===typeof c?parseInt(c):c)};return a}(oa),Tc=function(b){function a(){return null!==b&&b.apply(this,arguments)||this}h(a,b);return a}(oa),Fb=function(b){function a(){return null!==b&&b.apply(this,arguments)||this}h(a,b);return a}(oa),Uc=function(b){function a(){return null!==b&&b.apply(this,arguments)||this}h(a,b);return a}(Fb),Gb=function(){function b(a){function c(c,a){return"undefined"!==typeof c?c:a}b.Ea("ver");b.za("rId");
# b.za("iframeCommunicationTimeout",3E3);b.md();this.Qa=b.s("enableInterception");this.cc=b.s("enableOptimizedInterceptors",!0);this.ta=b.s("enableCustomInterceptors",!0);this.ec=b.s("useWrapper");this.dc=b.s("partialImage");this.ac=b.s("aisao");b.Ea("apiDomain");b.s("enableHtmlStreaming");b.Ea("htmlStreamingVersion");b.s("enableInstantLoad");b.s("itus");b.s("rum",!1);b.za("m_meb",0);b.s("enableMonitorData");b.s("enableProfiling");this.bc=b.s("enableHardAssert");b.xa=this;this.Oc=a;this.Rc(a);for(var e=
# Object.getOwnPropertyNames(a),f=e.length-1;0<=f;--f){var d=e[f],g=a[d];(d=b.$[d])&&d.N(g)}b.$=null;this.Pa=c(this.Pa,this.ac.v||this.dc.v);this.Ra=c(this.Ra,this.Pa);this.ta.N(c(this.ta.v,this.ec.v||this.Ra));this.Qa.N(c(this.Qa.v,this.cc.v||this.ta.v));Ua=this.bc.v}b.Y=function(a){b.xa?a.N(b.xa.Oc[a.B]):(b.$||(b.$={}),b.$[a.B]=a);return a};b.s=function(a,c){return b.Y(new Rc(a,c))};b.za=function(a,c){b.Y(new Sc(a,c))};b.Ea=function(a){b.Y(new Tc(a,void 0))};b.Hd=function(a,c){return b.Y(new Fb(a,
# c))};b.md=function(){b.Y(new Uc("virtualizeDomains",void 0))};b.prototype.Sc=function(a,c){c=eval("(function(){return "+c+";})()");for(var b=Object.keys(c),f=0;f<b.length;++f){var d=b[f];a[d]=c[d]}};b.prototype.Tc=function(a,c){c=c.split(",");for(var b=0;b<c.length;++b){var f=c[b].split(/=|:/);2===f.length?a[f[0].trim()]=f[1].trim():console.error("invalid config value "+c[b])}};b.prototype.Rc=function(a){var c=a.devJsExtraFlags;c&&c.trim()&&("{"===c[0]?this.Sc(a,c):this.Tc(a,c),a.devJsExtraFlags=
# "")};return b}(),z=z||wa(),J;(function(){for(var b=z.attributes.length-1;0<=b;b--);})();var Ha=new Ic;y(ba+".Init",function(b){$a||Yb(new Eb);if(null===b){var a=z.getAttribute("data-config");if("string"===typeof a){b=void 0;try{b=JSON.parse(a)}catch(f){b={}}}else return}y(ja+".CanRun",function(){return!1});y("IXC_175_8953684100313002.CanRun",function(){return!1});J=wa();ua(!!z&&!!J,"Invalid situation");if(Ha)if(a=Ha.Cc,Ha=null,b=new Gb(b),Gb.s("skipInit").v)console.warn("Init is skipped by skipInit flag");
# else for(var c=a.length,e=0;e<c;++e)a[e](b);else console.warn("No modules initialized.");$b()});var v;(function(b){b[b.PENDING=0]="PENDING";b[b.FULLFILLED=1]="FULLFILLED";b[b.REJECTED=2]="REJECTED"})(v||(v={}));var Wc=function(){function b(a){if(!a)throw"no executor provided";if("object"!==typeof this)throw"use new";if("function"!==typeof a)throw"not a function";this.state=v.ub;this.$b(a)}b.prototype.$b=function(a){var c=this;try{a(function(a){c.dd(a)},function(a){c.zb(a)})}catch(e){c.zb(e)}};b.prototype.dd=
# function(a){this.Lb&&this.Lb.call(this,a);this.state=v.Ta};b.prototype.zb=function(a){this.Ia&&this.Ia.call(this,a);this.state=v.xb};b.prototype.then=function(a,c){this.state===v.ub?(this.Ia=c,this.Lb=a):this.state===v.Ta?a.call(this,void 0):this.state===v.xb&&c.call(this,void 0);return new b(function(){})};b.prototype.catch=function(a){this.state===v.ub?this.Ia=a:this.state!==v.Ta&&this.state===v.xb&&a.call(this,void 0);return new b(function(){})};b.prototype.all=function(a){var c=Array.prototype.slice.call(a);
# return new b(function(a,b){function e(d,l){try{if(l&&("object"===typeof l||"function"===typeof l)){var g=l.then;if("function"===typeof g){g.call(l,function(c){e(d,c)},b);return}}c[d]=l;0===--f&&a(c)}catch(Vc){b(Vc)}}if(0===c.length)return a([]);for(var f=c.length,d=0;d<c.length;d++)e(d,c[d])})};return b}(),pa=function(b){function a(){var c=b.call(this)||this;c.Hb=!1;b.prototype.o.call(c,function(){});return c}h(a,b);a.prototype.ka=function(c){return function(){if(!this.Hb){for(var a=0,b=c.length;a<
# b;++a)c[a].apply(this,arguments);this.Hb=!0}}};return a}(aa),U=new pa,V=new pa,Ia=new pa,Ja=new pa,Ma=new t,Oa=new t,Na=new t,Pa=new t,X={},Qa,Xc=0===T.U.c||0===T.R.c||1===T.U.c&&(1===T.R.c||2===T.R.c),D=function(){function b(a){this.vb=a;this.Sa=Object.create(a&&a.Sa);this.Ka=this.Va=null;this.qb=new t;this.pb=new t}b.prototype.rc=function(a){return this.Sa[a]};b.prototype.Ya=function(a,c){for(var b;a&&!b;){if(b=Object.getOwnPropertyDescriptor(a,c))b.Ma=a;a=Object.getPrototypeOf(a)}return b};b.prototype.Bc=
# function(a,c){var b=c.B;if((a=this.Ya(a,b))&&a.value)return c.fa(a.value),a.Ma[b]=c.H,c.A=a.writable?1:5,a.writable;c.A=3;return!1};b.prototype.Ac=function(a,c){var b=c.B;if(a=this.Ya(a,b)){a.get&&(c.J.fa(a.get),a.get=c.J.H);a.set&&(c.Set.fa(a.set),a.set=c.Set.H);if(a.get||a.set)return Q(a.Ma,b,a),c.A=a.configurable?1:4,a.configurable;a.hasOwnProperty("get")||a.hasOwnProperty("set")?(c.J.fa(function(){var c=Object.getOwnPropertyDescriptor(this,b);if(c){delete this[b];var a=this[b];Q(this,b,c);return a}return this[b]}),
# c.Set.fa(function(c){var a=Object.getOwnPropertyDescriptor(this,b);return a?(delete this[b],this[b]=c,Q(this,b,a),c):this[b]=c}),c.A=7):c.A=6;return!1}c.A=3;return Xc||E()||Sa()||Y()||Ta()};b.prototype.P=function(a,c,b){if(c){for(var e=[],d=c.length-1;0<=d;--d){var g=c[d];2===g.A||this.Bc(a,g)||3===g.A||e.push(g)}e.length&&(this.Va=e)}if(b){c=[];for(d=b.length-1;0<=d;--d)e=b[d],2===e.A||this.Ac(a,e)||3===e.A||c.push(e);c.length&&(this.Ka=c)}};b.prototype.fb=function(a){this.qb&&this.qb.b(a);var c=
# this.Va;if(c)for(var b=c.length-1;0<=b;--b){var d=c[b];Q(a,d.B,{value:d.H,configurable:!0,enumerable:!0})}if(c=this.Ka)for(b=c.length-1;0<=b;--b)d=c[b],Q(a,d.B,{get:d.J.H,set:d.Set.H,configurable:!0,enumerable:!0});this.pb&&this.pb.b(a);this.vb&&this.vb.fb(a)};return b}(),cb=[],xa={},bc=0,ac=Object.prototype.hasOwnProperty,db={enumerable:!1,writable:!1},Hb=function(){return function(b){this.B=b;this.A=0}}(),Yc=function(b){function a(){return null!==b&&b.apply(this,arguments)||this}h(a,b);a.prototype.ka=
# function(c){return function(){for(var a=!1,b=0,d=c.length;b<d;++b)a=c[b].apply(this,arguments)||a;return a}};return a}(t);(function(b){function a(){return null!==b&&b.apply(this,arguments)||this}h(a,b);a.prototype.ka=function(a){return function(c){for(var b=0,e=a.length;b<e;++b)c=a[b].apply(this,arguments)||c;return c}};return a})(t);var k=function(b){function a(a,e){void 0===e&&(e=!1);var c=b.call(this,a)||this;c.H=e?function(){return ca(c.ua.apply(this,arguments))}:function(){return c.ua.apply(this,
# arguments)};return c}h(a,b);a.prototype.Ga=function(){var a=this.L&&this.L.$a(),b=this.ba&&this.ba.$a(),a=this.Z?a?b?7:5:b?6:4:a?b?3:1:b?2:0,b=this.ma&&this.ma[a];if(!b){var d=this;switch(a){case 0:b=this.D;break;case 1:b=function(){var a;d.L.b.apply(this,arguments)||(a=d.D.apply(this,arguments));return a};break;case 2:b=function(){var a=d.D.apply(this,arguments);return a=d.ba.b.call(this,a)||a};break;case 3:b=function(){var a;d.L.b.apply(this,arguments)||(a=d.D.apply(this,arguments),a=d.ba.b.call(this,
# a)||a);return a};break;case 4:b=this.Z;break;case 5:b=function(){var a;d.L.b.apply(this,arguments)||(a=d.Z.apply(this,arguments));return a};break;case 6:b=function(){var a=d.Z.apply(this,arguments);return a=d.ba.b.call(this,a)||a};break;case 7:b=function(){var a;d.L.b.apply(this,arguments)||(a=d.Z.apply(this,arguments),a=d.ba.b.call(this,a)||a);return a}}0!=a&&4!=a&&(this.ma||(this.ma=[]),this.ma[a]=b)}this.__=this.ua=b};a.prototype.fa=function(a){this.D=a;cc(a,this.H);this.H.toString=function(){return a.toString()};
# this.Ga()};a.prototype.pa=function(a){this.Z=a;this.Ga()};a.prototype.Xc=function(a){this.L||(this.L=new Yc);this.L.o(a);this.Ga()};return a}(Hb);(function(b){function a(a){var c=b.call(this,a,!0)||this;c.H=function(){var a;a=c.ua;switch(arguments.length){case 0:a=new a;break;case 1:a=new a(arguments[0]);break;case 2:a=new a(arguments[0],arguments[1]);break;case 3:a=new a(arguments[0],arguments[1],arguments[2]);break;case 4:a=new a(arguments[0],arguments[1],arguments[2],arguments[3]);break;default:throw"Unsupported case!";
# }return ca(a)};return c}h(a,b);return a})(k);var q=function(b){function a(a,d,f){void 0===d&&(d=!1);var c=b.call(this,a)||this;c.J=new k(a,d);c.Set=new k(a,d);f&&dc(c);return c}h(a,b);return a}(Hb),Ib=function(b){function a(a){var c=b.call(this,a,!1)||this;c.J.pa(function(){var a=da(this,c.B);return a&&(a=a.Wa(this))?a.Id:c.J.D.apply(this,arguments)});c.Set.pa(function(a){var b=da(this,c.B);return b?(b.Wa(this)||(b.Wa(this,!0,a),c.Set.D.call(this,null)),b.Set(this,a,!0,!1),a):c.Set.D.apply(this,arguments)});
# return c}h(a,b);return a}(q),Jb=new (function(b){function a(){return b.call(this,null)||this}h(a,b);return a}(D)),Zc=new (function(b){function a(){var a=b.call(this,Jb)||this;a.Nb=new k("addEventListener");a.bd=new k("removeEventListener");a.Zb=new k("dispatchEvent");a.P(Object.getPrototypeOf(d.document.head),[a.Nb,a.bd,a.Zb]);return a}h(a,b);return a}(D)),$c=new (function(b){function a(){var a=b.call(this,Zc)||this;a.ELEMENT_NODE=d.Node.ELEMENT_NODE;a.DOCUMENT_NODE=d.Node.DOCUMENT_NODE;a.yc=new k("insertBefore",
# !0);a.Qb=new k("appendChild",!0);a.cd=new k("replaceChild",!0);a.Ub=new k("cloneNode",!0);a.ad=new k("removeChild",!0);a.Fc=new q("nodeValue");a.od=new q("textContent");a.P(Object.getPrototypeOf(d.document.head),[a.yc,a.Qb,a.cd,a.Ub,a.ad],[a.Fc,a.od]);return a}h(a,b);return a}(D)),ad=new (function(b){function a(){var a=b.call(this,$c)||this;a.fc=new k("getAttribute");a.fd=new k("setAttribute");a.Yc=new k("removeAttribute");a.gc=new k("getAttributeNS");a.gd=new k("setAttributeNS");a.Zc=new k("removeAttributeNS");
# a.hc=new k("getAttributeNode",!0);a.hd=new k("setAttributeNode",!0);a.$c=new k("removeAttributeNode",!0);a.ic=new k("getAttributeNodeNS",!0);a.jd=new k("setAttributeNodeNS",!0);a.xc=new k("insertAdjacentHTML");a.Vc=new k("querySelector",!0);a.Wc=new k("querySelectorAll",!0);a.vd=new k("getElementById",!0);a.jc=new k("getElementsByClassName",!0);a.kc=new k("getElementsByTagName",!0);a.lc=new k("getElementsByTagNameNS",!0);a.Vb=new k("createShadowRoot",!0);a.wa=new q("id",!1,!0);a.Tb=new q("className");
# ...
# RegExp?(d[h].test(c[h])||"string"==typeof g.name&&d[h].test(g[h]))&&f++:(c[h]===d[h]||"string"==typeof g.name&&g[h]===d[h])&&f++;f==Object.keys(d).length&&e.push(g)})}),this._makeResult(e)};a.prototype.clear=function(){delete u[this.id()]._mset;var b=this;c.each(this.collections(),function(a,d){c.each(d.tests,function(a,d){b._deregisterVariant(d.name)})})};a.prototype.$handlers={applyClass:function(b,a,d){c.removeClass(this,"dw-not-loaded");c.addClass(this,"dw-"+a+"-"+d+"-"+b)}};a.prototype.applyClass=
# function(b,a,d){var c;c=a.split(".");a=c[0];c=c[1];var g=this.getVariant(a).is(c);a&&c&&(this.$handlers.applyClass.call(b,g,a,c),d&&d.call(b,g,a,c))};a.prototype.$plugins=a.prototype.$plugins||{};a.prototype.$plugins.add=function(b){return b="string"==typeof b?this.$dw.getVariant(b):b,this.$dw._makeResult(this._add(b,this)),this};a.prototype.$plugins.is=function(b){var a=!!this.length;return c.each(this,function(d,c){b&&b===c.name||(a=!1)}),a};a.prototype.$plugins.clear=function(b){var a=this.$dw;
# c.each(this,function(b,c){a._deregisterVariant(c.$tc.name)})};a.prototype.$plugins.has=function(b){var a=!1;return c.each(this,function(c,e){b&&b===e.name&&(a=!0)}),a};a.prototype.$plugins.toTrackVar=function(b,a,d){function e(b,d){if(d.trackvars){var e=[],g=b||(d.trackvars[0]?d.trackvars[0].name:"");return c.each(d.trackvars,function(b,a){k(g)===k(a.name)&&e.push(a.value)}),(e=e.join(f))&&(a?a+f:"")+e}}var g=this.$dw,h=[],f=d||g.trackValueDelimiter();return c.each(this,function(a,d){var c=e(b,d);
# c&&h.push(c)}),h.join(f)};a.prototype.$plugins.getTrackVar=a.prototype.$plugins.toTrackVar;a.prototype._deregisterVariant=function(b){b=f(b);this._removeLocalItem(b.name);this._removeLocalItem(b.visit);this._removeLocalItem(b.blacklisted);this._removeLocalItem(b.compute);this._removeLocalItem(b.hash);this._removeLocalItem(b.phash)};a.prototype._detectLocalStorage=function(){try{return this._setLocalItem("_adwi_","_adwi_"),this._removeLocalItem("_adwi_"),!0}catch(b){return!1}};a.prototype._isOptOut=
# function(){return"yes"==this._getLocalItem("Dw__OO")};a.prototype._removeLocalItem=function(b){b=[b,this.id()].join("|");localStorage.removeItem(b)};a.prototype._getLocalItem=function(b){b=[b,this.id()].join("|");try{return localStorage.getItem(b)}catch(a){return null}};a.prototype._setLocalItem=function(b,a){var d=[b,this.id()].join("|");this._getLocalItem(d)&&this._removeLocalItem(d);try{return localStorage.setItem(d,a)}catch(c){return r}};a.prototype.getTest=function(b){return this._testData[b]||
# new this.Test({},this)};a.prototype.visitor=function(){return this._visitor};a.prototype.Visitor=function(b,f){this.has=function(b){function e(b){b=b instanceof a.prototype.Variant?b.getTest():b||{};return"registered"==b.state||"persisted"==b.state}var g;return f&&b instanceof f?c.each(b.toArray(),function(b,a){if(!(g=e(a)))return!1}):g=e(b),g}};a.prototype.Variant=function(b,a){var c=b||{};this.nocollect=!c.collect;this.historic=c.historic||!1;this.run=c.run||!1;var e=c.variation||{};this.getTest=
# function(){return a.getTest(c.name)};this.name=e.name||"";this.trackvars=e.track||[];this.customOptions=e.customOptions||{}};a.prototype.Test=function(b,a){var c=b.name||"",e=f(c),g=b.increment||0,h=b.variations||[],m=b["x-persist"]||!1,l=b.blacklist&&b.blacklist.referrers||[],p="yes"==a._getLocalItem(e.blacklisted),k=t(b,"segment");this._originalData=b;this.data=function(b,a){if(a==r)return this._originalData[b];this._originalData[b]=a};this.getToolkit=function(){return a};var u=C(k);this.segments=
# k?u.match:[];k=!!k&&u.value;p||a._getLocalItem(e.blacklisted)||(p=a._isBlacklisted(l)||!k,a._setLocalItem(e.blacklisted,p?"yes":"no"));e=!!h.length;g=h.length&&new a.Variant(a._registerVariant(c,h,p,g,k,m),a);this.name=c;e&&b.active&&!g.nocollect&&(this.variation=g);h=e&&b.active?b.defaultTrack:[];p&&Array.prototype.push.apply(h,b.blacklist?b.blacklist.track:[]);(h.length&&g.nocollect||!e||!g||!k)&&(this.variation=new a.Variant({name:c,variation:{track:k?h:[]}},a));e&&g&&k?g&&g.run?this.state="registered":
# this.state="persisted":(a._deregisterVariant(c),this.state="deregistered")};a.prototype._registerVariant=function(b,a,d,e,g,h){var k=f(b);e=h?w(b,[],!1,e):w(b,a,d,e);var m=h?this._getLocalItem(k.phash):this._getLocalItem(k.hash),l=this._getLocalItem(k.name);h="yes"==this._getLocalItem(k.visit);var p="yes"==this._getLocalItem(k.compute),t=function(a,b){a=parseFloat(a.customOptions.target);b=parseFloat(b.customOptions.target);return a<b?-1:a>b?1:0},r=u[this.id()],q=x(a,"name",l);if(g=!(!g||(p||d||"string"==
# typeof l||q)&&(!p||e==m)))if(r._mset&&r._mset[b])c.each(a,function(a,c){r._mset[b][c.name]&&(q=c)});else{a.sort(t);var A=[],y=0,z=0;c.each(a,function(a,b){var c=b.customOptions&&b.customOptions.target;if(c){c=parseFloat(c)/100;y+=c;var d={value:[z,y]};z+=c;A.push(d)}});var B=Math.random(0,1);c.each(A,function(a,b){B>=b.value[0]&&B<=b.value[1]&&(l=a)});q=a[l]}q?this._setLocalItem(k.name,q.name):this._setLocalItem(k.name,"_default");this._setLocalItem(k.visit,"yes");this._setLocalItem(k.compute,"yes");
# this._setLocalItem(k.hash,e);this._setLocalItem(k.phash,e);a=q&&(!d||h)&&{name:b,variation:q,collect:!0};return a||(a={name:b}),a.run=g,a};a.prototype._isBlacklisted=function(a){var f;a=a||[];return this._ignoreBlacklist||c.each(a,function(a,b){var c=new RegExp("^(http://)?(www\\.)?"+b.replace(/\./g,"\\.").replace(/\-/g,"\\-"),"gi");return!(f=!b&&!document.referrer||0<(b&&document.referrer.match(c)||[]).length)}),f};m("darwin-toolkit:v2.0.0",function(){return!0});l._dw.push=function(a){u[a[0]]?(u[a[0]]._dispatches[a[1]]&&
# a[2]&&a[2](u[a[0]]),u[a[0]]._handlers.push(a.slice(1,a.length))):(p[a[0]]||(p[a[0]]=[]),p[a[0]].push(a.slice(1,a.length)))};l._dw})(VisitorSegment,this);(function(m){m=new m("global");m.config({trackValueDelimiter:",",deferSegments:!1,collections:[{name:"recommendation",disabled:!1,tests:[{name:"recommendation-influencersexperiments",active:!0,"x-persist":!0,"x-status":"1",increment:0,segment:{},_token:"e3d87a",variations:[{customOptions:{target:"50"},name:"influencers",track:[{name:"list1",dynamic:!1,
# value:"recommendation-influencersexperiments:influencers"},{name:"prop56",dynamic:!1,value:"recommendation-influencersexperiments:influencers"},{name:"list1",dynamic:!1,value:"recommendation-influencersexperiments-e3d87a"},{name:"prop56",dynamic:!1,value:"recommendation-influencersexperiments-e3d87a"}]}],defaultTrack:[{name:"list1",dynamic:!1,value:"recommendation-influencersexperiments:default"},{name:"prop56",dynamic:!1,value:"recommendation-influencersexperiments:default"},{name:"list1",dynamic:!1,
# value:"recommendation-influencersexperiments-e3d87a"},{name:"prop56",dynamic:!1,value:"recommendation-influencersexperiments-e3d87a"}]}]},{name:"article",disabled:!0,tests:[{name:"article-breakingnews",active:!1,"x-persist":!0,"x-status":"1","x-linked":"0",increment:0,segment:{desktop:!0},_token:"3d7545",variations:[{customOptions:{target:"34"},name:"nobreakingnews",track:[{name:"list1",dynamic:!1,value:"article-breakingnews:nobreakingnews"},{name:"prop56",dynamic:!1,value:"article-breakingnews:nobreakingnews"},
# {name:"list1",dynamic:!1,value:"article-breakingnews-3d7545"},{name:"prop56",dynamic:!1,value:"article-breakingnews-3d7545"}]},{customOptions:{target:"33"},name:"sectionbreakingnews",track:[{name:"list1",dynamic:!1,value:"article-breakingnews:sectionbreakingnews"},{name:"prop56",dynamic:!1,value:"article-breakingnews:sectionbreakingnews"},{name:"list1",dynamic:!1,value:"article-breakingnews-3d7545"},{name:"prop56",dynamic:!1,value:"article-breakingnews-3d7545"}]},{customOptions:{target:"33"},name:"allbreakingnews",
# track:[{name:"list1",dynamic:!1,value:"article-breakingnews:allbreakingnews"},{name:"prop56",dynamic:!1,value:"article-breakingnews:allbreakingnews"},{name:"list1",dynamic:!1,value:"article-breakingnews-3d7545"},{name:"prop56",dynamic:!1,value:"article-breakingnews-3d7545"}]}],defaultTrack:[{name:"list1",dynamic:!1,value:"article-breakingnews:default"},{name:"prop56",dynamic:!1,value:"article-breakingnews:default"},{name:"list1",dynamic:!1,value:"article-breakingnews-3d7545"},{name:"prop56",dynamic:!1,
# value:"article-breakingnews-3d7545"}]},{name:"article-curatedContent",active:!1,"x-persist":!0,"x-status":"1","x-linked":"0",increment:1,segment:{},_token:"7d2dac",variations:[{customOptions:{target:"25"},name:"enabledhpfirst",track:[{name:"list1",dynamic:!1,value:"article-curatedContent:enabledhpfirst"},{name:"prop56",dynamic:!1,value:"article-curatedContent:enabledhpfirst"},{name:"list1",dynamic:!1,value:"article-curatedContent-7d2dac"},{name:"prop56",dynamic:!1,value:"article-curatedContent-7d2dac"}]},
# {customOptions:{target:"25"},name:"enabledprfirst",track:[{name:"list1",dynamic:!1,value:"article-curatedContent:enabledprfirst"},{name:"prop56",dynamic:!1,value:"article-curatedContent:enabledprfirst"},{name:"list1",dynamic:!1,value:"article-curatedContent-7d2dac"},{name:"prop56",dynamic:!1,value:"article-curatedContent-7d2dac"}]},{customOptions:{target:"25"},name:"enabledhponly",track:[{name:"list1",dynamic:!1,value:"article-curatedContent:enabledhponly"},{name:"prop56",dynamic:!1,value:"article-curatedContent:enabledhponly"},
# {name:"list1",dynamic:!1,value:"article-curatedContent-7d2dac"},{name:"prop56",dynamic:!1,value:"article-curatedContent-7d2dac"}]}],defaultTrack:[{name:"list1",dynamic:!1,value:"article-curatedContent:default"},{name:"prop56",dynamic:!1,value:"article-curatedContent:default"},{name:"list1",dynamic:!1,value:"article-curatedContent-7d2dac"},{name:"prop56",dynamic:!1,value:"article-curatedContent-7d2dac"}]}]},{name:"modal",disabled:!1,tests:[{name:"modal-adblock_v1",active:!0,"x-persist":!0,"x-status":"1",
# "x-linked":"0",increment:2,segment:{adblock_generic:!0},_token:"55ca44",variations:[{customOptions:{target:"90"},name:"enabled",track:[{name:"list1",dynamic:!1,value:"modal-adblock_v1:enabled"},{name:"prop56",dynamic:!1,value:"modal-adblock_v1:enabled"},{name:"list1",dynamic:!1,value:"modal-adblock_v1-55ca44"},{name:"prop56",dynamic:!1,value:"modal-adblock_v1-55ca44"}]}],defaultTrack:[{name:"list1",dynamic:!1,value:"modal-adblock_v1:default"},{name:"prop56",dynamic:!1,value:"modal-adblock_v1:default"},
# {name:"list1",dynamic:!1,value:"modal-adblock_v1-55ca44"},{name:"prop56",dynamic:!1,value:"modal-adblock_v1-55ca44"}]}]},{name:"video",disabled:!1,tests:[{name:"video-adtimeout",active:!0,"x-persist":!0,"x-status":"1","x-linked":"0",increment:0,segment:{},_token:"ca9b46",variations:[{customOptions:{target:"10"},name:"eightSecond",track:[{name:"list1",dynamic:!1,value:"video-adtimeout:eightSecond"},{name:"prop56",dynamic:!1,value:"video-adtimeout:eightSecond"},{name:"list1",dynamic:!1,value:"video-adtimeout-ca9b46"},
# {name:"prop56",dynamic:!1,value:"video-adtimeout-ca9b46"}]}],defaultTrack:[{name:"list1",dynamic:!1,value:"video-adtimeout:default"},{name:"prop56",dynamic:!1,value:"video-adtimeout:default"},{name:"list1",dynamic:!1,value:"video-adtimeout-ca9b46"},{name:"prop56",dynamic:!1,value:"video-adtimeout-ca9b46"}]}]},{name:"upgrade",disabled:!1,tests:[{name:"upgrade-toolkit_v110",active:!0,"x-persist":!0,"x-status":"1","x-linked":"0",increment:0,segment:{},_token:"fe334d",variations:[{customOptions:{target:"25"},
# name:"variant_1",track:[{name:"list1",dynamic:!1,value:"upgrade-toolkit_v110:variant_1"},{name:"prop56",dynamic:!1,value:"upgrade-toolkit_v110:variant_1"},{name:"list1",dynamic:!1,value:"upgrade-toolkit_v110-fe334d"},{name:"prop56",dynamic:!1,value:"upgrade-toolkit_v110-fe334d"}]}],defaultTrack:[{name:"list1",dynamic:!1,value:"upgrade-toolkit_v110:default"},{name:"prop56",dynamic:!1,value:"upgrade-toolkit_v110:default"},{name:"list1",dynamic:!1,value:"upgrade-toolkit_v110-fe334d"},{name:"prop56",
# dynamic:!1,value:"upgrade-toolkit_v110-fe334d"}]}]}]});this.__dwCallback__?this.__dwCallback__(m):m.init()})(this._dw)}();</script> </div> </div> <div class="moat-trackable pb-f-theme-normal pb-f-dehydrate-false full pb-feature pb-layout-item pb-f-posttv-player" data-chain-name="no-name" data-feature-id="posttv/player" data-feature-name="no-name" data-pb-fingerprint="0fQbyEaIOpT" id="f0bFz5SocOndnq" moat-id="posttv/player|world"> </div> <div class="pb-container"> </div></section> <div class="pb-container"> </div></div> <script>window.pageBuilder&&window.pageBuilder.initVariants&&window.pageBuilder.initVariants({IS_ADMIN:!1,TIMEOUT:wp_pb.banditoEnv.TIMEOUT,PERF_API:wp_pb.banditoEnv.PERF_API,TESTS_API:wp_pb.banditoEnv.TESTS_API,EVENTS_API:wp_pb.banditoEnv.EVENTS_API});</script> <script>console.time("hi-pri-js");</script> <script src="/pb/gr/c/default/r0pDNIUocOndnq/hi-pri-js/e7f066f51e.js?_=72a89"></script> <script src="/pb/gr/p/default/r0pDNIUocOndnq/hi-pri-render.js?_=5b7b1"></script> <script>console.timeEnd("hi-pri-js");</script> <script>window.TWPHead.ready("main.js",function(){window.TWP&&TWP.Analytics&&TWP.Analytics.init({trackScrolling:{omniture:!1},snowflake:!0,suppressTrackPageLoad:wp_pb.StaticMethods.isPageHydrated()?!1:!0})});</script> <noscript><img src="https://sb.scorecardresearch.com/p?c1=2&amp;c2=3005617&amp;cv=2.0&amp;cj=1"/></noscript> <noscript><img alt="" src="//me.effectivemeasure.net/em_image" style="position:absolute; left:-5px;"/></noscript> <script>console.time("js");</script> <script src="/pb/gr/c/default/r0pDNIUocOndnq/js/46707ff31b.js?_=a69b2"></script> <script src="//js.washingtonpost.com/video/resources/js/posttv/vendor/underscore-min.js"></script> <script src="//js.washingtonpost.com/video/resources/env/WapoVideo/dist/WapoVideoEmbed.min.js"></script> <script>console.timeEnd("js");</script> <script>console.time("render.js");</script> <script src="/pb/gr/p/default/r0pDNIUocOndnq/render.js?_=5b7b1"></script> <script>console.timeEnd("render.js");</script> <script>console.time("instance.js");</script> <script src="/pb/gr/p/default/r0pDNIUocOndnq/instance.js?_=5b7b1"></script> <script>console.timeEnd("instance.js");</script> <script>console.time("after_features");</script> <script src="/pb/gr/c/default/r0pDNIUocOndnq/after_features/faf77027df.js?_=374bc"></script> <script>console.timeEnd("after_features");</script> <script>console.time("content_type_article");</script> <script>console.timeEnd("content_type_article");</script> <script>console.time("third_party");</script> <script>console.timeEnd("third_party");</script> <script>(function(){"__twpCookieMonster__"in document&&document.__twpCookieMonster__.ommNom()})();</script> <script>jQuery(function(){function a(){try{var a=$(".tweet-authors");!a.length||window.twttr&&twttr.widgets||$.ajax({dataType:"script",cache:!0,url:"//platform.twitter.com/widgets.js",success:function(b){a.find(".pb-twitter-follow.unprocessed").removeClass("unprocessed")}});$.ajax({dataType:"script",cache:!0,url:"//ak.sail-horizon.com/horizon/v1.js",success:function(a){window.Sailthru&&Sailthru.setup({domain:"horizon.washingtonpost.com"})}})}catch(c){}}wp_pb.StaticMethods.isPageHydrated()&&a();__e.push(["shamble:end",
# function(){a()}])});</script> <script>jQuery(function(){try{$("body").append('\x3cimg src\x3d"https://amplifypixel.outbrain.com/pixel?mid\x3d00bb70a80ee8f020d9011cbcef307fe64d"\x3e')}catch(a){}});</script> <script>!function(){if(!(99<Math.floor(100*Math.random()))){var c,b,d,a=document.createElement("iframe");a.src="javascript:false";(a.frameElement||a).style.cssText="width: 0; height: 0; border: 0";d=document.getElementsByTagName("script")[0];d.parentNode.insertBefore(a,d);try{b=a.contentWindow.document}catch(e){c=document.domain,a.src="javascript:var d\x3ddocument.open();d.domain\x3d'"+c+"';void(0);",b=a.contentWindow.document}b.open()._l=function(){var a=this.createElement("script");c&&(this.domain=c);a.id=
# "boomr-if-as";a.src="//www.washingtonpost.com/wp-stat/rum/wprum.min.js";this.body.appendChild(a)};b.write('\x3cbody onload\x3d"document._l();"\x3e');b.close()}}();</script> <script>ResourceBundle.processInlineScripts();</script> </body> </html>

# %% [markdown]
# ###### Usually all the text in the Washington post is enclosed in the article tag. so we are returning the article

# %%
soup.find('Article')
soup
# Out:
# <!DOCTYPE html>
# <html class="article layout_article rendering-context-www" itemscope="" itemtype="http://schema.org/NewsArticle" lang="en"> <head> <script id="_$cookiemonster">(function(b,m){function d(b,d){this.wl={map:f.map.concat(b||[]),reg:f.reg.concat(d||[])}}var f={reg:[],map:[]};d.prototype.ommNom=function(){return this.nom(!0,void 0)};d.prototype.allows=function(b){return!(-1<this.nom(!1,[b]).indexOf(b))};d.prototype.nom=function(d,f){for(var c=[],l=b.location.hostname.split("").reverse().join("").slice(0,18),g=f||b.cookie.split(";"),a,h,e=0;e<g.length,a=g[e];e++)a=a.trim().split("\x3d")[0].toLowerCase(),-1<this.wl.map.indexOf(a)||c.push(a);for(var k=0;k<this.wl.reg.length,
# h=this.wl.reg[k];k++)for(e=h.lastIndex=0;e<g.length,a=g[e];e++)a=a.trim().split("\x3d")[0].toLowerCase(),h.test(a)?-1<c.indexOf(a)&&c.splice(c.indexOf(a),1):0>c.indexOf(a)&&0>this.wl.map.indexOf(a)&&c.push(a);d&&("moc.tsopnotgnihsaw"==l&&(this.wl.reg.length||this.wl.map.length)?setTimeout(function(a){return function(){for(var a=0;a<c.length;a++)b.cookie=c[a]+"\x3d; expires\x3dThu, 01 Jan 1970 00:00:01 GMT; path\x3d/; domain\x3dwww.washingtonpost.com",b.cookie=c[a]+"\x3d; expires\x3dThu, 01 Jan 1970 00:00:01 GMT; path\x3d/; domain\x3d.washingtonpost.com",
# b.cookie=c[a]+"\x3d; expires\x3dThu, 01 Jan 1970 00:00:01 GMT; path\x3d/; domain\x3d"}}(this),0):console.error("[cookie-monster] Cowardly refusing to delete cookies on "+b.location.hostname,c));return c};return b.__CookieMonster__=d})(document);</script> <script>console.time("header-start");</script> <script>var TWP_Debug=window.TWP_Debug||{};TWP_Debug.initialTime=new Date;window.pageBuilder=window.pageBuilder||{};window.pageBuilder.loadAsyncFeatures=function(){__e=window.__e||[];__e.push(["lazy-scroll",function(){var b=window.document.getElementsByClassName("pb-async");[].slice.call(b).map(function(a){return a.id}).forEach(function(a){window.pageBuilder.loadAsyncFeature(a)})}])};window.pageBuilder.featureLoaded=function(){$(window.document).trigger("dom-manipulation-complete")};</script> <meta content="4e9e8fbe-5bd5-11e7-8e2f-ef443171f6bd" name="eomportal-uuid"/> <meta content="1498678244" name="object-hash"/> <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/> <meta charset="utf-8"/> <meta content="width=device-width, initial-scale=1.0, user-scalable=yes, minimum-scale=0.5, maximum-scale=2.0" id="viewport" name="viewport"/> <meta content="unsafe-url" name="referrer"/> <meta content="ukraine, ransomware, cyberattack, ukraine cyber, ukraine ransomware, bitcoin, rosneft, pavlo rozenko, Kaspersky labs, Petya, Maersk, worldwide cybarattack" name="keywords"/> <meta content="ukraine, ransomware, cyberattack, ukraine cyber, ukraine ransomware, bitcoin, rosneft, pavlo rozenko, Kaspersky labs, Petya, Maersk, worldwide cybarattack" name="news_keywords"/> <meta name="twitter:site" value="@WashingtonPost"/> <meta content="summary_large_image" name="twitter:card"/> <meta content="article" property="og:type"/> <meta content="Washington Post" property="og:site_name"/> <meta content="True" itemprop="mainEntityOfPage"/> <meta content="https://www.facebook.com/washingtonpost" property="article:publisher"/> <meta content="1513210492" property="fb:admins"/> <meta content="41245586762" property="fb:app_id"/> <meta content="1244584375" property="fb:admins"/> <meta content="4403963" property="fb:admins"/> <meta content="2724956" property="fb:admins"/> <meta content="500835072" property="fb:admins"/> <link href="/pb/resources/json/desktop-notifications-manifest.json" rel="manifest"/> <title>Companies struggle to recover after massive cyberattack with ransom demands - The Washington Post</title> <link href="https://www.washingtonpost.com/world/europe/companies-struggle-to-recover-after-massive-cyberattack-with-ransom-demands/2017/06/28/4e9e8fbe-5bd5-11e7-8e2f-ef443171f6bd_story.html" itemprop="url" rel="canonical"/> <meta content="https://www.washingtonpost.com/world/europe/companies-struggle-to-recover-after-massive-cyberattack-with-ransom-demands/2017/06/28/4e9e8fbe-5bd5-11e7-8e2f-ef443171f6bd_story.html" property="og:url"/> <meta content="https://img.washingtonpost.com/rf/image_1484w/2010-2019/WashingtonPost/2017/06/28/Foreign/Images/2017-06-28T023423Z_1888700886_RC17E8D8BE10_RTRMADP_3_CYBER-ATTACK-MAERSK.jpg?t=20170517" itemprop="image" property="og:image"/> <meta content="Companies struggle to recover after massive cyberattack with ransom demands" property="og:title"/> <meta content="Systems as far afield as Asia were hit, but the epicenter of the outbreak was in Ukraine." itemprop="description" name="description"/> <meta content="Systems as far afield as Asia were hit, but the epicenter of the outbreak was in Ukraine." property="og:description"/> <meta content="index,follow" name="robots"/> <meta content="normal" name="theme"/> <meta content="" name="audio_url"/> <link href="https://www.washingtonpost.com/amphtml/world/europe/companies-struggle-to-recover-after-massive-cyberattack-with-ransom-demands/2017/06/28/4e9e8fbe-5bd5-11e7-8e2f-ef443171f6bd_story.html" rel="amphtml"/> <link href="android-app://com.washingtonpost.rainbow/wp-android-rainbow/www.washingtonpost.com/world/europe/companies-struggle-to-recover-after-massive-cyberatt ...
# (function(){try{wp_meta_data=window.wp_meta_data||{},wp_meta_data.platform="pagebuilder","isPageInitiallyHydrated"in wp_meta_data||(wp_meta_data.isPageInitiallyHydrated=!0),wp_meta_data.showAds=!0,wp_meta_data.isPWA=!1,wp_meta_data.showPreRollAds=!1,wp_meta_data.isHomepage=!1,wp_meta_data.isErrorPage=!1,wp_meta_data.isMultimedia=!1,wp_meta_data.wt="article_story",delete wp_meta_data.facet,delete wp_meta_data.contentName,delete wp_meta_data.contentLength,wp_meta_data.page_id=["4e9e8fbe-5bd5-11e7-8e2f-ef443171f6bd"],
# wp_meta_data.author=["David Filipov","Andrew Roth","Ellen Nakashima"],wp_meta_data.keywords="ukraine;ransomware;cyberattack;ukraine cyber;ukraine ransomware;bitcoin;rosneft;pavlo rozenko;Kaspersky labs;Petya;Maersk;worldwide cybarattack".split(";"),wp_meta_data.clavis=wp_meta_data.clavis||{},wp_meta_data.clavis.keywords=[],wp_meta_data.clavis.topics=[],wp_meta_data.clavis.ct=[],delete wp_meta_data.destinations,wp_meta_data.hot_topic=[!1],delete wp_meta_data.subjects,delete wp_meta_data.category,delete wp_meta_data.people_names,
# delete wp_meta_data.people_positions,delete wp_meta_data.organization_names,delete wp_meta_data.coverage_industrys,delete wp_meta_data.ideology,delete wp_meta_data.addresses,delete wp_meta_data.neighborhoods,delete wp_meta_data.zip_codes,delete wp_meta_data.counties,delete wp_meta_data.venues,delete wp_meta_data.cities,delete wp_meta_data.states,delete wp_meta_data.countries,delete wp_meta_data.breaking_news,wp_meta_data.contentType=["article"]}catch(a){}})();</script> <script>window.wpAd={inventory:{interstitial:{size:[],keyvalues:{ad:"interstitial"}},leaderboard:{size:[[728,90],[970,66],[970,250]],keyvalues:{pos:"leaderboard"}},inline_bb:{size:[[300,250],"fluid"],sizeOnCondition:{windowWidth:1250,size:[620,250]}},"inline_bb_*":{size:[[300,250],"fluid"],sizeOnCondition:{windowWidth:1250,size:[620,250]}},flex_ss_bb_hp:{size:[[336,850],[336,280],[160,600],[300,250],[300,600],[300,1050]]},"flex_ss_bb_hp_*":{size:[[336,850],[336,280],[160,600],[300,250],[300,600],[300,1050]]},
# flex_bb_hp:{size:[[336,850],[336,280],[300,600],[300,1050],[300,250]]},tiffany_tile:{size:[[200,60],[184,90]],keyvalues:{ad:["tiffany_tile"]}},"tiffany_tile_*":{size:[[200,60],[184,90]]},brandconnect_front:{size:[[1,8],"fluid"]},bc_pb_homepage:{size:[[1,8],"fluid"]},"336x60":{size:[[336,60]],keyvalues:{ad:["336x60"]}},"336x35_top":{size:[[336,35]],keyvalues:{ad:["336x35"]}},marketing_2:{size:[[1,1]]},marketwatch:{size:[[1,1]]},"88x31":{size:[[88,31]]},bigbox_gallery:{size:[[300,250]]},mob_bigbox:{size:[[300,
# 250],[300,600],"fluid"]},"mob_bigbox_*":{size:[[300,250],"fluid"]},fixedBottom:{size:[[320,50],[300,50]]},pushdown:{size:[[1,1],[970,66],[970,90],[728,90],[970,250]]},bc_bigbox:{size:[[300,250]]},polly_article:{size:[[1,1]]}},exclusionsKeyWords:{natural_disaster:"deepwater;oil spill;shell;exxon;citgo;bp;chevron;hess;sunoco;disaster;fire;explosion;oil;coal;death;dead;quake;earthquake;tsunami;tornado;hurricane;flood;bed bug;infestation;gas".split(";"),human_disaster:"oreilly;Ailes;o'reilly;fox news;abuse;death;trafficking;dead;gunshot;murderer;porn;sex tape;sexting;sexual abuse;molestation;assault;child abuse;sex abuse;ISIS;ISIL;Islamic State;Al Qaeda;Syria;Syrian;Assad;shooter;shooting;migrants;aylan kurdi;refugee crisis;drown;shoot;vatican;spanair;aground;rescue;attack;disaster;explosion;war;hostage;terror;terrorist;bomb;blast;mining;miner;violence;riot;crash;9/11;sept. 11;september 11;behead;United 93;pistorius;ebola;rape;rapist;amtrak;derailment;benghazi;misconduct".split(";"),
# financial_crisis:"corrupt;lawsuit;goldman;aig;foreclosure;enron;sec;mortgage;Insurance;health;bank;wall street;protest;labor strike;union strike;labor issue;union issue;teacher strike;teachers strike;election".split(";"),inappropriate:"porn deepwater gambling sex alcohol pornography".split(" ")},posOnCommericalNode:{"washingtonpost.com":{pos:{leaderboard:{start:"06/17/2017 00:00 EDT",end:"06/17/2017 23:59 EDT"},flex_bb_hp:{start:"06/14/2017 00:00 EDT",end:"12/31/2017 23:59 EDT"},tiffany_tile:{start:"05/24/2017 00:00 EDT",
# end:"12/31/2017 23:59 EDT"},tiffany_tile_2:{start:"05/24/2017 00:00 EDT",end:"12/31/2017 23:59 EDT"},marketwatch:!1,pushdown:{start:"06/21/2017 00:00 EDT",end:"06/22/2017 23:59 EDT"}}}}};</script> <script async="" src="https://www.washingtonpost.com/wp-stat/ad/zeus/wp-ad.min.js"></script> <script>window.console&&console.log&&console.log("["+(new Date-TWP_Debug.initialTime)/1E3+"] STARTING load_immediately");</script> <script>console.time("load_immediately");</script> <script src="/pb/gr/c/default/r0pDNIUocOndnq/load_immediately/4697e08d36.js?_=e1bf8"></script> <script>console.timeEnd("load_immediately");</script> <script>wp_import.valor(!0);</script> <script>window.wp_pb=window.wp_pb||{};wp_pb.banditoEnv={TIMEOUT:2500,PERF_API:"https://loxodo-ct.ext.nile.works/api/save-perf",TESTS_API:"https://www.washingtonpost.com/bandito/tests-pb/",EVENTS_API:"https://loxodo-ct.ext.nile.works/api/save-event"};</script> <script>window.head_conf={head:"TWPHead"};</script> <script>console.time("head.min.js");</script> <script src="/pb/resources/js/head.min.js"></script> <script>console.timeEnd("head.min.js");</script> <script>console.time("global");</script> <script src="/pb/gr/c/default/r0pDNIUocOndnq/global/ecae3e7968.js?_=b9e93"></script> <script>console.timeEnd("global");</script> <script>console.time("headjs");</script> <script src="/pb/gr/c/default/r0pDNIUocOndnq/headjs/8bb9d8351d.js?_=69d73"></script> <script>console.timeEnd("headjs");</script> <script>console.time("head.js");</script> <script src="/pb/gr/p/default/r0pDNIUocOndnq/head.js?_=5b7b1"></script> <script>console.timeEnd("head.js");</script> <script>console.time("exec-header-tracking");</script> <script>(function(){TWP="undefined"==typeof TWP?{}:TWP;TWP.Data="undefined"==typeof TWP.Data?{}:TWP.Data;TWP.Data.Tracking={init:function(){this.props={};this.props.platform="pagebuilder";this.props.site="www.washingtonpost.com";this.props.page_type="";this.props.page_name="world:article - ef443171f6bd - 20170628 - companies-struggle-to-recover-after-massive-cyberattack-with-ransom-demands";this.props.section="world";this.props.channel="wp - world";this.props.subsection="world - europe";this.props.hierarchy=
# "world|europe|article";this.props.content_type="article";this.props.story_type="";this.props.headline="Companies struggle to recover after massive cyberattack with ransom demands";this.props.author="David Filipov; Andrew Roth; Ellen Nakashima";this.props.source="The Washington Post";this.props.content_id="4e9e8fbe-5bd5-11e7-8e2f-ef443171f6bd";this.props.page_num="";this.props.columnname="";this.props.blogname="";this.props.published="";this.props.news_or_commercial="News";this.props.commercial_node=
# "/world/europe";this.props.content_category="Foreign";this.props.sectionfront="";this.props.track_scrolling=!0}};TWP.Data.Tracking.init()})();</script> <script>console.timeEnd("exec-header-tracking");</script> <script>console.time("exec-header-review");</script> <script>console.timeEnd("exec-header-review");</script> <script>console.time("exec-header-abtest");</script> <script>console.timeEnd("exec-header-abtest");</script> <script>window.console&&console.log&&console.log("["+(new Date-TWP_Debug.initialTime)/1E3+"] STARTING exec-twp-global");</script> <script>console.time("exec-twp-global");</script> <script>(function(b){var a=[];a.push("//www.washingtonpost.com/pb/gr/c/default/r0pDNIUocOndnq/conf-production/b5411285f6.js?_\x3d81d55");a.push("//www.washingtonpost.com/pb/gr/c/default/r0pDNIUocOndnq/modal-css/938c258067.css?_\x3d874d9");a.push("//www.washingtonpost.com/pb/gr/c/default/r0pDNIUocOndnq/identity-management/da39a3ee5e.js?_\x3d21843");a.push("https://www.washingtonpost.com/wp-stat/pwapi/prod/wpPwapi1-min.js?token\x3d201706011309EST");a.push("//www.washingtonpost.com/pb/gr/c/default/r0pDNIUocOndnq/identity-management/c4d7fa1f35.js?_\x3d21843");
# a.push("//www.washingtonpost.com/pb/gr/c/default/r0pDNIUocOndnq/wapo-production/8f8c39c9d8.js?_\x3dbee5a");a.push("//www.washingtonpost.com/wp-stat/analytics/latest/main.js?token\x3d201706271439EST");a.push("//www.washingtonpost.com/wp-stat/advertising/pseudo-static/identity-retargeting.js");"undefined"===typeof b.jqm&&a.unshift("//www.washingtonpost.com/pb/gr/c/default/r0pDNIUocOndnq/jqmodal/7a5b554023.js?_\x3da9337");"undefined"===typeof b.cookie&&a.unshift("//www.washingtonpost.com/pb/gr/c/default/r0pDNIUocOndnq/jquery-cookie/4cc3c1bef0.js?_\x3db8874");
# "undefined"===typeof jQuery&&a.unshift("//www.washingtonpost.com/pb/gr/c/default/r0pDNIUocOndnq/jquery/c85562b39d.js?_\x3db45ba");window.head_conf={head:"TWPHead"};console.time("ResourceBundle pb-r-identity");if("undefined"==typeof window.TWPHead){b=document.createElement("script");b.onload=b.onreadystatechange=function(){this.readyState&&"complete"!=this.readyState&&"loaded"!=this.readyState||TWPHead.load(a,function(){console.timeEnd("ResourceBundle pb-r-identity")})};b.src="//www.washingtonpost.com/pb/resources/js/head.min.js";
# var c=document.getElementsByTagName("script")[0];c.parentNode.insertBefore(b,c)}else TWPHead&&TWPHead.load(a,function(){console.timeEnd("ResourceBundle pb-r-identity")})})(jQuery);</script> <script>console.timeEnd("exec-twp-global");</script> </head> <body class="pb-theme-normal pb-full-fluid"> <div class="pub_300x250 pub_300x250m pub_728x90 text-ad textAd text_ad text_ads text-ads text-ad-links" id="wp-adb-c" style="width: 1px !important; height: 1px !important; position: absolute !important; left: -10000px !important; top: -1000px !important;"></div> <div id="pb-f-a"></div> <div class="" id="pb-root"><section class="col-xs-12 layout" id="top-furniture"> <div class="pb-container"> <div class="moat-trackable pb-f-theme-normal pb-f-dehydrate-false pb-1 pb-feature pb-layout-item pb-f-page-push-notifications" data-chain-name="no-name" data-feature-id="page/push-notifications" data-feature-name="no-name" data-pb-fingerprint="0fIsR8n9Wp7" id="f6V38Y1ocOndnq" moat-id="page/push-notifications|world"> <div class="notifications-container hidden"> <div class="pull-right notify-ic"> <i aria-hidden="true" class="fa fa-bell-o"></i> <span class="notif-number hide">2</span> </div> <div class="clear"> </div> <div class="notification-items hide"> <div class="notifications-top-arrow"></div> <div class="notifications-list"> </div> <div class="notifications-controll"> <p class="notify-txt">Desktop notifications are on   | <a class="turn-off" href="">Turn off</a> </p> </div> </div> <div class="permission-request hide"> <div class="notifications-top-arrow"></div> <p class="headline">Get breaking news alerts from <span class="wp-txt"> The Washington Post </span></p> <div class="permission-default"> <p class="notify-txt">Turn on desktop notifications?</p> <div class="actions-container"> <span class="notify-action yes">Yes</span> <span class="notify-action not-now">Not now</span> </div> </div> <div class="permission-denied hide"> <p class="notify-txt">It looks like you've previously blocked notifications. Please update your browser permissions to allow them.</p> <img class="permission-denied-img" src="/pb/resources/img/push_notifications/notification_denied_v1.png"/> </div> </div> </div> </div> </div> <div class="moat-trackable pb-f-theme-normal pb-f-dehydrate-false full pb-feature pb-layout-item pb-f-page-header-v2" data-chain-name="no-name" data-feature-id="page/header-v2" data-feature-name="no-name" data-pb-fingerprint="0fE2pbXsipa" id="f0Z6rqHocOndnq" moat-id="page/header-v2|world"> <!--[if IE 9]><style>#main-sections-nav.subNavigation{width:475px !important}#main-sections-nav{left:-250px !important;width:315px !important}#main-sections-nav-inner{position:absolute !important}#main-sections-nav.subNavigation #main-sections-nav-inner{width:550px !important;overflow-x:hidden !important}#main-sections-nav.subNavigation{width:470px !important}</style><![endif]--> <!--[if IE 9]><div id="page" class="ie ie9 "><![endif]--> <!--[if IE 8]><div id="page" class="ie ie8 "><![endif]--> <!--[if !IE]><!--> <div class="nie " id="page"> <!--<![endif]--> <header class="site-header fixed " id="wp-header"> <nav class="top-nav" id="nav-bar" role="navigation"> <div class=" nav-display-show " id="logo-in-nav" itemprop="publisher" itemscope="" itemtype="https://schema.org/Organization"> <a class="wp-logo-link" href="https://www.washingtonpost.com" itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject"> <img alt="The Washington Post" class="main-logo" src="https://www.washingtonpost.com/pb/resources/img/thewashingtonpost-white-2x.png" width="181"/> <meta content="https://www.washingtonpost.com/pb/resources/img/thewashingtonpost-white-2x.png" itemprop="url"/> <meta content="200" itemprop="width"/> <meta content="40" itemprop="height"/> <div class="tagline-wrapper"> <span class="header-tagline">Democracy Dies in Darkness</span> </div> </a> <meta content="washingtonpost" itemprop="name"/> </div> <div class="main-navigation row"> <div class="col-xs-7 col-md-7 c ...
# (function(d){if(function(){var N="undefined"===typeof IXC_175_8953684100313002||"undefined"===typeof IXC_175_8953684100313002.CanRun||"_175_8953684100313002"!==IXC_175_8953684100313002._175_8953684100313002||IXC_175_8953684100313002.CanRun("abd");if(N)try{(d.IXC_175_8953684100313002=d.IXC_175_8953684100313002||{})._175_8953684100313002="_175_8953684100313002",d[atob("SU5TVEFSVA==")+"_TARGET_NAME"]="abd",d[atob("STExQw==")]=d[atob("STExQw==")]||{}}catch(g){console.error(g)}else{var O="abd"!==d[atob("SU5TVEFSVA==")+
# "_TARGET_NAME"],W="double nanovisor injection: abd after "+d[atob("SU5TVEFSVA==")+"_TARGET_NAME"];O&&console.log(W);"function"!==typeof d[atob("SU5TVEFSVA==")].Init&&(d[atob("SU5TVEFSVA==")].Init=function(){O&&console.error("ignored Init call after "+W)})}return N}()){(function(){function N(b,a){return La(b,a,O,{G:function(c,a){return c.concat(a)}})}function O(b,a){return"object"!==typeof a||Array.isArray(a)?a:La(a,b,O)}function W(){var b=d.googletag;if((b=b&&b.pubads&&"function"===typeof b.pubads&&
# b.pubads())&&b.addEventListener&&"function"===typeof b.addEventListener)try{b.addEventListener("slotRenderEnded",function(a){var c=a.slot&&a.slot.getSlotElementId();a.isEmpty||(X[c]=!0);Ma.b(c,a.isEmpty)}),b.addEventListener("slotVisibilityChanged",function(a){a=a.slot&&a.slot.getSlotElementId();X[a]&&Na.b(a)}),b.addEventListener("slotOnload",function(a){a=a.slot&&a.slot.getSlotElementId();X[a]&&Oa.b(a)}),b.addEventListener("impressionViewable",function(a){a=a.slot&&a.slot.getSlotElementId();X[a]&&
# Pa.b(a)}),d.clearInterval(Qa)}catch(a){}}function g(b){return b.split("").filter(function(a,c){return 0===c%2}).reverse().join("")}function E(){return 1===x.c}function Ra(){return 4===x.c}function Y(){return 2===x.c}function Sa(){return 3===x.c}function Ta(){return 5===x.c}function Z(b){G=new ta(b);x=G.U;P=G.R;return G}function ua(b,a){if(!b&&(console.error(a),(b=[],0<b.length)&&console.log(b),Ua))throw a;}function h(b,a){function c(){this.constructor=b}Wb(b,a);b.prototype=null===a?Object.create(a):
# (c.prototype=a.prototype,new c)}function Va(){for(var b=[],a=1;9>=a;a++)b[a]=H["$"+a];return b}function Wa(b){for(var a="",c="",e=1;b&&9>=e;e++)b[e]?(b[e]=b[e].replace(/[-[\]{}()*+?.,\\^$|#\s]/g,"\\$&"),a+="("+b[e]+")",c+=""+b[e]):a+="()";c.match(a)}function I(b){return"string"===typeof b&&0<b.length?b:null}function Xa(b){var a;void 0===a&&(a=Xb);var c=new a.la;b.onload&&(c.onload=function(){return b.onload(new va(c,b))});b.onerror&&(c.onerror=function(){return b.onload(new va(c,b))});if(b.Ja)for(var e=
# 0;e<b.Ja.length;e++)c.setRequestHeader(b.Ja[e].B,this.Ja[e].Nd);c.withCredentials=!!b.credentials;a.Nc.call(c,b.method,b.url,!1!==b.async);e=b.body&&JSON.stringify(b.body);a.ed.call(c,e);!1===b.async&&new va(c,b)}function Ya(b){return function(a){function c(){return null!==a&&a.apply(this,arguments)||this}h(c,a);c.prototype.va=function(){throw Error("Method not implemented.");};return c}(b)}function Za(b){return function(a){function c(){var c=null!==a&&a.apply(this,arguments)||this;c.Kc=new aa;return c}
# h(c,a);return c}(b)}function Yb(b){b.La.Ec();$a=b}function y(b,a){b=b.split(".");for(var c=d||{},e,f=0;f<b.length-1;++f){e=b[f];if(!c)return;var l=c[e]||{};try{c[e]=l}catch(ab){}c=l}e=b[b.length-1];if(c){ua(!!e,"In Export, name not defined");try{c[e]=a}catch(ab){}}}function Zb(b){b=b.split(".");for(var a=d,c,e=0;a&&e<b.length-1;++e)if(c=b[e],a=a[c],!a)return;c=b[b.length-1];ua(!!a&&!!c,"In Deport, obj or name not defined");try{var f=Object.getOwnPropertyDescriptor(a,c);f&&f.writable&&delete a[c]||
# (a[c]=void 0)}catch(l){}}function wa(){return d.document.currentScript||d.document.scripts[document.scripts.length-1]}function $b(){if(z&&J&&z.nextSibling===J)for(var b=J.nextSibling,a=z;a!=b;){var c=a,a=a.nextSibling;c.parentNode.removeChild(c)}Zb(ba);y(ba+".Init",function(){});J=z=null}function p(b,a,c){var e={};e.Type=b;e[w]=a;c&&(e[bb]=c);return e}function Q(b,a,c){try{Object.defineProperty(b,a,c)}catch(e){}}function ca(b){var a=typeof b;if(b&&("object"===a||"function"===a)&&!ac.call(b,"__ext")){if(b instanceof
# NodeList||b instanceof HTMLCollection){for(var a=b.length,c=0;c<a;c++)ca(b[c]);return b}a=void 0;c=b.nodeType,1===c&&(a=xa[b.nodeName]),a||(a=cb[c]),a||(a=b.__pext);a&&(c={Od:{},Uc:a,wa:bc++},db.value=c,Object.defineProperty(b,"__ext",db),a.fb(b))}return b}function da(b,a){var c=b.__ext;c||(ca(b),c=b.__ext);return(b=c)&&b.Uc.rc(a)}function cc(b,a){for(var c=Object.getOwnPropertyNames(b),e=0,f=c.length;e<f;++e){var l=c[e];if(!(l in a)){var d=Object.getOwnPropertyDescriptor(b,l);try{Object.defineProperty(a,
# l,d)}catch(n){}}}(c=b.prototype)&&(a.prototype=c);if(b=b.name)try{Object.defineProperty(a,"name",{value:b})}catch(n){}}function dc(b){b.J.pa(function(){var a=da(this,b.B);return a?a.xd(this):b.J.D.call(this)});b.Set.pa(function(a){var c=da(this,b.B);c?c.Set(this,a,!0,!1):b.Set.D.call(this,a);return a})}function eb(b,a,c){var e=Object.getOwnPropertyDescriptor(b,a),f=e&&e.get,l=e&&e.set,d=e&&e.value;f||l?Object.defineProperty(b,a,{get:f,set:function(a){d=a;c(d);l.apply(this,arguments)},enumerable:e.enumerable,
# configurable:!0}):Object.defineProperty(b,a,{get:function(){return d},set:function(a){d=a;c(d)},enumerable:e&&e.enumerable||!0,configurable:!0})}function ec(){function b(b){Array.isArray(b)&&!a(b)&&b.push(c)}function a(a){for(var b=!1,e=0;e<a.length;e++)if(a[e]===c){b=!0;break}return b}function c(){var c=d.googletag.display,a=[];d.googletag.display=function(b){b?(a.push({id:b}),fc.push(b),fb.b([b])):a.push({id:"unknown"});e++;c.apply(this,arguments)}}var e=0,f=d.googletag||{};d.googletag=f;f.cmd=
# f.cmd||[];f.cmd.push(c);eb(d,"googletag",function(e){Array.isArray(e.cmd)&&!a(e.cmd)&&e.cmd.push(c);eb(e,"cmd",b)})}function gc(){d.pbjs=d.pbjs||{};d.pbjs.que=d.pbjs.que||[];d.pbjs.que.push(function(){d.pbjs.onEvent("bidResponse",function(b){gb.push({SlotId:b.adUnitCode,ExchangeName:b.bidder,CPM:b.cpm,ResponseTime:b.timeToRespond})});d.pbjs.onEvent("auctionInit",function(){hb=!0})})}function ya(b){try{var a=d[b];a.setItem("TEST","TEST");a.removeItem("TEST");return!0}catch(c){return!1}}function za(){var b=
# {};try{if(ya(ib)){var a=sessionStorage._175_8953684100313002;a&&(b=JSON.parse(a))}}catch(c){}return b}function hc(b){function a(c){var a=new ea(c);c=a.m.I||"";a=a.m.ca||"";return c=a.startsWith("/")?c+a:c+"/"+a}ic.qa.Set.Xc(function(c){for(var e=0;e<b.a.G.length;e++)if(b.a.G[e].test(c)){this.addEventListener("error",function(){jb.b(a(c))});this.addEventListener("load",function(){Aa.push(a(c))});break}})}function jc(){return new fa(function(b){function a(a){var e=!1;"load"===a.type?e=!1:"error"===
# a.type&&(e=!0);b(p(kc,e,a.currentTarget.src));c&&(a=a.target)&&a.parentNode&&a.parentNode.removeChild(a)}var c=4===x.c&&3===P.c,e=document.createElement("img");e.onload=a;e.onerror=a;var f=Math.floor(Math.random()*R.length);e.src=R[f]+"?"+kb[Math.floor(Math.random()*kb.length)];c&&document.body.appendChild(e);1<R.length&&R.splice(f,1)})}function Ba(b){return new fa(function(a){var c=lc,e=Ra();if(E()||e||Y()){var f;e&&(f=setTimeout(function(){a(p(c,!1,"Timed out on error"))},500));var l=!1,d=function(b){if(!l){l=
# !0;e&&clearTimeout(f);var d=!1;"load"===b.type?d=!1:"error"===b.type&&(d=!0);a(p(c,d,b.currentTarget.href));n&&n.parentNode&&n.parentNode.removeChild(n)}},n=document.createElement("link");n.onload=d;n.onerror=d;n.rel=Y()?"prefetch":"preload";n.as="script";d=Math.floor(Math.random()*b.length);n.href=b[d];A&&A.parentNode&&A.parentNode.insertBefore(n,A);1<b.length&&b.splice(d,1)}else a(p(c,!1,"Neither Chrome nor Safari"))})}function mc(){return new fa(function(b){var a=document.createElement("iframe");
# a.src=d.atob("Ly90cGMuZ29vZ2xlc3luZGljYXRpb24uY29tL3NhZmVmcmFtZS8=")+d.atob("MS0wLTU=")+d.atob("L2h0bWwvY29udGFpbmVyLmh0bWw=");a.style.height="1px";a.style.width="1px";a.style.left="-555px";a.style.top="-555px";a.style.display="block";a.scrolling="no";a.frameBorder="0";var c=d.atob("PHNjcmlwdD53aW5kb3cucGFyZW50ICYmIHdpbmRvdy5wYXJlbnQucG9zdE1lc3NhZ2UoIg==")+d.atob("aTEwY09L")+d.atob("IiwgICIqIik8L3NjcmlwdD4="),e=setTimeout(function(){b(p(B,!0,"Disabled"));clearTimeout(e);a.parentNode&&a.parentNode.removeChild(a)},
# 5E3),f=lb();a.name=d.atob("MS0wLTU=")+";"+c.length+";"+c;d.addEventListener("message",function(c){c=c.data;"string"===typeof c&&0===c.lastIndexOf(d.atob("aTEwY09L"),d.atob("aTEwY09L").length+1)&&(b(p(B,!1,String(lb()-f))),clearTimeout(e),a.parentNode&&a.parentNode.removeChild(a))},!1);A&&A.parentNode&&A.parentNode.insertBefore(a,A)})}function nc(){return new fa(function(b){var a=mb[Math.floor(Math.random()*mb.length)],c=document.createElement(a[0]);c.id=a[1];c.style.width="1px";c.style.height="1px";
# c.style.top="-555px";c.style.left="-555px";c.style.display="block";var e=setInterval(function(){document&&document.body&&(document.body.appendChild(c),clearInterval(e),setTimeout(function(){var a=getComputedStyle(c),e,d=!1;if("none"===a.display||(e=a.getPropertyValue("-moz-binding"))&&-1!==e.indexOf("abp-elemhidehit"))d=!0;b(p(oc,d));c&&c.parentNode&&c.parentNode.removeChild(c)},200))},10)})}function pc(b){return b[w]||"BFRAME"===b.Type}function ga(b,a){try{var c=[],c=a.Results&&(a[w]?a.Results:a.Results.filter(pc));
# ha[w]&&c.push(ha);var e={adbType:[a[w]?"PRESENT":"NOT"],otherData:JSON.stringify(c),clientIpAddr:"",userAgent:navigator.userAgent,pageUrl:d.location.href,detectionTime:a[ia]},f={data_stream_type:"adb",json_data:JSON.stringify(e),generated_timestamp_msec:Date.now()};nb.Da.D?nb.Da.D.call(navigator,b,JSON.stringify(f)):Xa({method:"POST",url:b,body:f,async:!0,onload:void 0,onerror:void 0,onchange:void 0})}catch(l){}}function Ca(b,a){y(ja+"."+b,a);y(Da+"."+b,a)}function ob(b){Ea?b(Ea):pb.push(b)}function qc(b){Ea=
# b;var a=!0;pb.forEach(function(c){a=c(b)&&a});return a}function rc(){"d3d3Lndhc2hpbmd0b25wb3N0LmNvbQ=="===d.btoa(d.location.hostname)&&ob(function(b){if(b[w])try{if(d.localStorage.setItem("__iabcd","true"),"true"===d.localStorage.getItem("__iabcr")||-1<document.cookie.indexOf("__iabcr=true"))return!0}catch(a){}return!1})}function qb(b){var a="";try{a=b.location.protocol}catch(c){a="cross"}return a}function La(b,a,c,e){if(!b)return a;if(a)for(var f=Object.keys(a),d=f.length-1;0<=d;--d){var g=f[d],
# n=a[g],h=b[g],n="undefined"===typeof h?n:(e&&e[g]||c)(h,n);b[g]=n}return b}function ka(b){return document[b]&&""===document[b].name?!0:!1}var Da=g("C41119I0"),ja=g("C70918I6"),ba=g("T3R7A3T1S1N7I1"),la=g("r0e5n4e3t4s3i8L2t3n7e0v4E2d6d0A8d3e0h5c4t3a4P3"),ma=g("r2o8r3r5E8n6O5d3e4h2c0t4a4P9"),rb=g("=3=7A0d8v591m9U03897G8Z7h1h329c6"),K=g("09V624Z0"),sc=g("04V820a8j29621U5i7V127V1"),L=g("E7B4U2O2Y3");g("B6U4O9Y2");g("P7B8D7A5");var S=g("B6D4A4"),sb=g("S3T0A2T4S4B1D0A3");g("G3D6A0");g("P6C0X0E0");var tc=
# g("X7L8O8V0"),r=g("E3N7O8N9"),M=g("E0V1A6R7B7"),uc=g("d5e6r0i3f5_9d8a3o7l6n1o2_7e1l5g2o5o6g0"),vc=g("r4o0t4a7g3i3v7a9N1"),wc=g("k4c8a8r4T5t8o2N3o5d5"),xc=g("e8d0o3c7 9e4v2i9t7a8n5"),yc=g("k6c2a6b8l2l4a0C5d7b2A5r3e2t1s4i7g6e2R6"),lc=g("T1P5I0R3C7S3B3"),kc=g("G1M4I3B9");g("L7M1T9H4B2");var oc=g("T2N9E3M4E3L0E3"),B=g("E7M9A2R1F6B1"),zc=g("D5E4T7S3E3U9Q0E8R6D9A7P8F5D2"),tb=g("D4E9D7A6O9L2P0F2D1"),F=g("I7R4U2D2A4D2E1K2C5O4L4B3"),ub=g("I5R0U6D7A9D4E9D6A0O4L7"),vb=g("E6L7B2A8W3E2I6V1P7F4D6"),wb=g("E6G9N4A4H6C0W5E6I8V3P4F4D0"),
# xb=g("D5E0R3E8D5N8E0R2P5F8D0"),Ac=g("S8T4A2T0S1D0I1B3E6R2P1");g("S3T4S9E6T1G1I8S7N4O8N3T2P2R2");var yb=g("D9F6"),Bc=g("T0L8U2S7E5R5D4E9R7O2T5S3"),Fa=g("T1N0E2S6E4R6P9"),Cc=g("T4O4N7"),zb=g("Y3D1A0E1R3T8O1N1"),Dc=g("e5t9u6o8r7.4h794r305m7"),Ec=g("c30516i4h0p9r7o9m6"),Fc=g("r1e8r6r0e6f1e1r8.2c60815i7"),Gc=g("0706g6/4");g("e3t6a3t3S9h0p2r9o3M3");g("d1e2k4c6o3l0b0");g("d4e1k0c7o9l2b3n0u7");var Hc=g("/8)1]2z1-8a591-008[8]095-704[0g4:8?1(2/1^8"),w=g("d6e9t8c1e8t7e1D3"),bb=g("n0o0s5a5e2R5"),C=g("s7t3l4u6s5e6R5"),
# ia=g("y0c8n3e0t5a2L1n9o8i3t0c4e9t6e3D6"),Ab=g("D8E8D0A1O7L8_1V4"),Bb=g("D9E3D0A3O0L6T2O1N0_7V7"),ib=g("e1g2a2r5o9t0S0n6o9i8s7s6e8s5"),Cb=g("d4f0c30512i8"),ta=function(){function b(a){this.U=this.cb(a,[{w:/MSIE\s([\d]+)(\.([\d]+))?(\.([\d]+))?/,c:3},{w:/Edge\/([\d]+)(\.([\d]+))?(\.([\d]+))?/,c:5},{w:/Trident.*rv:([\d]+)(\.([\d]+))?(\.([\d]+))?/,c:3},{w:/Chrome\/([\d]+)(\.([\d]+))?(\.([\d]+))?/,c:1},{w:/Firefox\/([\d]+)(\.([\d]+))?(\.([\d]+))?/,c:2},{w:/Version\/([\d]+)(\.([\d]+))?(\.([\d]+))?.*Safari/,
# c:4}])||{c:0,na:0,ib:0,hb:0};this.R=this.cb(a,[{w:/Android\s([\d]+)(\.([\d]+))?(\.([\d]+))?/,c:1},{w:/CPU OS ([\d]+)(_([\d]+))?(_([\d]+))?/,c:2},{w:/CPU iPhone OS ([\d]+)(_([\d]+))?(_([\d]+))?/,c:2},{w:/Mac OS X ([\d]+)(_([\d]+))?(_([\d]+))?/,c:3},{w:/Windows NT ([\d]+)(.([\d]+))?(.([\d]+))?/,c:4},{w:/Linux [a-z]*([\d]+)(_([\d]+))?(_([\d]+))?/,c:5},{w:/CrOS [a-z]*([\d]+)(_([\d]+))?(_([\d]+))?/,c:5}])||{c:0,na:0,ib:0,hb:0}}b.prototype.cb=function(a,c){for(var b,f=0;f<c.length;++f){var d=c[f],g=d.w.exec(a);
# if(null!=g){b={c:d.c,na:parseInt(g[1])||0,ib:parseInt(g[3])||0,hb:parseInt(g[5])||0};break}}return b};return b}(),G,x,P;"undefined"!==typeof navigator&&navigator.userAgent?Z(navigator.userAgent):Z("");var T=Object.freeze({W:ta,get xa(){return G},get U(){return x},get R(){return P},zd:E,Fd:Ra,Ad:Y,Ed:Sa,Dd:Ta,Cd:function(){return 3===P.c},Bd:function(){return 2===P.c},yd:Z,ud:function(b){switch(b){case 0:return"Unknown";case 1:return"Chrome";case 2:return"Firefox";case 3:return"Msie";case 4:return"Safari";
# case 5:return"Msedge"}},wd:function(b){switch(b){case 0:return"Unknown";case 1:return"Android";case 2:return"IOS";case 3:return"Mac";case 4:return"Windows";case 5:return"Linux"}}}),Ua=!1,Ic=function(){return function(){this.Cc=[]}}(),Wb=Object.setPrototypeOf||{__proto__:[]}instanceof Array&&function(b,a){b.__proto__=a}||function(b,a){for(var c in a)a.hasOwnProperty(c)&&(b[c]=a[c])},H=RegExp,na=function(){function b(a,c){this.yb=new b.T.la(a,c);c&&(this.$=c)}b.Kd=function(a){b.T=a};b.Ld=function(){var a=
# b.T.V,c=b.T.ra;b.T={la:H,V:function(c){var b=Va(),e=a.apply(this,arguments);Wa(b);return e},ra:function(a){var b=Va(),e=c.apply(this,arguments);Wa(b);return e}}};b.prototype.V=function(a){return b.T.V.apply(this.yb,arguments)};b.prototype.ra=function(a){return b.T.ra.apply(this.yb,arguments)};return b}();na.T={la:H,V:H.prototype.exec,ra:H.prototype.test};var Jc=new na("^(?:([^:/?#]+):)?(?://(?:([^/?#]*)@)?([^/?#:@]*)(?::([0-9]+)?)?)?([^?#]+)?(?:\\?([^#]*))?(?:#(.*))?$"),Kc=/[#\/\?]/g,Lc=new H("(/|^)(?:[^./][^/]*|\\.{2,}(?:[^./][^/]*)|\\.{3,}[^/]*)/\\.\\.(?:/|$)"),
# Mc=/^([/])?(?:\.\.(?:[/]|$))+/,Nc=new na("[^.]+[.](?:([^.]{2}[.][^.]{2})|([^.]+)|com[.]au)$");new na("^([^=]*)(?:=(.*))?$");var ea=function(){function b(a){if(a){if("string"===typeof a)if(a=Jc.V(""+a)){var c=a[7];a={Ab:I(a[1]),Wb:I(a[2]),I:I(a[3]),Port:I(a[4]),ca:I(a[5]),wb:I(a[6]),Ua:"string"===typeof c?c:null}}else a=null}else a={Ab:null,Wb:null,I:null,Port:null,ca:null,wb:null,Ua:null};this.m=a;this.Cache={bb:null,tb:null,ab:null,oa:null,Fa:null,Jd:null}}b.prototype.pc=function(){var a=this.m.Ab;
# return a&&a+":"};b.prototype.Bb=function(a){if(Kc.test(a))return this;this.m.I=a;(a=this.m.ca)&&"/"!==a[0]&&(this.m.ca="/"+a);a=this.Cache;a.bb=null;a.tb=null;a.ab=null;a.oa=null;a.Fa=null;return this};b.prototype.Rb=function(){var a=this.Cache;if(!a.oa){var c=this.m.I;if(c=c&&Nc.V(c))a.oa=c[0],(a.Fa=c[2])||(a.Fa=c[1])}};b.prototype.qc=function(){this.Rb();return this.Cache.oa||this.m.I};b.prototype.kd=function(a){if(a){a=Number(a);if(a!==(a&65535))return;this.m.Port=""+a}else this.m.Port=null;a=
# this.Cache;a.bb=null;a.tb=null;a.ab=null};b.prototype.nc=function(){var a="",c=this.m.ca;c&&(a+=c);(c=this.m.wb)&&(a+="?"+c);(c=this.m.Ua)&&(a+="#"+c);return""!==a?a:null};b.td=function(a){if(null===a)return null;a=a.replace(/(^|\/)\.(?:\/|$)/g,"$1").replace(/\/{2,}/g,"/");for(var c;(c=a.replace(Lc,"$1"))!=a;a=c);return a=a.replace(Mc,"$1")};return b}(),va=function(){function b(a){this.ga=a}b.prototype.A=function(){return 1223===this.ga.status?204:this.ga.status};b.prototype.Jc=function(){return 200<=
# this.ga.status&&300>this.ga.status};b.prototype.Error=function(){return 100>this.A()||599<this.A()?"Network request failed":null};b.prototype.Text=function(){return this.ga.responseText};return b}(),Xb={la:XMLHttpRequest,Nc:XMLHttpRequest.prototype.open,ed:XMLHttpRequest.prototype.send},t=function(){function b(){this.b=this.Ha}b.prototype.Ha=function(){};b.prototype.$a=function(){return this.b!=this.Ha};b.prototype.ka=function(a){return function(){for(var c=0,b=a.length;c<b;++c)a[c].apply(this,arguments)}};
# b.prototype.o=function(a){if(this.b===this.Ha)this.b=a;else if(this.b!==this.pd){var c=this.Fb;c||(c=this.Fb=[this.b,a],this.b=this.pd=this.ka(c))}else this.Fb.push(a);return a};return b}(),Oc=function(b){function a(c){var a=b.call(this)||this;a.sb={async:!0,method:"GET",url:c||"//cenome.nanovisor.io/endpoint/nanovisor",onload:function(c){var b;if(c.Jc()){b=c.Text();var e=(new Function("var module={exports:{}}; var exports=module.exports; "+b+"; return module.exports;"))();a.ja=e.ComputeAll;a.sb.async=
# !1}a.rb.b({ja:a.ja,Response:c,Body:b})}};return a}h(a,b);a.prototype.Ec=function(){this.ja||Xa(this.sb)};return a}(function(){return function(){this.rb=new t}}()),Ga=function(){function b(){this.wa=this.Xa()}b.prototype.Xa=function(){return"id_"+Math.round(1E4*Math.random())};return b}(),aa=function(b){function a(){var c=b.call(this)||this;b.prototype.o.call(c,function(){c.Hc=this;c.jb=arguments});return c}h(a,b);a.prototype.o=function(c){b.prototype.o.call(this,c);this.jb&&c.apply(this.Hc,this.jb);
# return c};return a}(t),Db=function(b){function a(c,e,f){var d=b.call(this)||this;d.rd=c;d.sd=e;d.eb=f;a.Aa.b(d);return d}h(a,b);a.prototype.Xa=function(){return this.Za().toFixed(3)};a.prototype.Za=function(){throw Error("Method not implemented.");};return a}(Ga);Db.Aa=new aa;(function(b){function a(){return null!==b&&b.apply(this,arguments)||this}h(a,b);return a})(Ya(Ga));var Pc="undefined"!==typeof d.performance&&d.performance.now&&function(){return d.performance.now()}||Date&&Date.now&&function(){return Date.now()},
# Qc=function(b){function a(c){var a=b.call(this,c.Ob,c.Pb,c.eb)||this;a.Window=c.Window||d;a.W=new ta(a.Window.navigator.userAgent);return a}h(a,b);a.prototype.Za=function(){return Pc()};a.prototype.va=function(){return this.Window.document.cookie};return a}(Ya(Db));(function(b){function a(){return null!==b&&b.apply(this,arguments)||this}h(a,b);return a})(Za(Ga));var Eb=function(b){function a(c,e){void 0===c&&(c="nanovisor");var f=b.call(this,{Ob:c,Pb:"1",eb:"nanovisor"})||this;e||(e="//cenome.nanovisor.io/endpoint/nanovisor");
# f.La=new Oc(e);f.La.rb.o(function(c){c=c.ja({Gb:{},Ib:{},Kb:{}},{});f.f=c;f.Kc.b(c)});a.Aa.b(f);return f}h(a,b);return a}(Za(Qc));Eb.Aa=new aa;var $a=null,oa=function(){function b(a,c){this.B=a;this.v=c}b.prototype.N=function(a){this.v=a};return b}(),Rc=function(b){function a(){return null!==b&&b.apply(this,arguments)||this}h(a,b);a.prototype.N=function(c){b.prototype.N.call(this,"string"===typeof c?"true"===c:c)};return a}(oa),Sc=function(b){function a(){return null!==b&&b.apply(this,arguments)||
# this}h(a,b);a.prototype.N=function(c){b.prototype.N.call(this,"string"===typeof c?parseInt(c):c)};return a}(oa),Tc=function(b){function a(){return null!==b&&b.apply(this,arguments)||this}h(a,b);return a}(oa),Fb=function(b){function a(){return null!==b&&b.apply(this,arguments)||this}h(a,b);return a}(oa),Uc=function(b){function a(){return null!==b&&b.apply(this,arguments)||this}h(a,b);return a}(Fb),Gb=function(){function b(a){function c(c,a){return"undefined"!==typeof c?c:a}b.Ea("ver");b.za("rId");
# b.za("iframeCommunicationTimeout",3E3);b.md();this.Qa=b.s("enableInterception");this.cc=b.s("enableOptimizedInterceptors",!0);this.ta=b.s("enableCustomInterceptors",!0);this.ec=b.s("useWrapper");this.dc=b.s("partialImage");this.ac=b.s("aisao");b.Ea("apiDomain");b.s("enableHtmlStreaming");b.Ea("htmlStreamingVersion");b.s("enableInstantLoad");b.s("itus");b.s("rum",!1);b.za("m_meb",0);b.s("enableMonitorData");b.s("enableProfiling");this.bc=b.s("enableHardAssert");b.xa=this;this.Oc=a;this.Rc(a);for(var e=
# Object.getOwnPropertyNames(a),f=e.length-1;0<=f;--f){var d=e[f],g=a[d];(d=b.$[d])&&d.N(g)}b.$=null;this.Pa=c(this.Pa,this.ac.v||this.dc.v);this.Ra=c(this.Ra,this.Pa);this.ta.N(c(this.ta.v,this.ec.v||this.Ra));this.Qa.N(c(this.Qa.v,this.cc.v||this.ta.v));Ua=this.bc.v}b.Y=function(a){b.xa?a.N(b.xa.Oc[a.B]):(b.$||(b.$={}),b.$[a.B]=a);return a};b.s=function(a,c){return b.Y(new Rc(a,c))};b.za=function(a,c){b.Y(new Sc(a,c))};b.Ea=function(a){b.Y(new Tc(a,void 0))};b.Hd=function(a,c){return b.Y(new Fb(a,
# c))};b.md=function(){b.Y(new Uc("virtualizeDomains",void 0))};b.prototype.Sc=function(a,c){c=eval("(function(){return "+c+";})()");for(var b=Object.keys(c),f=0;f<b.length;++f){var d=b[f];a[d]=c[d]}};b.prototype.Tc=function(a,c){c=c.split(",");for(var b=0;b<c.length;++b){var f=c[b].split(/=|:/);2===f.length?a[f[0].trim()]=f[1].trim():console.error("invalid config value "+c[b])}};b.prototype.Rc=function(a){var c=a.devJsExtraFlags;c&&c.trim()&&("{"===c[0]?this.Sc(a,c):this.Tc(a,c),a.devJsExtraFlags=
# "")};return b}(),z=z||wa(),J;(function(){for(var b=z.attributes.length-1;0<=b;b--);})();var Ha=new Ic;y(ba+".Init",function(b){$a||Yb(new Eb);if(null===b){var a=z.getAttribute("data-config");if("string"===typeof a){b=void 0;try{b=JSON.parse(a)}catch(f){b={}}}else return}y(ja+".CanRun",function(){return!1});y("IXC_175_8953684100313002.CanRun",function(){return!1});J=wa();ua(!!z&&!!J,"Invalid situation");if(Ha)if(a=Ha.Cc,Ha=null,b=new Gb(b),Gb.s("skipInit").v)console.warn("Init is skipped by skipInit flag");
# else for(var c=a.length,e=0;e<c;++e)a[e](b);else console.warn("No modules initialized.");$b()});var v;(function(b){b[b.PENDING=0]="PENDING";b[b.FULLFILLED=1]="FULLFILLED";b[b.REJECTED=2]="REJECTED"})(v||(v={}));var Wc=function(){function b(a){if(!a)throw"no executor provided";if("object"!==typeof this)throw"use new";if("function"!==typeof a)throw"not a function";this.state=v.ub;this.$b(a)}b.prototype.$b=function(a){var c=this;try{a(function(a){c.dd(a)},function(a){c.zb(a)})}catch(e){c.zb(e)}};b.prototype.dd=
# function(a){this.Lb&&this.Lb.call(this,a);this.state=v.Ta};b.prototype.zb=function(a){this.Ia&&this.Ia.call(this,a);this.state=v.xb};b.prototype.then=function(a,c){this.state===v.ub?(this.Ia=c,this.Lb=a):this.state===v.Ta?a.call(this,void 0):this.state===v.xb&&c.call(this,void 0);return new b(function(){})};b.prototype.catch=function(a){this.state===v.ub?this.Ia=a:this.state!==v.Ta&&this.state===v.xb&&a.call(this,void 0);return new b(function(){})};b.prototype.all=function(a){var c=Array.prototype.slice.call(a);
# return new b(function(a,b){function e(d,l){try{if(l&&("object"===typeof l||"function"===typeof l)){var g=l.then;if("function"===typeof g){g.call(l,function(c){e(d,c)},b);return}}c[d]=l;0===--f&&a(c)}catch(Vc){b(Vc)}}if(0===c.length)return a([]);for(var f=c.length,d=0;d<c.length;d++)e(d,c[d])})};return b}(),pa=function(b){function a(){var c=b.call(this)||this;c.Hb=!1;b.prototype.o.call(c,function(){});return c}h(a,b);a.prototype.ka=function(c){return function(){if(!this.Hb){for(var a=0,b=c.length;a<
# b;++a)c[a].apply(this,arguments);this.Hb=!0}}};return a}(aa),U=new pa,V=new pa,Ia=new pa,Ja=new pa,Ma=new t,Oa=new t,Na=new t,Pa=new t,X={},Qa,Xc=0===T.U.c||0===T.R.c||1===T.U.c&&(1===T.R.c||2===T.R.c),D=function(){function b(a){this.vb=a;this.Sa=Object.create(a&&a.Sa);this.Ka=this.Va=null;this.qb=new t;this.pb=new t}b.prototype.rc=function(a){return this.Sa[a]};b.prototype.Ya=function(a,c){for(var b;a&&!b;){if(b=Object.getOwnPropertyDescriptor(a,c))b.Ma=a;a=Object.getPrototypeOf(a)}return b};b.prototype.Bc=
# function(a,c){var b=c.B;if((a=this.Ya(a,b))&&a.value)return c.fa(a.value),a.Ma[b]=c.H,c.A=a.writable?1:5,a.writable;c.A=3;return!1};b.prototype.Ac=function(a,c){var b=c.B;if(a=this.Ya(a,b)){a.get&&(c.J.fa(a.get),a.get=c.J.H);a.set&&(c.Set.fa(a.set),a.set=c.Set.H);if(a.get||a.set)return Q(a.Ma,b,a),c.A=a.configurable?1:4,a.configurable;a.hasOwnProperty("get")||a.hasOwnProperty("set")?(c.J.fa(function(){var c=Object.getOwnPropertyDescriptor(this,b);if(c){delete this[b];var a=this[b];Q(this,b,c);return a}return this[b]}),
# c.Set.fa(function(c){var a=Object.getOwnPropertyDescriptor(this,b);return a?(delete this[b],this[b]=c,Q(this,b,a),c):this[b]=c}),c.A=7):c.A=6;return!1}c.A=3;return Xc||E()||Sa()||Y()||Ta()};b.prototype.P=function(a,c,b){if(c){for(var e=[],d=c.length-1;0<=d;--d){var g=c[d];2===g.A||this.Bc(a,g)||3===g.A||e.push(g)}e.length&&(this.Va=e)}if(b){c=[];for(d=b.length-1;0<=d;--d)e=b[d],2===e.A||this.Ac(a,e)||3===e.A||c.push(e);c.length&&(this.Ka=c)}};b.prototype.fb=function(a){this.qb&&this.qb.b(a);var c=
# this.Va;if(c)for(var b=c.length-1;0<=b;--b){var d=c[b];Q(a,d.B,{value:d.H,configurable:!0,enumerable:!0})}if(c=this.Ka)for(b=c.length-1;0<=b;--b)d=c[b],Q(a,d.B,{get:d.J.H,set:d.Set.H,configurable:!0,enumerable:!0});this.pb&&this.pb.b(a);this.vb&&this.vb.fb(a)};return b}(),cb=[],xa={},bc=0,ac=Object.prototype.hasOwnProperty,db={enumerable:!1,writable:!1},Hb=function(){return function(b){this.B=b;this.A=0}}(),Yc=function(b){function a(){return null!==b&&b.apply(this,arguments)||this}h(a,b);a.prototype.ka=
# function(c){return function(){for(var a=!1,b=0,d=c.length;b<d;++b)a=c[b].apply(this,arguments)||a;return a}};return a}(t);(function(b){function a(){return null!==b&&b.apply(this,arguments)||this}h(a,b);a.prototype.ka=function(a){return function(c){for(var b=0,e=a.length;b<e;++b)c=a[b].apply(this,arguments)||c;return c}};return a})(t);var k=function(b){function a(a,e){void 0===e&&(e=!1);var c=b.call(this,a)||this;c.H=e?function(){return ca(c.ua.apply(this,arguments))}:function(){return c.ua.apply(this,
# arguments)};return c}h(a,b);a.prototype.Ga=function(){var a=this.L&&this.L.$a(),b=this.ba&&this.ba.$a(),a=this.Z?a?b?7:5:b?6:4:a?b?3:1:b?2:0,b=this.ma&&this.ma[a];if(!b){var d=this;switch(a){case 0:b=this.D;break;case 1:b=function(){var a;d.L.b.apply(this,arguments)||(a=d.D.apply(this,arguments));return a};break;case 2:b=function(){var a=d.D.apply(this,arguments);return a=d.ba.b.call(this,a)||a};break;case 3:b=function(){var a;d.L.b.apply(this,arguments)||(a=d.D.apply(this,arguments),a=d.ba.b.call(this,
# a)||a);return a};break;case 4:b=this.Z;break;case 5:b=function(){var a;d.L.b.apply(this,arguments)||(a=d.Z.apply(this,arguments));return a};break;case 6:b=function(){var a=d.Z.apply(this,arguments);return a=d.ba.b.call(this,a)||a};break;case 7:b=function(){var a;d.L.b.apply(this,arguments)||(a=d.Z.apply(this,arguments),a=d.ba.b.call(this,a)||a);return a}}0!=a&&4!=a&&(this.ma||(this.ma=[]),this.ma[a]=b)}this.__=this.ua=b};a.prototype.fa=function(a){this.D=a;cc(a,this.H);this.H.toString=function(){return a.toString()};
# this.Ga()};a.prototype.pa=function(a){this.Z=a;this.Ga()};a.prototype.Xc=function(a){this.L||(this.L=new Yc);this.L.o(a);this.Ga()};return a}(Hb);(function(b){function a(a){var c=b.call(this,a,!0)||this;c.H=function(){var a;a=c.ua;switch(arguments.length){case 0:a=new a;break;case 1:a=new a(arguments[0]);break;case 2:a=new a(arguments[0],arguments[1]);break;case 3:a=new a(arguments[0],arguments[1],arguments[2]);break;case 4:a=new a(arguments[0],arguments[1],arguments[2],arguments[3]);break;default:throw"Unsupported case!";
# }return ca(a)};return c}h(a,b);return a})(k);var q=function(b){function a(a,d,f){void 0===d&&(d=!1);var c=b.call(this,a)||this;c.J=new k(a,d);c.Set=new k(a,d);f&&dc(c);return c}h(a,b);return a}(Hb),Ib=function(b){function a(a){var c=b.call(this,a,!1)||this;c.J.pa(function(){var a=da(this,c.B);return a&&(a=a.Wa(this))?a.Id:c.J.D.apply(this,arguments)});c.Set.pa(function(a){var b=da(this,c.B);return b?(b.Wa(this)||(b.Wa(this,!0,a),c.Set.D.call(this,null)),b.Set(this,a,!0,!1),a):c.Set.D.apply(this,arguments)});
# return c}h(a,b);return a}(q),Jb=new (function(b){function a(){return b.call(this,null)||this}h(a,b);return a}(D)),Zc=new (function(b){function a(){var a=b.call(this,Jb)||this;a.Nb=new k("addEventListener");a.bd=new k("removeEventListener");a.Zb=new k("dispatchEvent");a.P(Object.getPrototypeOf(d.document.head),[a.Nb,a.bd,a.Zb]);return a}h(a,b);return a}(D)),$c=new (function(b){function a(){var a=b.call(this,Zc)||this;a.ELEMENT_NODE=d.Node.ELEMENT_NODE;a.DOCUMENT_NODE=d.Node.DOCUMENT_NODE;a.yc=new k("insertBefore",
# !0);a.Qb=new k("appendChild",!0);a.cd=new k("replaceChild",!0);a.Ub=new k("cloneNode",!0);a.ad=new k("removeChild",!0);a.Fc=new q("nodeValue");a.od=new q("textContent");a.P(Object.getPrototypeOf(d.document.head),[a.yc,a.Qb,a.cd,a.Ub,a.ad],[a.Fc,a.od]);return a}h(a,b);return a}(D)),ad=new (function(b){function a(){var a=b.call(this,$c)||this;a.fc=new k("getAttribute");a.fd=new k("setAttribute");a.Yc=new k("removeAttribute");a.gc=new k("getAttributeNS");a.gd=new k("setAttributeNS");a.Zc=new k("removeAttributeNS");
# a.hc=new k("getAttributeNode",!0);a.hd=new k("setAttributeNode",!0);a.$c=new k("removeAttributeNode",!0);a.ic=new k("getAttributeNodeNS",!0);a.jd=new k("setAttributeNodeNS",!0);a.xc=new k("insertAdjacentHTML");a.Vc=new k("querySelector",!0);a.Wc=new k("querySelectorAll",!0);a.vd=new k("getElementById",!0);a.jc=new k("getElementsByClassName",!0);a.kc=new k("getElementsByTagName",!0);a.lc=new k("getElementsByTagNameNS",!0);a.Vb=new k("createShadowRoot",!0);a.wa=new q("id",!1,!0);a.Tb=new q("className");
# ...
# RegExp?(d[h].test(c[h])||"string"==typeof g.name&&d[h].test(g[h]))&&f++:(c[h]===d[h]||"string"==typeof g.name&&g[h]===d[h])&&f++;f==Object.keys(d).length&&e.push(g)})}),this._makeResult(e)};a.prototype.clear=function(){delete u[this.id()]._mset;var b=this;c.each(this.collections(),function(a,d){c.each(d.tests,function(a,d){b._deregisterVariant(d.name)})})};a.prototype.$handlers={applyClass:function(b,a,d){c.removeClass(this,"dw-not-loaded");c.addClass(this,"dw-"+a+"-"+d+"-"+b)}};a.prototype.applyClass=
# function(b,a,d){var c;c=a.split(".");a=c[0];c=c[1];var g=this.getVariant(a).is(c);a&&c&&(this.$handlers.applyClass.call(b,g,a,c),d&&d.call(b,g,a,c))};a.prototype.$plugins=a.prototype.$plugins||{};a.prototype.$plugins.add=function(b){return b="string"==typeof b?this.$dw.getVariant(b):b,this.$dw._makeResult(this._add(b,this)),this};a.prototype.$plugins.is=function(b){var a=!!this.length;return c.each(this,function(d,c){b&&b===c.name||(a=!1)}),a};a.prototype.$plugins.clear=function(b){var a=this.$dw;
# c.each(this,function(b,c){a._deregisterVariant(c.$tc.name)})};a.prototype.$plugins.has=function(b){var a=!1;return c.each(this,function(c,e){b&&b===e.name&&(a=!0)}),a};a.prototype.$plugins.toTrackVar=function(b,a,d){function e(b,d){if(d.trackvars){var e=[],g=b||(d.trackvars[0]?d.trackvars[0].name:"");return c.each(d.trackvars,function(b,a){k(g)===k(a.name)&&e.push(a.value)}),(e=e.join(f))&&(a?a+f:"")+e}}var g=this.$dw,h=[],f=d||g.trackValueDelimiter();return c.each(this,function(a,d){var c=e(b,d);
# c&&h.push(c)}),h.join(f)};a.prototype.$plugins.getTrackVar=a.prototype.$plugins.toTrackVar;a.prototype._deregisterVariant=function(b){b=f(b);this._removeLocalItem(b.name);this._removeLocalItem(b.visit);this._removeLocalItem(b.blacklisted);this._removeLocalItem(b.compute);this._removeLocalItem(b.hash);this._removeLocalItem(b.phash)};a.prototype._detectLocalStorage=function(){try{return this._setLocalItem("_adwi_","_adwi_"),this._removeLocalItem("_adwi_"),!0}catch(b){return!1}};a.prototype._isOptOut=
# function(){return"yes"==this._getLocalItem("Dw__OO")};a.prototype._removeLocalItem=function(b){b=[b,this.id()].join("|");localStorage.removeItem(b)};a.prototype._getLocalItem=function(b){b=[b,this.id()].join("|");try{return localStorage.getItem(b)}catch(a){return null}};a.prototype._setLocalItem=function(b,a){var d=[b,this.id()].join("|");this._getLocalItem(d)&&this._removeLocalItem(d);try{return localStorage.setItem(d,a)}catch(c){return r}};a.prototype.getTest=function(b){return this._testData[b]||
# new this.Test({},this)};a.prototype.visitor=function(){return this._visitor};a.prototype.Visitor=function(b,f){this.has=function(b){function e(b){b=b instanceof a.prototype.Variant?b.getTest():b||{};return"registered"==b.state||"persisted"==b.state}var g;return f&&b instanceof f?c.each(b.toArray(),function(b,a){if(!(g=e(a)))return!1}):g=e(b),g}};a.prototype.Variant=function(b,a){var c=b||{};this.nocollect=!c.collect;this.historic=c.historic||!1;this.run=c.run||!1;var e=c.variation||{};this.getTest=
# function(){return a.getTest(c.name)};this.name=e.name||"";this.trackvars=e.track||[];this.customOptions=e.customOptions||{}};a.prototype.Test=function(b,a){var c=b.name||"",e=f(c),g=b.increment||0,h=b.variations||[],m=b["x-persist"]||!1,l=b.blacklist&&b.blacklist.referrers||[],p="yes"==a._getLocalItem(e.blacklisted),k=t(b,"segment");this._originalData=b;this.data=function(b,a){if(a==r)return this._originalData[b];this._originalData[b]=a};this.getToolkit=function(){return a};var u=C(k);this.segments=
# k?u.match:[];k=!!k&&u.value;p||a._getLocalItem(e.blacklisted)||(p=a._isBlacklisted(l)||!k,a._setLocalItem(e.blacklisted,p?"yes":"no"));e=!!h.length;g=h.length&&new a.Variant(a._registerVariant(c,h,p,g,k,m),a);this.name=c;e&&b.active&&!g.nocollect&&(this.variation=g);h=e&&b.active?b.defaultTrack:[];p&&Array.prototype.push.apply(h,b.blacklist?b.blacklist.track:[]);(h.length&&g.nocollect||!e||!g||!k)&&(this.variation=new a.Variant({name:c,variation:{track:k?h:[]}},a));e&&g&&k?g&&g.run?this.state="registered":
# this.state="persisted":(a._deregisterVariant(c),this.state="deregistered")};a.prototype._registerVariant=function(b,a,d,e,g,h){var k=f(b);e=h?w(b,[],!1,e):w(b,a,d,e);var m=h?this._getLocalItem(k.phash):this._getLocalItem(k.hash),l=this._getLocalItem(k.name);h="yes"==this._getLocalItem(k.visit);var p="yes"==this._getLocalItem(k.compute),t=function(a,b){a=parseFloat(a.customOptions.target);b=parseFloat(b.customOptions.target);return a<b?-1:a>b?1:0},r=u[this.id()],q=x(a,"name",l);if(g=!(!g||(p||d||"string"==
# typeof l||q)&&(!p||e==m)))if(r._mset&&r._mset[b])c.each(a,function(a,c){r._mset[b][c.name]&&(q=c)});else{a.sort(t);var A=[],y=0,z=0;c.each(a,function(a,b){var c=b.customOptions&&b.customOptions.target;if(c){c=parseFloat(c)/100;y+=c;var d={value:[z,y]};z+=c;A.push(d)}});var B=Math.random(0,1);c.each(A,function(a,b){B>=b.value[0]&&B<=b.value[1]&&(l=a)});q=a[l]}q?this._setLocalItem(k.name,q.name):this._setLocalItem(k.name,"_default");this._setLocalItem(k.visit,"yes");this._setLocalItem(k.compute,"yes");
# this._setLocalItem(k.hash,e);this._setLocalItem(k.phash,e);a=q&&(!d||h)&&{name:b,variation:q,collect:!0};return a||(a={name:b}),a.run=g,a};a.prototype._isBlacklisted=function(a){var f;a=a||[];return this._ignoreBlacklist||c.each(a,function(a,b){var c=new RegExp("^(http://)?(www\\.)?"+b.replace(/\./g,"\\.").replace(/\-/g,"\\-"),"gi");return!(f=!b&&!document.referrer||0<(b&&document.referrer.match(c)||[]).length)}),f};m("darwin-toolkit:v2.0.0",function(){return!0});l._dw.push=function(a){u[a[0]]?(u[a[0]]._dispatches[a[1]]&&
# a[2]&&a[2](u[a[0]]),u[a[0]]._handlers.push(a.slice(1,a.length))):(p[a[0]]||(p[a[0]]=[]),p[a[0]].push(a.slice(1,a.length)))};l._dw})(VisitorSegment,this);(function(m){m=new m("global");m.config({trackValueDelimiter:",",deferSegments:!1,collections:[{name:"recommendation",disabled:!1,tests:[{name:"recommendation-influencersexperiments",active:!0,"x-persist":!0,"x-status":"1",increment:0,segment:{},_token:"e3d87a",variations:[{customOptions:{target:"50"},name:"influencers",track:[{name:"list1",dynamic:!1,
# value:"recommendation-influencersexperiments:influencers"},{name:"prop56",dynamic:!1,value:"recommendation-influencersexperiments:influencers"},{name:"list1",dynamic:!1,value:"recommendation-influencersexperiments-e3d87a"},{name:"prop56",dynamic:!1,value:"recommendation-influencersexperiments-e3d87a"}]}],defaultTrack:[{name:"list1",dynamic:!1,value:"recommendation-influencersexperiments:default"},{name:"prop56",dynamic:!1,value:"recommendation-influencersexperiments:default"},{name:"list1",dynamic:!1,
# value:"recommendation-influencersexperiments-e3d87a"},{name:"prop56",dynamic:!1,value:"recommendation-influencersexperiments-e3d87a"}]}]},{name:"article",disabled:!0,tests:[{name:"article-breakingnews",active:!1,"x-persist":!0,"x-status":"1","x-linked":"0",increment:0,segment:{desktop:!0},_token:"3d7545",variations:[{customOptions:{target:"34"},name:"nobreakingnews",track:[{name:"list1",dynamic:!1,value:"article-breakingnews:nobreakingnews"},{name:"prop56",dynamic:!1,value:"article-breakingnews:nobreakingnews"},
# {name:"list1",dynamic:!1,value:"article-breakingnews-3d7545"},{name:"prop56",dynamic:!1,value:"article-breakingnews-3d7545"}]},{customOptions:{target:"33"},name:"sectionbreakingnews",track:[{name:"list1",dynamic:!1,value:"article-breakingnews:sectionbreakingnews"},{name:"prop56",dynamic:!1,value:"article-breakingnews:sectionbreakingnews"},{name:"list1",dynamic:!1,value:"article-breakingnews-3d7545"},{name:"prop56",dynamic:!1,value:"article-breakingnews-3d7545"}]},{customOptions:{target:"33"},name:"allbreakingnews",
# track:[{name:"list1",dynamic:!1,value:"article-breakingnews:allbreakingnews"},{name:"prop56",dynamic:!1,value:"article-breakingnews:allbreakingnews"},{name:"list1",dynamic:!1,value:"article-breakingnews-3d7545"},{name:"prop56",dynamic:!1,value:"article-breakingnews-3d7545"}]}],defaultTrack:[{name:"list1",dynamic:!1,value:"article-breakingnews:default"},{name:"prop56",dynamic:!1,value:"article-breakingnews:default"},{name:"list1",dynamic:!1,value:"article-breakingnews-3d7545"},{name:"prop56",dynamic:!1,
# value:"article-breakingnews-3d7545"}]},{name:"article-curatedContent",active:!1,"x-persist":!0,"x-status":"1","x-linked":"0",increment:1,segment:{},_token:"7d2dac",variations:[{customOptions:{target:"25"},name:"enabledhpfirst",track:[{name:"list1",dynamic:!1,value:"article-curatedContent:enabledhpfirst"},{name:"prop56",dynamic:!1,value:"article-curatedContent:enabledhpfirst"},{name:"list1",dynamic:!1,value:"article-curatedContent-7d2dac"},{name:"prop56",dynamic:!1,value:"article-curatedContent-7d2dac"}]},
# {customOptions:{target:"25"},name:"enabledprfirst",track:[{name:"list1",dynamic:!1,value:"article-curatedContent:enabledprfirst"},{name:"prop56",dynamic:!1,value:"article-curatedContent:enabledprfirst"},{name:"list1",dynamic:!1,value:"article-curatedContent-7d2dac"},{name:"prop56",dynamic:!1,value:"article-curatedContent-7d2dac"}]},{customOptions:{target:"25"},name:"enabledhponly",track:[{name:"list1",dynamic:!1,value:"article-curatedContent:enabledhponly"},{name:"prop56",dynamic:!1,value:"article-curatedContent:enabledhponly"},
# {name:"list1",dynamic:!1,value:"article-curatedContent-7d2dac"},{name:"prop56",dynamic:!1,value:"article-curatedContent-7d2dac"}]}],defaultTrack:[{name:"list1",dynamic:!1,value:"article-curatedContent:default"},{name:"prop56",dynamic:!1,value:"article-curatedContent:default"},{name:"list1",dynamic:!1,value:"article-curatedContent-7d2dac"},{name:"prop56",dynamic:!1,value:"article-curatedContent-7d2dac"}]}]},{name:"modal",disabled:!1,tests:[{name:"modal-adblock_v1",active:!0,"x-persist":!0,"x-status":"1",
# "x-linked":"0",increment:2,segment:{adblock_generic:!0},_token:"55ca44",variations:[{customOptions:{target:"90"},name:"enabled",track:[{name:"list1",dynamic:!1,value:"modal-adblock_v1:enabled"},{name:"prop56",dynamic:!1,value:"modal-adblock_v1:enabled"},{name:"list1",dynamic:!1,value:"modal-adblock_v1-55ca44"},{name:"prop56",dynamic:!1,value:"modal-adblock_v1-55ca44"}]}],defaultTrack:[{name:"list1",dynamic:!1,value:"modal-adblock_v1:default"},{name:"prop56",dynamic:!1,value:"modal-adblock_v1:default"},
# {name:"list1",dynamic:!1,value:"modal-adblock_v1-55ca44"},{name:"prop56",dynamic:!1,value:"modal-adblock_v1-55ca44"}]}]},{name:"video",disabled:!1,tests:[{name:"video-adtimeout",active:!0,"x-persist":!0,"x-status":"1","x-linked":"0",increment:0,segment:{},_token:"ca9b46",variations:[{customOptions:{target:"10"},name:"eightSecond",track:[{name:"list1",dynamic:!1,value:"video-adtimeout:eightSecond"},{name:"prop56",dynamic:!1,value:"video-adtimeout:eightSecond"},{name:"list1",dynamic:!1,value:"video-adtimeout-ca9b46"},
# {name:"prop56",dynamic:!1,value:"video-adtimeout-ca9b46"}]}],defaultTrack:[{name:"list1",dynamic:!1,value:"video-adtimeout:default"},{name:"prop56",dynamic:!1,value:"video-adtimeout:default"},{name:"list1",dynamic:!1,value:"video-adtimeout-ca9b46"},{name:"prop56",dynamic:!1,value:"video-adtimeout-ca9b46"}]}]},{name:"upgrade",disabled:!1,tests:[{name:"upgrade-toolkit_v110",active:!0,"x-persist":!0,"x-status":"1","x-linked":"0",increment:0,segment:{},_token:"fe334d",variations:[{customOptions:{target:"25"},
# name:"variant_1",track:[{name:"list1",dynamic:!1,value:"upgrade-toolkit_v110:variant_1"},{name:"prop56",dynamic:!1,value:"upgrade-toolkit_v110:variant_1"},{name:"list1",dynamic:!1,value:"upgrade-toolkit_v110-fe334d"},{name:"prop56",dynamic:!1,value:"upgrade-toolkit_v110-fe334d"}]}],defaultTrack:[{name:"list1",dynamic:!1,value:"upgrade-toolkit_v110:default"},{name:"prop56",dynamic:!1,value:"upgrade-toolkit_v110:default"},{name:"list1",dynamic:!1,value:"upgrade-toolkit_v110-fe334d"},{name:"prop56",
# dynamic:!1,value:"upgrade-toolkit_v110-fe334d"}]}]}]});this.__dwCallback__?this.__dwCallback__(m):m.init()})(this._dw)}();</script> </div> </div> <div class="moat-trackable pb-f-theme-normal pb-f-dehydrate-false full pb-feature pb-layout-item pb-f-posttv-player" data-chain-name="no-name" data-feature-id="posttv/player" data-feature-name="no-name" data-pb-fingerprint="0fQbyEaIOpT" id="f0bFz5SocOndnq" moat-id="posttv/player|world"> </div> <div class="pb-container"> </div></section> <div class="pb-container"> </div></div> <script>window.pageBuilder&&window.pageBuilder.initVariants&&window.pageBuilder.initVariants({IS_ADMIN:!1,TIMEOUT:wp_pb.banditoEnv.TIMEOUT,PERF_API:wp_pb.banditoEnv.PERF_API,TESTS_API:wp_pb.banditoEnv.TESTS_API,EVENTS_API:wp_pb.banditoEnv.EVENTS_API});</script> <script>console.time("hi-pri-js");</script> <script src="/pb/gr/c/default/r0pDNIUocOndnq/hi-pri-js/e7f066f51e.js?_=72a89"></script> <script src="/pb/gr/p/default/r0pDNIUocOndnq/hi-pri-render.js?_=5b7b1"></script> <script>console.timeEnd("hi-pri-js");</script> <script>window.TWPHead.ready("main.js",function(){window.TWP&&TWP.Analytics&&TWP.Analytics.init({trackScrolling:{omniture:!1},snowflake:!0,suppressTrackPageLoad:wp_pb.StaticMethods.isPageHydrated()?!1:!0})});</script> <noscript><img src="https://sb.scorecardresearch.com/p?c1=2&amp;c2=3005617&amp;cv=2.0&amp;cj=1"/></noscript> <noscript><img alt="" src="//me.effectivemeasure.net/em_image" style="position:absolute; left:-5px;"/></noscript> <script>console.time("js");</script> <script src="/pb/gr/c/default/r0pDNIUocOndnq/js/46707ff31b.js?_=a69b2"></script> <script src="//js.washingtonpost.com/video/resources/js/posttv/vendor/underscore-min.js"></script> <script src="//js.washingtonpost.com/video/resources/env/WapoVideo/dist/WapoVideoEmbed.min.js"></script> <script>console.timeEnd("js");</script> <script>console.time("render.js");</script> <script src="/pb/gr/p/default/r0pDNIUocOndnq/render.js?_=5b7b1"></script> <script>console.timeEnd("render.js");</script> <script>console.time("instance.js");</script> <script src="/pb/gr/p/default/r0pDNIUocOndnq/instance.js?_=5b7b1"></script> <script>console.timeEnd("instance.js");</script> <script>console.time("after_features");</script> <script src="/pb/gr/c/default/r0pDNIUocOndnq/after_features/faf77027df.js?_=374bc"></script> <script>console.timeEnd("after_features");</script> <script>console.time("content_type_article");</script> <script>console.timeEnd("content_type_article");</script> <script>console.time("third_party");</script> <script>console.timeEnd("third_party");</script> <script>(function(){"__twpCookieMonster__"in document&&document.__twpCookieMonster__.ommNom()})();</script> <script>jQuery(function(){function a(){try{var a=$(".tweet-authors");!a.length||window.twttr&&twttr.widgets||$.ajax({dataType:"script",cache:!0,url:"//platform.twitter.com/widgets.js",success:function(b){a.find(".pb-twitter-follow.unprocessed").removeClass("unprocessed")}});$.ajax({dataType:"script",cache:!0,url:"//ak.sail-horizon.com/horizon/v1.js",success:function(a){window.Sailthru&&Sailthru.setup({domain:"horizon.washingtonpost.com"})}})}catch(c){}}wp_pb.StaticMethods.isPageHydrated()&&a();__e.push(["shamble:end",
# function(){a()}])});</script> <script>jQuery(function(){try{$("body").append('\x3cimg src\x3d"https://amplifypixel.outbrain.com/pixel?mid\x3d00bb70a80ee8f020d9011cbcef307fe64d"\x3e')}catch(a){}});</script> <script>!function(){if(!(99<Math.floor(100*Math.random()))){var c,b,d,a=document.createElement("iframe");a.src="javascript:false";(a.frameElement||a).style.cssText="width: 0; height: 0; border: 0";d=document.getElementsByTagName("script")[0];d.parentNode.insertBefore(a,d);try{b=a.contentWindow.document}catch(e){c=document.domain,a.src="javascript:var d\x3ddocument.open();d.domain\x3d'"+c+"';void(0);",b=a.contentWindow.document}b.open()._l=function(){var a=this.createElement("script");c&&(this.domain=c);a.id=
# "boomr-if-as";a.src="//www.washingtonpost.com/wp-stat/rum/wprum.min.js";this.body.appendChild(a)};b.write('\x3cbody onload\x3d"document._l();"\x3e');b.close()}}();</script> <script>ResourceBundle.processInlineScripts();</script> </body> </html>

# %% [markdown]
# ###### Returns all the article elements

# %%
text = ''. join(map(lambda p:p.text, soup.find_all('article')))
text
# Out:
# "  MOSCOW — Companies worldwide struggled to recover Wednesday after a wave of powerful cyberattacks crippled computer systems in Europe, Asia and the United States with a virus similar to the global ransomware assault in May that infected computers.\xa0 Researchers at Kaspersky Lab in Russia\xa0said\xa0Wednesday that a regional Ukrainian website was hacked and used to distribute the ransomware, which attacked around 2,000 users across the globe.\xa0 The company said that its preliminary findings suggest the malware is a new kind of ransomware not seen before, not a variant of the Petya ransomware, as other cybersecurity researchers had suggested. It named the malware *ExPetr*, adding that while “it has several strings similar to Petya, it possesses entirely different functionality.” Kaspersky estimated that more than 2,000 attacks were carried out — 60 percent of them in Ukraine and 30 percent in Russia. Among the targets was Russia’s largest oil company. But Kremlin spokesman Dmitry Peskov said “no serious problems” had occurred as a result of the cyberattacks. Speaking on a conference call Wednesday, Peskov also said\xa0he had no accurate information on the origin of the attacks.\xa0       (Sarah Parnass,Dani Player,Daron Taylor/The Washington Post)   The worst damage was in Ukraine,\xa0and some Ukrainian officials initially\xa0expressed suspicions\xa0that the attacks originated in Russia. The country’s cyber police department told the Interfax news agency that it has received more than 1,000 reports of attacks. They affected government ministries, banks, utilities and other important infrastructure and companies nationwide, demanding ransoms from government employees in the cryptocurrency bitcoin. The virus even downed systems at the site of the former Chernobyl nuclear power plant in northern Ukraine, forcing scientists to manually monitor radiation levels at the site of a 1986 disaster that released massive amounts of radioactive material.  Companies in Belarus were also hit, the country's Interior Ministry said Wednesday. It said infected files were being sent under the guise of CVs, financial reports and other documents, or disguised as archives containing documents. On Wednesday, Danish shipping giant A.P. Moller-Maersk\xa0said it was working to\xa0restore its operations a day after being hit by the cyberattack.\xa0 “We have contained the issue and are working on a technical recovery plan with key IT partners and global cyber security agencies,” Maersk, which handles one in every seven containers shipped worldwide, said in a stock exchange announcement.\xa0 The Copenhagen-based group said APM Terminals, an international container terminal operating company owned by Maersk, was affected “in a number of ports.” But it said its\xa0vessels with Maersk Line were “maneuverable, able to communicate and crews are safe.” Cyberattacks also spread as far as India and the United States, where the\xa0pharmaceutical giant Merck reported on Twitter that “our company’s computer network was compromised today as part of global hack.” The New Jersey-based company said it was investigating the attack.   The Maersk ship Adrian Maersk is seen as it departs from New York Harbor on June 27. (Brendan Mcdermid/Reuters)  France’s biggest bank, BNP Paribas, said Wednesday that its real estate unit, which provides services to corporations around Europe, was hit. “The international cyber attack hit our non-bank subsidiary, Real Estate. The necessary measures have been taken to rapidly contain the attack,” the bank said in a statement to Reuters. Kaspersky said the cyberattack involved modified versions of EternalBlue and EternalRomance, “exploits” developed by the National Security Agency that were later leaked onto the Internet by hackers. It was the second massive attack in the past two months to use powerful U.S. exploits against the IT infrastructure that supports national governments and corporations. The onslaught of ransomware attacks may b ...

# %% [markdown]
# #### removes all the special Characters from the text

# %%
text.encode('ascii', errors='replace').replace("?"," ")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-91-f893defcc0af> in <module>()
# ----> 1 text.encode('ascii', errors='replace').replace("?"," ")
#
# TypeError: a bytes-like object is required, not 'str'

# %%
from nltk.tokenize import sent_tokenize, word_tokenize

# %%
from nltk.corpus import stopwords

# %%
from string import punctuation

# %%
sents = sent_tokenize(text)
sents
# Out:
# ['  MOSCOW — Companies worldwide struggled to recover Wednesday after a wave of powerful cyberattacks crippled computer systems in Europe, Asia and the United States with a virus similar to the global ransomware assault in May that infected computers.',
#  'Researchers at Kaspersky Lab in Russia\xa0said\xa0Wednesday that a regional Ukrainian website was hacked and used to distribute the ransomware, which attacked around 2,000 users across the globe.',
#  'The company said that its preliminary findings suggest the malware is a new kind of ransomware not seen before, not a variant of the Petya ransomware, as other cybersecurity researchers had suggested.',
#  'It named the malware *ExPetr*, adding that while “it has several strings similar to Petya, it possesses entirely different functionality.” Kaspersky estimated that more than 2,000 attacks were carried out — 60 percent of them in Ukraine and 30 percent in Russia.',
#  'Among the targets was Russia’s largest oil company.',
#  'But Kremlin spokesman Dmitry Peskov said “no serious problems” had occurred as a result of the cyberattacks.',
#  'Speaking on a conference call Wednesday, Peskov also said\xa0he had no accurate information on the origin of the attacks.',
#  '(Sarah Parnass,Dani Player,Daron Taylor/The Washington Post)   The worst damage was in Ukraine,\xa0and some Ukrainian officials initially\xa0expressed suspicions\xa0that the attacks originated in Russia.',
#  'The country’s cyber police department told the Interfax news agency that it has received more than 1,000 reports of attacks.',
#  'They affected government ministries, banks, utilities and other important infrastructure and companies nationwide, demanding ransoms from government employees in the cryptocurrency bitcoin.',
#  'The virus even downed systems at the site of the former Chernobyl nuclear power plant in northern Ukraine, forcing scientists to manually monitor radiation levels at the site of a 1986 disaster that released massive amounts of radioactive material.',
#  "Companies in Belarus were also hit, the country's Interior Ministry said Wednesday.",
#  'It said infected files were being sent under the guise of CVs, financial reports and other documents, or disguised as archives containing documents.',
#  'On Wednesday, Danish shipping giant A.P.',
#  'Moller-Maersk\xa0said it was working to\xa0restore its operations a day after being hit by the cyberattack.',
#  '“We have contained the issue and are working on a technical recovery plan with key IT partners and global cyber security agencies,” Maersk, which handles one in every seven containers shipped worldwide, said in a stock exchange announcement.',
#  'The Copenhagen-based group said APM Terminals, an international container terminal operating company owned by Maersk, was affected “in a number of ports.” But it said its\xa0vessels with Maersk Line were “maneuverable, able to communicate and crews are safe.” Cyberattacks also spread as far as India and the United States, where the\xa0pharmaceutical giant Merck reported on Twitter that “our company’s computer network was compromised today as part of global hack.” The New Jersey-based company said it was investigating the attack.',
#  'The Maersk ship Adrian Maersk is seen as it departs from New York Harbor on June 27.',
#  '(Brendan Mcdermid/Reuters)  France’s biggest bank, BNP Paribas, said Wednesday that its real estate unit, which provides services to corporations around Europe, was hit.',
#  '“The international cyber attack hit our non-bank subsidiary, Real Estate.',
#  'The necessary measures have been taken to rapidly contain the attack,” the bank said in a statement to Reuters.',
#  'Kaspersky said the cyberattack involved modified versions of EternalBlue and EternalRomance, “exploits” developed by the National Security Agency that were later leaked onto the Internet by hackers.',
#  'It was the second massive attack in the past two months to use powerful U.S. exploits against the IT infrastructure that supports national governments and corporations.',
#  'The onslaught of ransomware attacks may be the “new normal,” said Mark Graff, chief executive of Tellagraff, a cybersecurity company.',
#  '“The emergence of Petya and WannaCry really points out the need for a response plan and a policy on what companies are going to do about ransomware,” he said.',
#  'WannaCry was the ransomware used in the May attack.',
#  '“You won’t want to make that decision at a time of panic, in a cloud of emotion.” The attack also hit companies in Spain, Norway and Britain.',
#  'Victims included the British advertising and marketing multinational WPP.',
#  'India’s biggest container port was also crippled when a Maersk-run terminal in Mumbai was hit.',
#  'The scale of the hacks and the use of ransomware recalled the massive cyberattack in May, in which hackers possibly linked to North Korea disabled computers in more than 150 nations using a flaw that was once incorporated into the NSA’s surveillance tool kit.',
#  '[NSA links WannaCry ransomware attack to North Korea]  Cyber researchers have tied the vulnerability exploited by the latest virus to the one used by WannaCry — a weakness discovered by the NSA years ago that the agency turned into a hacking tool dubbed EternalBlue.',
#  'The Petya-like malware, like WannaCry, is a worm that spreads quickly to vulnerable systems, said Bill Wright, senior policy counsel for Symantec, the world’s largest cyber\xadsecurity firm.',
#  'Its pervasiveness is\xa0what makes it difficult to control — or to aim at anyone in particular, he said.',
#  '“Once you unleash something that propagates in this manner, it’s impossible to control,” he said.',
#  'Although Microsoft in March made available a patch for the Windows flaw exploited by EternalBlue, Petya and its variants use other techniques to infect systems, said Jeff Greene, Symantec government affairs director.',
#  '“It’s a worm that has multiple ways to spread,” he said, which could explain why there are victims who applied the EternalBlue patch and still were affected.',
#  'The malware Kaspersky is calling *ExPetr* differs from WannaCry in that it does not appear to reach out to the Internet and scan for vulnerable systems, said Paul Burbage, a malware researcher with Flashpoint, a cyberthreat analysis firm.',
#  'It limits itself to the computers linked to the same router.',
#  'He said the variant of Petya used in the attacks is called GoldenEye, which was sold on underground forums used mainly by Russian-speaking criminal hackers, he said.',
#  '[The next ransomware attack will be worse]  The ransomware hit Europe in the early afternoon Tuesday.',
#  'In Ukraine, breaches were reported at computers governing the municipal energy company and airport in the capital, Kiev, the state telecommunications company Ukrtelecom, the Ukrainian postal service and the State Savings Bank of Ukraine.',
#  'Grocery store checkout machines broke down, ATMs demanded ransom payments, and the turnstile system in the Kiev metro reportedly stopped working.',
#  'The mayhem reached high into the government.',
#  'Ukrainian Deputy Prime Minister Pavlo Rozenko on Tuesday tweeted a picture of a computer screen warning in English that “one of your disks contains errors,” then adding in all capital letters: “DO NOT TURN OFF YOUR PC!',
#  'IF YOU ABORT THIS PROCESS, YOU COULD DESTROY ALL YOUR DATA!” “Ta-Dam!” he wrote.',
#  '“It seems the computers at the Cabinet of Ministers of Ukraine have been ‘knocked out.’ The network is down.” His spokeswoman published a photograph showing demands for a ransom in bitcoin to release data encrypted by the virus.',
#  'Suspicions in Ukraine quickly fell on Russia, which annexed Crimea in 2014 and has been blamed for several large-scale cyberattacks on Ukraine’s power infrastructure.',
#  'But no proof of the attack was presented, and Russian companies, like the oil giant Rosneft, also complained of being hit by a “powerful hacking attack.” Photographs leaked to the news media from a Rosneft-owned regional oil company showed computers displaying ransomware demands similar to those in Ukraine.',
#  'Nakashima reported from Washington.',
#  'Isaac Stanley-Becker in Berlin and Hamza Shaban and Julie Tate in Washington contributed to this report.',
#  'Read more:   How to protect yourself from the global ransomware attack       Today’s coverage from Post correspondents around the world   Like Washington Post World on Facebook and stay updated on foreign news']

# %%
words_sent = word_tokenize(text.lower())
words_sent
# Out:
# ['moscow',
#  '—',
#  'companies',
#  'worldwide',
#  'struggled',
#  'to',
#  'recover',
#  'wednesday',
#  'after',
#  'a',
#  'wave',
#  'of',
#  'powerful',
#  'cyberattacks',
#  'crippled',
#  'computer',
#  'systems',
#  'in',
#  'europe',
#  ',',
#  'asia',
#  'and',
#  'the',
#  'united',
#  'states',
#  'with',
#  'a',
#  'virus',
#  'similar',
#  'to',
#  'the',
#  'global',
#  'ransomware',
#  'assault',
#  'in',
#  'may',
#  'that',
#  'infected',
#  'computers',
#  '.',
#  'researchers',
#  'at',
#  'kaspersky',
#  'lab',
#  'in',
#  'russia',
#  'said',
#  'wednesday',
#  'that',
#  'a',
#  'regional',
#  'ukrainian',
#  'website',
#  'was',
#  'hacked',
#  'and',
#  'used',
#  'to',
#  'distribute',
#  'the',
#  'ransomware',
#  ',',
#  'which',
#  'attacked',
#  'around',
#  '2,000',
#  'users',
#  'across',
#  'the',
#  'globe',
#  '.',
#  'the',
#  'company',
#  'said',
#  'that',
#  'its',
#  'preliminary',
#  'findings',
#  'suggest',
#  'the',
#  'malware',
#  'is',
#  'a',
#  'new',
#  'kind',
#  'of',
#  'ransomware',
#  'not',
#  'seen',
#  'before',
#  ',',
#  'not',
#  'a',
#  'variant',
#  'of',
#  'the',
#  'petya',
#  'ransomware',
#  ',',
#  'as',
#  'other',
#  'cybersecurity',
#  'researchers',
#  'had',
#  'suggested',
#  '.',
#  'it',
#  'named',
#  'the',
#  'malware',
#  '*expetr*',
#  ',',
#  'adding',
#  'that',
#  'while',
#  '“',
#  'it',
#  'has',
#  'several',
#  'strings',
#  'similar',
#  'to',
#  'petya',
#  ',',
#  'it',
#  'possesses',
#  'entirely',
#  'different',
#  'functionality.',
#  '”',
#  'kaspersky',
#  'estimated',
#  'that',
#  'more',
#  'than',
#  '2,000',
#  'attacks',
#  'were',
#  'carried',
#  'out',
#  '—',
#  '60',
#  'percent',
#  'of',
#  'them',
#  'in',
#  'ukraine',
#  'and',
#  '30',
#  'percent',
#  'in',
#  'russia',
#  '.',
#  'among',
#  'the',
#  'targets',
#  'was',
#  'russia',
#  '’',
#  's',
#  'largest',
#  'oil',
#  'company',
#  '.',
#  'but',
#  'kremlin',
#  'spokesman',
#  'dmitry',
#  'peskov',
#  'said',
#  '“',
#  'no',
#  'serious',
#  'problems',
#  '”',
#  'had',
#  'occurred',
#  'as',
#  'a',
#  'result',
#  'of',
#  'the',
#  'cyberattacks',
#  '.',
#  'speaking',
#  'on',
#  'a',
#  'conference',
#  'call',
#  'wednesday',
#  ',',
#  'peskov',
#  'also',
#  'said',
#  'he',
#  'had',
#  'no',
#  'accurate',
#  'information',
#  'on',
#  'the',
#  'origin',
#  'of',
#  'the',
#  'attacks',
#  '.',
#  '(',
#  'sarah',
#  'parnass',
#  ',',
#  'dani',
#  'player',
#  ',',
#  'daron',
#  'taylor/the',
#  'washington',
#  'post',
#  ')',
#  'the',
#  'worst',
#  'damage',
#  'was',
#  'in',
#  'ukraine',
#  ',',
#  'and',
#  'some',
#  'ukrainian',
#  'officials',
#  'initially',
#  'expressed',
#  'suspicions',
#  'that',
#  'the',
#  'attacks',
#  'originated',
#  'in',
#  'russia',
#  '.',
#  'the',
#  'country',
#  '’',
#  's',
#  'cyber',
#  'police',
#  'department',
#  'told',
#  'the',
#  'interfax',
#  'news',
#  'agency',
#  'that',
#  'it',
#  'has',
#  'received',
#  'more',
#  'than',
#  '1,000',
#  'reports',
#  'of',
#  'attacks',
#  '.',
#  'they',
#  'affected',
#  'government',
#  'ministries',
#  ',',
#  'banks',
#  ',',
#  'utilities',
#  'and',
#  'other',
#  'important',
#  'infrastructure',
#  'and',
#  'companies',
#  'nationwide',
#  ',',
#  'demanding',
#  'ransoms',
#  'from',
#  'government',
#  'employees',
#  'in',
#  'the',
#  'cryptocurrency',
#  'bitcoin',
#  '.',
#  'the',
#  'virus',
#  'even',
#  'downed',
#  'systems',
#  'at',
#  'the',
#  'site',
#  'of',
#  'the',
#  'former',
#  'chernobyl',
#  'nuclear',
#  'power',
#  'plant',
#  'in',
#  'northern',
#  'ukraine',
#  ',',
#  'forcing',
#  'scientists',
#  'to',
#  'manually',
#  'monitor',
#  'radiation',
#  'levels',
#  'at',
#  'the',
#  'site',
#  'of',
#  'a',
#  '1986',
#  'disaster',
#  'that',
#  'released',
#  'massive',
#  'amounts',
#  'of',
#  'radioactive',
#  'material',
#  '.',
#  'companies',
#  'in',
#  'belarus',
#  'were',
#  'also',
#  'hit',
#  ',',
#  'the',
#  'country',
#  "'s",
#  'interior',
#  'ministry',
#  'said',
#  'wednesday',
#  '.',
#  'it',
#  'said',
#  'infected',
#  'files',
#  'were',
#  'being',
#  'sent',
#  'under',
#  'the',
#  'guise',
#  'of',
#  'cvs',
#  ',',
#  'financial',
#  'reports',
#  'and',
#  'other',
#  'documents',
#  ',',
#  'or',
#  'disguised',
#  'as',
#  'archives',
#  'containing',
#  'documents',
#  '.',
#  'on',
#  'wednesday',
#  ',',
#  'danish',
#  'shipping',
#  'giant',
#  'a.p',
#  '.',
#  'moller-maersk',
#  'said',
#  'it',
#  'was',
#  'working',
#  'to',
#  'restore',
#  'its',
#  'operations',
#  'a',
#  'day',
#  'after',
#  'being',
#  'hit',
#  'by',
#  'the',
#  'cyberattack',
#  '.',
#  '“',
#  'we',
#  'have',
#  'contained',
#  'the',
#  'issue',
#  'and',
#  'are',
#  'working',
#  'on',
#  'a',
#  'technical',
#  'recovery',
#  'plan',
#  'with',
#  'key',
#  'it',
#  'partners',
#  'and',
#  'global',
#  'cyber',
#  'security',
#  'agencies',
#  ',',
#  '”',
#  'maersk',
#  ',',
#  'which',
#  'handles',
#  'one',
#  'in',
#  'every',
#  'seven',
#  'containers',
#  'shipped',
#  'worldwide',
#  ',',
#  'said',
#  'in',
#  'a',
#  'stock',
#  'exchange',
#  'announcement',
#  '.',
#  'the',
#  'copenhagen-based',
#  'group',
#  'said',
#  'apm',
#  'terminals',
#  ',',
#  'an',
#  'international',
#  'container',
#  'terminal',
#  'operating',
#  'company',
#  'owned',
#  'by',
#  'maersk',
#  ',',
#  'was',
#  'affected',
#  '“',
#  'in',
#  'a',
#  'number',
#  'of',
#  'ports.',
#  '”',
#  'but',
#  'it',
#  'said',
#  'its',
#  'vessels',
#  'with',
#  'maersk',
#  'line',
#  'were',
#  '“',
#  'maneuverable',
#  ',',
#  'able',
#  'to',
#  'communicate',
#  'and',
#  'crews',
#  'are',
#  'safe.',
#  '”',
#  'cyberattacks',
#  'also',
#  'spread',
#  'as',
#  'far',
#  'as',
#  'india',
#  'and',
#  'the',
#  'united',
#  'states',
#  ',',
#  'where',
#  'the',
#  'pharmaceutical',
#  'giant',
#  'merck',
#  'reported',
#  'on',
#  'twitter',
#  'that',
#  '“',
#  'our',
#  'company',
#  '’',
#  's',
#  'computer',
#  'network',
#  'was',
#  'compromised',
#  'today',
#  'as',
#  'part',
#  'of',
#  'global',
#  'hack.',
#  '”',
#  'the',
#  'new',
#  'jersey-based',
#  'company',
#  'said',
#  'it',
#  'was',
#  'investigating',
#  'the',
#  'attack',
#  '.',
#  'the',
#  'maersk',
#  'ship',
#  'adrian',
#  'maersk',
#  'is',
#  'seen',
#  'as',
#  'it',
#  'departs',
#  'from',
#  'new',
#  'york',
#  'harbor',
#  'on',
#  'june',
#  '27',
#  '.',
#  '(',
#  'brendan',
#  'mcdermid/reuters',
#  ')',
#  'france',
#  '’',
#  's',
#  'biggest',
#  'bank',
#  ',',
#  'bnp',
#  'paribas',
#  ',',
#  'said',
#  'wednesday',
#  'that',
#  'its',
#  'real',
#  'estate',
#  'unit',
#  ',',
#  'which',
#  'provides',
#  'services',
#  'to',
#  'corporations',
#  'around',
#  'europe',
#  ',',
#  'was',
#  'hit',
#  '.',
#  '“',
#  'the',
#  'international',
#  'cyber',
#  'attack',
#  'hit',
#  'our',
#  'non-bank',
#  'subsidiary',
#  ',',
#  'real',
#  'estate',
#  '.',
#  'the',
#  'necessary',
#  'measures',
#  'have',
#  'been',
#  'taken',
#  'to',
#  'rapidly',
#  'contain',
#  'the',
#  'attack',
#  ',',
#  '”',
#  'the',
#  'bank',
#  'said',
#  'in',
#  'a',
#  'statement',
#  'to',
#  'reuters',
#  '.',
#  'kaspersky',
#  'said',
#  'the',
#  'cyberattack',
#  'involved',
#  'modified',
#  'versions',
#  'of',
#  'eternalblue',
#  'and',
#  'eternalromance',
#  ',',
#  '“',
#  'exploits',
#  '”',
#  'developed',
#  'by',
#  'the',
#  'national',
#  'security',
#  'agency',
#  'that',
#  'were',
#  'later',
#  'leaked',
#  'onto',
#  'the',
#  'internet',
#  'by',
#  'hackers',
#  '.',
#  'it',
#  'was',
#  'the',
#  'second',
#  'massive',
#  'attack',
#  'in',
#  'the',
#  'past',
#  'two',
#  'months',
#  'to',
#  'use',
#  'powerful',
#  'u.s.',
#  'exploits',
#  'against',
#  'the',
#  'it',
#  'infrastructure',
#  'that',
#  'supports',
#  'national',
#  'governments',
#  'and',
#  'corporations',
#  '.',
#  'the',
#  'onslaught',
#  'of',
#  'ransomware',
#  'attacks',
#  'may',
#  'be',
#  'the',
#  '“',
#  'new',
#  'normal',
#  ',',
#  '”',
#  'said',
#  'mark',
#  'graff',
#  ',',
#  'chief',
#  'executive',
#  'of',
#  'tellagraff',
#  ',',
#  'a',
#  'cybersecurity',
#  'company',
#  '.',
#  '“',
#  'the',
#  'emergence',
#  'of',
#  'petya',
#  'and',
#  'wannacry',
#  'really',
#  'points',
#  'out',
#  'the',
#  'need',
#  'for',
#  'a',
#  'response',
#  'plan',
#  'and',
#  'a',
#  'policy',
#  'on',
#  'what',
#  'companies',
#  'are',
#  'going',
#  'to',
#  'do',
#  'about',
#  'ransomware',
#  ',',
#  '”',
#  'he',
#  'said',
#  '.',
#  'wannacry',
#  'was',
#  'the',
#  'ransomware',
#  'used',
#  'in',
#  'the',
#  'may',
#  'attack',
#  '.',
#  '“',
#  'you',
#  'won',
#  '’',
#  't',
#  'want',
#  'to',
#  'make',
#  'that',
#  'decision',
#  'at',
#  'a',
#  'time',
#  'of',
#  'panic',
#  ',',
#  'in',
#  'a',
#  'cloud',
#  'of',
#  'emotion.',
#  '”',
#  'the',
#  'attack',
#  'also',
#  'hit',
#  'companies',
#  'in',
#  'spain',
#  ',',
#  'norway',
#  'and',
#  'britain',
#  '.',
#  'victims',
#  'included',
#  'the',
#  'british',
#  'advertising',
#  'and',
#  'marketing',
#  'multinational',
#  'wpp',
#  '.',
#  'india',
#  '’',
#  's',
#  'biggest',
#  'container',
#  'port',
#  'was',
#  'also',
#  'crippled',
#  'when',
#  'a',
#  'maersk-run',
#  'terminal',
#  'in',
#  'mumbai',
#  'was',
#  'hit',
#  '.',
#  'the',
#  'scale',
#  'of',
#  'the',
#  'hacks',
#  'and',
#  'the',
#  'use',
#  'of',
#  'ransomware',
#  'recalled',
#  'the',
#  'massive',
#  'cyberattack',
#  'in',
#  'may',
#  ',',
#  'in',
#  'which',
#  'hackers',
#  'possibly',
#  'linked',
#  'to',
#  'north',
#  'korea',
#  'disabled',
#  'computers',
#  'in',
#  'more',
#  'than',
#  '150',
#  'nations',
#  'using',
#  'a',
#  'flaw',
#  'that',
#  'was',
#  'once',
#  'incorporated',
#  'into',
#  'the',
#  'nsa',
#  '’',
#  's',
#  'surveillance',
#  'tool',
#  'kit',
#  '.',
#  '[',
#  'nsa',
#  'links',
#  'wannacry',
#  'ransomware',
#  'attack',
#  'to',
#  'north',
#  'korea',
#  ']',
#  'cyber',
#  'researchers',
#  'have',
#  'tied',
#  'the',
#  'vulnerability',
#  'exploited',
#  'by',
#  'the',
#  'latest',
#  'virus',
#  'to',
#  'the',
#  'one',
#  'used',
#  'by',
#  'wannacry',
#  '—',
#  'a',
#  'weakness',
#  'discovered',
#  'by',
#  'the',
#  'nsa',
#  'years',
#  'ago',
#  'that',
#  'the',
#  'agency',
#  'turned',
#  'into',
#  'a',
#  'hacking',
#  'tool',
#  'dubbed',
#  'eternalblue',
#  '.',
#  'the',
#  'petya-like',
#  'malware',
#  ',',
#  'like',
#  'wannacry',
#  ',',
#  'is',
#  'a',
#  'worm',
#  'that',
#  'spreads',
#  'quickly',
#  'to',
#  'vulnerable',
#  'systems',
#  ',',
#  'said',
#  'bill',
#  'wright',
#  ',',
#  'senior',
#  'policy',
#  'counsel',
#  'for',
#  'symantec',
#  ',',
#  'the',
#  'world',
#  '’',
#  's',
#  'largest',
#  'cyber\xadsecurity',
#  'firm',
#  '.',
#  'its',
#  'pervasiveness',
#  'is',
#  'what',
#  'makes',
#  'it',
#  'difficult',
#  'to',
#  'control',
#  '—',
#  'or',
#  'to',
#  'aim',
#  'at',
#  'anyone',
#  'in',
#  'particular',
#  ',',
#  'he',
#  'said',
#  '.',
#  '“',
#  'once',
#  'you',
#  'unleash',
#  'something',
#  'that',
#  'propagates',
#  'in',
#  'this',
#  'manner',
#  ',',
#  'it',
#  '’',
#  's',
#  'impossible',
#  'to',
#  'control',
#  ',',
#  '”',
#  'he',
#  'said',
#  '.',
#  'although',
#  'microsoft',
#  'in',
#  'march',
#  'made',
#  'available',
#  'a',
#  'patch',
#  'for',
#  'the',
#  'windows',
#  'flaw',
#  'exploited',
#  'by',
#  'eternalblue',
#  ',',
#  'petya',
#  'and',
#  'its',
#  ...]

# %%
_stopwords = set(stopwords.words('english')+list(punctuation))
_stopwords
# Out:
# {'!',
#  '"',
#  '#',
#  '$',
#  '%',
#  '&',
#  "'",
#  '(',
#  ')',
#  '*',
#  '+',
#  ',',
#  '-',
#  '.',
#  '/',
#  ':',
#  ';',
#  '<',
#  '=',
#  '>',
#  '?',
#  '@',
#  '[',
#  '\\',
#  ']',
#  '^',
#  '_',
#  '`',
#  'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  'd',
#  'did',
#  'didn',
#  'do',
#  'does',
#  'doesn',
#  'doing',
#  'don',
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  'has',
#  'hasn',
#  'have',
#  'haven',
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  'it',
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  'more',
#  'most',
#  'mustn',
#  'my',
#  'myself',
#  'needn',
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  'she',
#  'should',
#  'shouldn',
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  'we',
#  'were',
#  'weren',
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  'wouldn',
#  'y',
#  'you',
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  '{',
#  '|',
#  '}',
#  '~'}

# %%
words_sent = [word for word in word_sent if word not in _stopwords]

# %%
words_sent
# Out:
# ['moscow',
#  '—',
#  'companies',
#  'worldwide',
#  'struggled',
#  'recover',
#  'wednesday',
#  'wave',
#  'powerful',
#  'cyberattacks',
#  'crippled',
#  'computer',
#  'systems',
#  'europe',
#  'asia',
#  'united',
#  'states',
#  'virus',
#  'similar',
#  'global',
#  'ransomware',
#  'assault',
#  'may',
#  'infected',
#  'computers',
#  'researchers',
#  'kaspersky',
#  'lab',
#  'russia',
#  'said',
#  'wednesday',
#  'regional',
#  'ukrainian',
#  'website',
#  'hacked',
#  'used',
#  'distribute',
#  'ransomware',
#  'attacked',
#  'around',
#  '2,000',
#  'users',
#  'across',
#  'globe',
#  'company',
#  'said',
#  'preliminary',
#  'findings',
#  'suggest',
#  'malware',
#  'new',
#  'kind',
#  'ransomware',
#  'seen',
#  'variant',
#  'petya',
#  'ransomware',
#  'cybersecurity',
#  'researchers',
#  'suggested',
#  'named',
#  'malware',
#  '*expetr*',
#  'adding',
#  '“',
#  'several',
#  'strings',
#  'similar',
#  'petya',
#  'possesses',
#  'entirely',
#  'different',
#  'functionality.',
#  '”',
#  'kaspersky',
#  'estimated',
#  '2,000',
#  'attacks',
#  'carried',
#  '—',
#  '60',
#  'percent',
#  'ukraine',
#  '30',
#  'percent',
#  'russia',
#  'among',
#  'targets',
#  'russia',
#  '’',
#  'largest',
#  'oil',
#  'company',
#  'kremlin',
#  'spokesman',
#  'dmitry',
#  'peskov',
#  'said',
#  '“',
#  'serious',
#  'problems',
#  '”',
#  'occurred',
#  'result',
#  'cyberattacks',
#  'speaking',
#  'conference',
#  'call',
#  'wednesday',
#  'peskov',
#  'also',
#  'said',
#  'accurate',
#  'information',
#  'origin',
#  'attacks',
#  'sarah',
#  'parnass',
#  'dani',
#  'player',
#  'daron',
#  'taylor/the',
#  'washington',
#  'post',
#  'worst',
#  'damage',
#  'ukraine',
#  'ukrainian',
#  'officials',
#  'initially',
#  'expressed',
#  'suspicions',
#  'attacks',
#  'originated',
#  'russia',
#  'country',
#  '’',
#  'cyber',
#  'police',
#  'department',
#  'told',
#  'interfax',
#  'news',
#  'agency',
#  'received',
#  '1,000',
#  'reports',
#  'attacks',
#  'affected',
#  'government',
#  'ministries',
#  'banks',
#  'utilities',
#  'important',
#  'infrastructure',
#  'companies',
#  'nationwide',
#  'demanding',
#  'ransoms',
#  'government',
#  'employees',
#  'cryptocurrency',
#  'bitcoin',
#  'virus',
#  'even',
#  'downed',
#  'systems',
#  'site',
#  'former',
#  'chernobyl',
#  'nuclear',
#  'power',
#  'plant',
#  'northern',
#  'ukraine',
#  'forcing',
#  'scientists',
#  'manually',
#  'monitor',
#  'radiation',
#  'levels',
#  'site',
#  '1986',
#  'disaster',
#  'released',
#  'massive',
#  'amounts',
#  'radioactive',
#  'material',
#  'companies',
#  'belarus',
#  'also',
#  'hit',
#  'country',
#  "'s",
#  'interior',
#  'ministry',
#  'said',
#  'wednesday',
#  'said',
#  'infected',
#  'files',
#  'sent',
#  'guise',
#  'cvs',
#  'financial',
#  'reports',
#  'documents',
#  'disguised',
#  'archives',
#  'containing',
#  'documents',
#  'wednesday',
#  'danish',
#  'shipping',
#  'giant',
#  'a.p',
#  'moller-maersk',
#  'said',
#  'working',
#  'restore',
#  'operations',
#  'day',
#  'hit',
#  'cyberattack',
#  '“',
#  'contained',
#  'issue',
#  'working',
#  'technical',
#  'recovery',
#  'plan',
#  'key',
#  'partners',
#  'global',
#  'cyber',
#  'security',
#  'agencies',
#  '”',
#  'maersk',
#  'handles',
#  'one',
#  'every',
#  'seven',
#  'containers',
#  'shipped',
#  'worldwide',
#  'said',
#  'stock',
#  'exchange',
#  'announcement',
#  'copenhagen-based',
#  'group',
#  'said',
#  'apm',
#  'terminals',
#  'international',
#  'container',
#  'terminal',
#  'operating',
#  'company',
#  'owned',
#  'maersk',
#  'affected',
#  '“',
#  'number',
#  'ports.',
#  '”',
#  'said',
#  'vessels',
#  'maersk',
#  'line',
#  '“',
#  'maneuverable',
#  'able',
#  'communicate',
#  'crews',
#  'safe.',
#  '”',
#  'cyberattacks',
#  'also',
#  'spread',
#  'far',
#  'india',
#  'united',
#  'states',
#  'pharmaceutical',
#  'giant',
#  'merck',
#  'reported',
#  'twitter',
#  '“',
#  'company',
#  '’',
#  'computer',
#  'network',
#  'compromised',
#  'today',
#  'part',
#  'global',
#  'hack.',
#  '”',
#  'new',
#  'jersey-based',
#  'company',
#  'said',
#  'investigating',
#  'attack',
#  'maersk',
#  'ship',
#  'adrian',
#  'maersk',
#  'seen',
#  'departs',
#  'new',
#  'york',
#  'harbor',
#  'june',
#  '27',
#  'brendan',
#  'mcdermid/reuters',
#  'france',
#  '’',
#  'biggest',
#  'bank',
#  'bnp',
#  'paribas',
#  'said',
#  'wednesday',
#  'real',
#  'estate',
#  'unit',
#  'provides',
#  'services',
#  'corporations',
#  'around',
#  'europe',
#  'hit',
#  '“',
#  'international',
#  'cyber',
#  'attack',
#  'hit',
#  'non-bank',
#  'subsidiary',
#  'real',
#  'estate',
#  'necessary',
#  'measures',
#  'taken',
#  'rapidly',
#  'contain',
#  'attack',
#  '”',
#  'bank',
#  'said',
#  'statement',
#  'reuters',
#  'kaspersky',
#  'said',
#  'cyberattack',
#  'involved',
#  'modified',
#  'versions',
#  'eternalblue',
#  'eternalromance',
#  '“',
#  'exploits',
#  '”',
#  'developed',
#  'national',
#  'security',
#  'agency',
#  'later',
#  'leaked',
#  'onto',
#  'internet',
#  'hackers',
#  'second',
#  'massive',
#  'attack',
#  'past',
#  'two',
#  'months',
#  'use',
#  'powerful',
#  'u.s.',
#  'exploits',
#  'infrastructure',
#  'supports',
#  'national',
#  'governments',
#  'corporations',
#  'onslaught',
#  'ransomware',
#  'attacks',
#  'may',
#  '“',
#  'new',
#  'normal',
#  '”',
#  'said',
#  'mark',
#  'graff',
#  'chief',
#  'executive',
#  'tellagraff',
#  'cybersecurity',
#  'company',
#  '“',
#  'emergence',
#  'petya',
#  'wannacry',
#  'really',
#  'points',
#  'need',
#  'response',
#  'plan',
#  'policy',
#  'companies',
#  'going',
#  'ransomware',
#  '”',
#  'said',
#  'wannacry',
#  'ransomware',
#  'used',
#  'may',
#  'attack',
#  '“',
#  '’',
#  'want',
#  'make',
#  'decision',
#  'time',
#  'panic',
#  'cloud',
#  'emotion.',
#  '”',
#  'attack',
#  'also',
#  'hit',
#  'companies',
#  'spain',
#  'norway',
#  'britain',
#  'victims',
#  'included',
#  'british',
#  'advertising',
#  'marketing',
#  'multinational',
#  'wpp',
#  'india',
#  '’',
#  'biggest',
#  'container',
#  'port',
#  'also',
#  'crippled',
#  'maersk-run',
#  'terminal',
#  'mumbai',
#  'hit',
#  'scale',
#  'hacks',
#  'use',
#  'ransomware',
#  'recalled',
#  'massive',
#  'cyberattack',
#  'may',
#  'hackers',
#  'possibly',
#  'linked',
#  'north',
#  'korea',
#  'disabled',
#  'computers',
#  '150',
#  'nations',
#  'using',
#  'flaw',
#  'incorporated',
#  'nsa',
#  '’',
#  'surveillance',
#  'tool',
#  'kit',
#  'nsa',
#  'links',
#  'wannacry',
#  'ransomware',
#  'attack',
#  'north',
#  'korea',
#  'cyber',
#  'researchers',
#  'tied',
#  'vulnerability',
#  'exploited',
#  'latest',
#  'virus',
#  'one',
#  'used',
#  'wannacry',
#  '—',
#  'weakness',
#  'discovered',
#  'nsa',
#  'years',
#  'ago',
#  'agency',
#  'turned',
#  'hacking',
#  'tool',
#  'dubbed',
#  'eternalblue',
#  'petya-like',
#  'malware',
#  'like',
#  'wannacry',
#  'worm',
#  'spreads',
#  'quickly',
#  'vulnerable',
#  'systems',
#  'said',
#  'bill',
#  'wright',
#  'senior',
#  'policy',
#  'counsel',
#  'symantec',
#  'world',
#  '’',
#  'largest',
#  'cyber\xadsecurity',
#  'firm',
#  'pervasiveness',
#  'makes',
#  'difficult',
#  'control',
#  '—',
#  'aim',
#  'anyone',
#  'particular',
#  'said',
#  '“',
#  'unleash',
#  'something',
#  'propagates',
#  'manner',
#  '’',
#  'impossible',
#  'control',
#  '”',
#  'said',
#  'although',
#  'microsoft',
#  'march',
#  'made',
#  'available',
#  'patch',
#  'windows',
#  'flaw',
#  'exploited',
#  'eternalblue',
#  'petya',
#  'variants',
#  'use',
#  'techniques',
#  'infect',
#  'systems',
#  'said',
#  'jeff',
#  'greene',
#  'symantec',
#  'government',
#  'affairs',
#  'director',
#  '“',
#  '’',
#  'worm',
#  'multiple',
#  'ways',
#  'spread',
#  '”',
#  'said',
#  'could',
#  'explain',
#  'victims',
#  'applied',
#  'eternalblue',
#  'patch',
#  'still',
#  'affected',
#  'malware',
#  'kaspersky',
#  'calling',
#  '*expetr*',
#  'differs',
#  'wannacry',
#  'appear',
#  'reach',
#  'internet',
#  'scan',
#  'vulnerable',
#  'systems',
#  'said',
#  'paul',
#  'burbage',
#  'malware',
#  'researcher',
#  'flashpoint',
#  'cyberthreat',
#  'analysis',
#  'firm',
#  'limits',
#  'computers',
#  'linked',
#  'router',
#  'said',
#  'variant',
#  'petya',
#  'used',
#  'attacks',
#  'called',
#  'goldeneye',
#  'sold',
#  'underground',
#  'forums',
#  'used',
#  'mainly',
#  'russian-speaking',
#  'criminal',
#  'hackers',
#  'said',
#  'next',
#  'ransomware',
#  'attack',
#  'worse',
#  'ransomware',
#  'hit',
#  'europe',
#  'early',
#  'afternoon',
#  'tuesday',
#  'ukraine',
#  'breaches',
#  'reported',
#  'computers',
#  'governing',
#  'municipal',
#  'energy',
#  'company',
#  'airport',
#  'capital',
#  'kiev',
#  'state',
#  'telecommunications',
#  'company',
#  'ukrtelecom',
#  'ukrainian',
#  'postal',
#  'service',
#  'state',
#  'savings',
#  'bank',
#  'ukraine',
#  'grocery',
#  'store',
#  'checkout',
#  'machines',
#  'broke',
#  'atms',
#  'demanded',
#  'ransom',
#  'payments',
#  'turnstile',
#  'system',
#  'kiev',
#  'metro',
#  'reportedly',
#  'stopped',
#  'working',
#  'mayhem',
#  'reached',
#  'high',
#  'government',
#  'ukrainian',
#  'deputy',
#  'prime',
#  'minister',
#  'pavlo',
#  'rozenko',
#  'tuesday',
#  'tweeted',
#  'picture',
#  'computer',
#  'screen',
#  'warning',
#  'english',
#  '“',
#  'one',
#  'disks',
#  'contains',
#  'errors',
#  '”',
#  'adding',
#  'capital',
#  'letters',
#  '“',
#  'turn',
#  'pc',
#  'abort',
#  'process',
#  'could',
#  'destroy',
#  'data',
#  '”',
#  '“',
#  'ta-dam',
#  '”',
#  'wrote',
#  '“',
#  'seems',
#  'computers',
#  'cabinet',
#  'ministers',
#  'ukraine',
#  '‘',
#  'knocked',
#  'out.',
#  '’',
#  'network',
#  'down.',
#  '”',
#  'spokeswoman',
#  'published',
#  'photograph',
#  'showing',
#  'demands',
#  'ransom',
#  'bitcoin',
#  'release',
#  'data',
#  'encrypted',
#  'virus',
#  'suspicions',
#  'ukraine',
#  'quickly',
#  'fell',
#  'russia',
#  'annexed',
#  'crimea',
#  '2014',
#  'blamed',
#  'several',
#  'large-scale',
#  'cyberattacks',
#  'ukraine',
#  '’',
#  'power',
#  'infrastructure',
#  'proof',
#  'attack',
#  'presented',
#  'russian',
#  'companies',
#  'like',
#  'oil',
#  'giant',
#  'rosneft',
#  'also',
#  'complained',
#  'hit',
#  '“',
#  'powerful',
#  'hacking',
#  'attack.',
#  '”',
#  'photographs',
#  'leaked',
#  'news',
#  'media',
#  'rosneft-owned',
#  'regional',
#  'oil',
#  'company',
#  'showed',
#  'computers',
#  'displaying',
#  'ransomware',
#  'demands',
#  'similar',
#  'ukraine',
#  'nakashima',
#  'reported',
#  'washington',
#  'isaac',
#  'stanley-becker',
#  'berlin',
#  'hamza',
#  'shaban',
#  'julie',
#  'tate',
#  'washington',
#  'contributed',
#  'report',
#  'read',
#  'protect',
#  'global',
#  'ransomware',
#  'attack',
#  'today',
#  '’',
#  'coverage',
#  'post',
#  'correspondents',
#  'around',
#  'world',
#  'like',
#  'washington',
#  'post',
#  'world',
#  'facebook',
#  'stay',
#  'updated',
#  'foreign',
#  'news']

# %%
from nltk.probability import FreqDist

# %%
freq = FreqDist(words_sent)
freq
# Out:
# FreqDist({"'s": 1,
#           '*expetr*': 2,
#           '1,000': 1,
#           '150': 1,
#           '1986': 1,
#           '2,000': 2,
#           '2014': 1,
#           '27': 1,
#           '30': 1,
#           '60': 1,
#           'a.p': 1,
#           'able': 1,
#           'abort': 1,
#           'accurate': 1,
#           'across': 1,
#           'adding': 2,
#           'adrian': 1,
#           'advertising': 1,
#           'affairs': 1,
#           'affected': 3,
#           'afternoon': 1,
#           'agencies': 1,
#           'agency': 3,
#           'ago': 1,
#           'aim': 1,
#           'airport': 1,
#           'also': 6,
#           'although': 1,
#           'among': 1,
#           'amounts': 1,
#           'analysis': 1,
#           'annexed': 1,
#           'announcement': 1,
#           'anyone': 1,
#           'apm': 1,
#           'appear': 1,
#           'applied': 1,
#           'archives': 1,
#           'around': 3,
#           'asia': 1,
#           'assault': 1,
#           'atms': 1,
#           'attack': 10,
#           'attack.': 1,
#           'attacked': 1,
#           'attacks': 6,
#           'available': 1,
#           'bank': 3,
#           'banks': 1,
#           'belarus': 1,
#           'berlin': 1,
#           'biggest': 2,
#           'bill': 1,
#           'bitcoin': 2,
#           'blamed': 1,
#           'bnp': 1,
#           'breaches': 1,
#           'brendan': 1,
#           'britain': 1,
#           'british': 1,
#           'broke': 1,
#           'burbage': 1,
#           'cabinet': 1,
#           'call': 1,
#           'called': 1,
#           'calling': 1,
#           'capital': 2,
#           'carried': 1,
#           'checkout': 1,
#           'chernobyl': 1,
#           'chief': 1,
#           'cloud': 1,
#           'communicate': 1,
#           'companies': 6,
#           'company': 9,
#           'complained': 1,
#           'compromised': 1,
#           'computer': 3,
#           'computers': 6,
#           'conference': 1,
#           'contain': 1,
#           'contained': 1,
#           'container': 2,
#           'containers': 1,
#           'containing': 1,
#           'contains': 1,
#           'contributed': 1,
#           'control': 2,
#           'copenhagen-based': 1,
#           'corporations': 2,
#           'correspondents': 1,
#           'could': 2,
#           'counsel': 1,
#           'country': 2,
#           'coverage': 1,
#           'crews': 1,
#           'crimea': 1,
#           'criminal': 1,
#           'crippled': 2,
#           'cryptocurrency': 1,
#           'cvs': 1,
#           'cyber': 4,
#           'cyberattack': 3,
#           'cyberattacks': 4,
#           'cybersecurity': 2,
#           'cyberthreat': 1,
#           'cyber\xadsecurity': 1,
#           'damage': 1,
#           'dani': 1,
#           'danish': 1,
#           'daron': 1,
#           'data': 2,
#           'day': 1,
#           'decision': 1,
#           'demanded': 1,
#           'demanding': 1,
#           'demands': 2,
#           'department': 1,
#           'departs': 1,
#           'deputy': 1,
#           'destroy': 1,
#           'developed': 1,
#           'different': 1,
#           'differs': 1,
#           'difficult': 1,
#           'director': 1,
#           'disabled': 1,
#           'disaster': 1,
#           'discovered': 1,
#           'disguised': 1,
#           'disks': 1,
#           'displaying': 1,
#           'distribute': 1,
#           'dmitry': 1,
#           'documents': 2,
#           'down.': 1,
#           'downed': 1,
#           'dubbed': 1,
#           'early': 1,
#           'emergence': 1,
#           'emotion.': 1,
#           'employees': 1,
#           'encrypted': 1,
#           'energy': 1,
#           'english': 1,
#           'entirely': 1,
#           'errors': 1,
#           'estate': 2,
#           'estimated': 1,
#           'eternalblue': 4,
#           'eternalromance': 1,
#           'europe': 3,
#           'even': 1,
#           'every': 1,
#           'exchange': 1,
#           'executive': 1,
#           'explain': 1,
#           'exploited': 2,
#           'exploits': 2,
#           'expressed': 1,
#           'facebook': 1,
#           'far': 1,
#           'fell': 1,
#           'files': 1,
#           'financial': 1,
#           'findings': 1,
#           'firm': 2,
#           'flashpoint': 1,
#           'flaw': 2,
#           'forcing': 1,
#           'foreign': 1,
#           'former': 1,
#           'forums': 1,
#           'france': 1,
#           'functionality.': 1,
#           'giant': 3,
#           'global': 4,
#           'globe': 1,
#           'going': 1,
#           'goldeneye': 1,
#           'governing': 1,
#           'government': 4,
#           'governments': 1,
#           'graff': 1,
#           'greene': 1,
#           'grocery': 1,
#           'group': 1,
#           'guise': 1,
#           'hack.': 1,
#           'hacked': 1,
#           'hackers': 3,
#           'hacking': 2,
#           'hacks': 1,
#           'hamza': 1,
#           'handles': 1,
#           'harbor': 1,
#           'high': 1,
#           'hit': 8,
#           'important': 1,
#           'impossible': 1,
#           'included': 1,
#           'incorporated': 1,
#           'india': 2,
#           'infect': 1,
#           'infected': 2,
#           'information': 1,
#           'infrastructure': 3,
#           'initially': 1,
#           'interfax': 1,
#           'interior': 1,
#           'international': 2,
#           'internet': 2,
#           'investigating': 1,
#           'involved': 1,
#           'isaac': 1,
#           'issue': 1,
#           'jeff': 1,
#           'jersey-based': 1,
#           'julie': 1,
#           'june': 1,
#           'kaspersky': 4,
#           'key': 1,
#           'kiev': 2,
#           'kind': 1,
#           'kit': 1,
#           'knocked': 1,
#           'korea': 2,
#           'kremlin': 1,
#           'lab': 1,
#           'large-scale': 1,
#           'largest': 2,
#           'later': 1,
#           'latest': 1,
#           'leaked': 2,
#           'letters': 1,
#           'levels': 1,
#           'like': 3,
#           'limits': 1,
#           'line': 1,
#           'linked': 2,
#           'links': 1,
#           'machines': 1,
#           'made': 1,
#           'maersk': 5,
#           'maersk-run': 1,
#           'mainly': 1,
#           'make': 1,
#           'makes': 1,
#           'malware': 5,
#           'maneuverable': 1,
#           'manner': 1,
#           'manually': 1,
#           'march': 1,
#           'mark': 1,
#           'marketing': 1,
#           'massive': 3,
#           'material': 1,
#           'may': 4,
#           'mayhem': 1,
#           'mcdermid/reuters': 1,
#           'measures': 1,
#           'media': 1,
#           'merck': 1,
#           'metro': 1,
#           'microsoft': 1,
#           'minister': 1,
#           'ministers': 1,
#           'ministries': 1,
#           'ministry': 1,
#           'modified': 1,
#           'moller-maersk': 1,
#           'monitor': 1,
#           'months': 1,
#           'moscow': 1,
#           'multinational': 1,
#           'multiple': 1,
#           'mumbai': 1,
#           'municipal': 1,
#           'nakashima': 1,
#           'named': 1,
#           'national': 2,
#           'nations': 1,
#           'nationwide': 1,
#           'necessary': 1,
#           'need': 1,
#           'network': 2,
#           'new': 4,
#           'news': 3,
#           'next': 1,
#           'non-bank': 1,
#           'normal': 1,
#           'north': 2,
#           'northern': 1,
#           'norway': 1,
#           'nsa': 3,
#           'nuclear': 1,
#           'number': 1,
#           'occurred': 1,
#           'officials': 1,
#           'oil': 3,
#           'one': 3,
#           'onslaught': 1,
#           'onto': 1,
#           'operating': 1,
#           'operations': 1,
#           'origin': 1,
#           'originated': 1,
#           'out.': 1,
#           'owned': 1,
#           'panic': 1,
#           'paribas': 1,
#           'parnass': 1,
#           'part': 1,
#           'particular': 1,
#           'partners': 1,
#           'past': 1,
#           'patch': 2,
#           'paul': 1,
#           'pavlo': 1,
#           'payments': 1,
#           'pc': 1,
#           'percent': 2,
#           'pervasiveness': 1,
#           'peskov': 2,
#           'petya': 5,
#           'petya-like': 1,
#           'pharmaceutical': 1,
#           'photograph': 1,
#           'photographs': 1,
#           'picture': 1,
#           'plan': 2,
#           'plant': 1,
#           'player': 1,
#           'points': 1,
#           'police': 1,
#           'policy': 2,
#           'port': 1,
#           'ports.': 1,
#           'possesses': 1,
#           'possibly': 1,
#           'post': 3,
#           'postal': 1,
#           'power': 2,
#           'powerful': 3,
#           'preliminary': 1,
#           'presented': 1,
#           'prime': 1,
#           'problems': 1,
#           'process': 1,
#           'proof': 1,
#           'propagates': 1,
#           'protect': 1,
#           'provides': 1,
#           'published': 1,
#           'quickly': 2,
#           'radiation': 1,
#           'radioactive': 1,
#           'ransom': 2,
#           'ransoms': 1,
#           'ransomware': 13,
#           'rapidly': 1,
#           'reach': 1,
#           'reached': 1,
#           'read': 1,
#           'real': 2,
#           'really': 1,
#           'recalled': 1,
#           'received': 1,
#           'recover': 1,
#           'recovery': 1,
#           'regional': 2,
#           'release': 1,
#           'released': 1,
#           'report': 1,
#           'reported': 3,
#           'reportedly': 1,
#           'reports': 2,
#           'researcher': 1,
#           'researchers': 3,
#           'response': 1,
#           'restore': 1,
#           'result': 1,
#           'reuters': 1,
#           'rosneft': 1,
#           'rosneft-owned': 1,
#           'router': 1,
#           'rozenko': 1,
#           'russia': 5,
#           'russian': 1,
#           'russian-speaking': 1,
#           'safe.': 1,
#           'said': 24,
#           'sarah': 1,
#           'savings': 1,
#           'scale': 1,
#           'scan': 1,
#           'scientists': 1,
#           'screen': 1,
#           'second': 1,
#           'security': 2,
#           'seems': 1,
#           'seen': 2,
#           'senior': 1,
#           'sent': 1,
#           'serious': 1,
#           'service': 1,
#           'services': 1,
#           'seven': 1,
#           'several': 2,
#           'shaban': 1,
#           'ship': 1,
#           'shipped': 1,
#           'shipping': 1,
#           'showed': 1,
#           'showing': 1,
#           'similar': 3,
#           'site': 2,
#           'sold': 1,
#           'something': 1,
#           'spain': 1,
#           'speaking': 1,
#           'spokesman': 1,
#           'spokeswoman': 1,
#           'spread': 2,
#           'spreads': 1,
#           'stanley-becker': 1,
#           'state': 2,
#           'statement': 1,
#           'states': 2,
#           'stay': 1,
#           'still': 1,
#           'stock': 1,
#           'stopped': 1,
#           'store': 1,
#           'strings': 1,
#           'struggled': 1,
#           'subsidiary': 1,
#           'suggest': 1,
#           'suggested': 1,
#           'supports': 1,
#           'surveillance': 1,
#           'suspicions': 2,
#           'symantec': 2,
#           'system': 1,
#           'systems': 5,
#           'ta-dam': 1,
#           'taken': 1,
#           'targets': 1,
#           'tate': 1,
#           'taylor/the': 1,
#           'technical': 1,
#           'techniques': 1,
#           'telecommunications': 1,
#           'tellagraff': 1,
#           'terminal': 2,
#           'terminals': 1,
#           'tied': 1,
#           'time': 1,
#           'today': 2,
#           'told': 1,
#           'tool': 2,
#           'tuesday': 2,
#           'turn': 1,
#           'turned': 1,
#           'turnstile': 1,
#           'tweeted': 1,
#           'twitter': 1,
#           'two': 1,
#           'u.s.': 1,
#           'ukraine': 9,
#           'ukrainian': 4,
#           'ukrtelecom': 1,
#           'underground': 1,
#           'unit': 1,
#           'united': 2,
#           'unleash': 1,
#           'updated': 1,
#           'use': 3,
#           'used': 5,
#           'users': 1,
#           'using': 1,
#           'utilities': 1,
#           'variant': 2,
#           'variants': 1,
#           'versions': 1,
#           'vessels': 1,
#           'victims': 2,
#           'virus': 4,
#           'vulnerability': 1,
#           'vulnerable': 2,
#           'wannacry': 6,
#           'want': 1,
#           'warning': 1,
#           'washington': 4,
#           'wave': 1,
#           'ways': 1,
#           'weakness': 1,
#           'website': 1,
#           'wednesday': 6,
#           'windows': 1,
#           'working': 3,
#           'world': 3,
#           'worldwide': 2,
#           'worm': 2,
#           'worse': 1,
#           'worst': 1,
#           'wpp': 1,
#           'wright': 1,
#           'wrote': 1,
#           'years': 1,
#           'york': 1,
#           '—': 4,
#           '‘': 1,
#           '’': 13,
#           '“': 18,
#           '”': 18})

# %%
from heapq import nlargest

# %% [markdown]
# ###### here in the below code 10 means the number of elements that are to be returned
# ###### freq is the collection that has to be sorted
# ###### the freq.get is the method to find the corresponding value in dict freq for a given key the function returns the count

# %%
nlargest(10, freq, key = freq.get)
# Out:
# ['said',
#  '“',
#  '”',
#  'ransomware',
#  '’',
#  'attack',
#  'company',
#  'ukraine',
#  'hit',
#  'companies']

# %%
from collections import defaultdict

# %%
ranking= defaultdict(int)
for i,sent in enumerate(sents):
    for w in word_tokenize(sent.lower()):
        if w in freq:
            ranking[i] += freq[w]
ranking
# Out:
# defaultdict(int,
#             {0: 84,
#              1: 79,
#              2: 87,
#              3: 99,
#              4: 34,
#              5: 73,
#              6: 50,
#              7: 45,
#              8: 39,
#              9: 31,
#              10: 46,
#              11: 56,
#              12: 40,
#              13: 12,
#              14: 42,
#              15: 100,
#              16: 312,
#              17: 23,
#              18: 76,
#              19: 48,
#              20: 62,
#              21: 94,
#              22: 35,
#              23: 105,
#              24: 100,
#              25: 38,
#              26: 89,
#              27: 8,
#              28: 40,
#              29: 72,
#              30: 91,
#              31: 80,
#              32: 36,
#              33: 80,
#              34: 66,
#              35: 95,
#              36: 68,
#              37: 10,
#              38: 82,
#              39: 53,
#              40: 70,
#              41: 20,
#              42: 7,
#              43: 86,
#              44: 63,
#              45: 91,
#              46: 57,
#              47: 143,
#              48: 8,
#              49: 13,
#              50: 75})

# %%
sents_idx = nlargest(4, ranking , key=ranking.get)
sents_idx
# Out:
# [16, 47, 23, 15]

# %%
[sents[j] for j in sorted(sents_idx)]
# Out:
# ['“We have contained the issue and are working on a technical recovery plan with key IT partners and global cyber security agencies,” Maersk, which handles one in every seven containers shipped worldwide, said in a stock exchange announcement.',
#  'The Copenhagen-based group said APM Terminals, an international container terminal operating company owned by Maersk, was affected “in a number of ports.” But it said its\xa0vessels with Maersk Line were “maneuverable, able to communicate and crews are safe.” Cyberattacks also spread as far as India and the United States, where the\xa0pharmaceutical giant Merck reported on Twitter that “our company’s computer network was compromised today as part of global hack.” The New Jersey-based company said it was investigating the attack.',
#  'The onslaught of ransomware attacks may be the “new normal,” said Mark Graff, chief executive of Tellagraff, a cybersecurity company.',
#  'But no proof of the attack was presented, and Russian companies, like the oil giant Rosneft, also complained of being hit by a “powerful hacking attack.” Photographs leaked to the news media from a Rosneft-owned regional oil company showed computers displaying ransomware demands similar to those in Ukraine.']
